# %%
from wikification import wikification, wikification_filter

# %%
TEST_PATH = "test.txt"
with open(TEST_PATH, "r") as f:
    text = "\n".join(f.readlines())

# %%
len(text)
# Out:
# 68355

# %%
res = wikification(text[:10000],
                   wikification_type="FULL",
                   long_text_method_name="sum_classic_page_rank")

# %%
len(res["words"])
# Out:
# 2

# %%
res["concepts"] # attention chunk 0 ?
# Out:
# [{'title': 'Herculaneum',
#   'url': 'http://en.wikipedia.org/wiki/Herculaneum',
#   'pageRank': 0.03739412937379306,
#   'cosine': 0.6801656584737229,
#   'lang': 'en',
#   'support': [{'wFrom': 25, 'wTo': 25, 'chunk': 0},
#    {'wFrom': 65, 'wTo': 65, 'chunk': 0},
#    {'wFrom': 165, 'wTo': 165, 'chunk': 0},
#    {'wFrom': 197, 'wTo': 197, 'chunk': 0},
#    {'wFrom': 242, 'wTo': 242, 'chunk': 0},
#    {'wFrom': 292, 'wTo': 292, 'chunk': 0},
#    {'wFrom': 352, 'wTo': 352, 'chunk': 0},
#    {'wFrom': 363, 'wTo': 363, 'chunk': 0},
#    {'wFrom': 392, 'wTo': 392, 'chunk': 0},
#    {'wFrom': 446, 'wTo': 446, 'chunk': 0},
#    {'wFrom': 578, 'wTo': 578, 'chunk': 0},
#    {'wFrom': 704, 'wTo': 704, 'chunk': 0},
#    {'wFrom': 848, 'wTo': 848, 'chunk': 0},
#    {'wFrom': 891, 'wTo': 891, 'chunk': 0},
#    {'wFrom': 910, 'wTo': 910, 'chunk': 0},
#    {'wFrom': 920, 'wTo': 920, 'chunk': 0},
#    {'wFrom': 943, 'wTo': 943, 'chunk': 0},
#    {'wFrom': 970, 'wTo': 970, 'chunk': 0},
#    {'wFrom': 980, 'wTo': 980, 'chunk': 0},
#    {'wFrom': 1005, 'wTo': 1005, 'chunk': 0},
#    {'wFrom': 1010, 'wTo': 1010, 'chunk': 0},
#    {'wFrom': 1015, 'wTo': 1015, 'chunk': 0},
#    {'wFrom': 1035, 'wTo': 1035, 'chunk': 0},
#    {'wFrom': 1050, 'wTo': 1050, 'chunk': 0},
#    {'wFrom': 1100, 'wTo': 1100, 'chunk': 0},
#    {'wFrom': 1120, 'wTo': 1120, 'chunk': 0},
#    {'wFrom': 1151, 'wTo': 1151, 'chunk': 0},
#    {'wFrom': 1253, 'wTo': 1253, 'chunk': 0},
#    {'wFrom': 1362, 'wTo': 1362, 'chunk': 0},
#    {'wFrom': 1407, 'wTo': 1407, 'chunk': 0},
#    {'wFrom': 1582, 'wTo': 1582, 'chunk': 0},
#    {'wFrom': 1655, 'wTo': 1655, 'chunk': 0},
#    {'wFrom': 1694, 'wTo': 1694, 'chunk': 0},
#    {'wFrom': 1816, 'wTo': 1816, 'chunk': 0}],
#   'wikiDataItemId': 'Q178813',
#   'wikiDataClasses': [{'itemId': 'Q17431399', 'enLabel': 'national museum'},
#    {'itemId': 'Q839954', 'enLabel': 'archaeological site'},
#    {'itemId': 'Q33506', 'enLabel': 'museum'},
#    {'itemId': 'Q1291195', 'enLabel': 'find spot'},
#    {'itemId': 'Q15642541', 'enLabel': 'human-geographic territorial entity'},
#    {'itemId': 'Q14524493', 'enLabel': 'terrain'},
#    {'itemId': 'Q1030034', 'enLabel': 'GLAM'},
#    {'itemId': 'Q13226383', 'enLabel': 'facility'},
#    {'itemId': 'Q5193377', 'enLabel': 'cultural institution'},
#    {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#    {'itemId': 'Q1496967', 'enLabel': 'territorial entity'},
#    {'itemId': 'Q16686448', 'enLabel': 'artificial entity'},
#    {'itemId': 'Q271669', 'enLabel': 'landform'},
#    {'itemId': 'Q2221906', 'enLabel': 'geographic location'},
#    {'itemId': 'Q178706', 'enLabel': 'institution'},
#    {'itemId': 'Q223557', 'enLabel': 'physical object'},
#    {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#    {'itemId': 'Q82794', 'enLabel': 'geographic region'},
#    {'itemId': 'Q35120', 'enLabel': 'entity'},
#    {'itemId': 'Q12766313', 'enLabel': 'geomorphological unit'},
#    {'itemId': 'Q17334923', 'enLabel': 'location'},
#    {'itemId': 'Q43229', 'enLabel': 'organization'},
#    {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#    {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#    {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#    {'itemId': 'Q24229398', 'enLabel': 'agent'},
#    {'itemId': 'Q16334295', 'enLabel': 'group of humans'},
#    {'itemId': 'Q16513015', 'enLabel': 'order'},
#    {'itemId': 'Q488383', 'enLabel': 'object'},
#    {'itemId': 'Q58778', 'enLabel': 'system'},
#    {'itemId': 'Q30060700', 'enLabel': 'object of science'},
#    {'itemId': 'Q23958946', 'enLabel': 'individual'},
#    {'itemId': 'Q1789452', 'enLabel': 'criterion'},
#    {'itemId': 'Q16334298', 'enLabel': 'living thing group'},
#    {'itemId': 'Q3505845', 'enLabel': 'state'},
#    {'itemId': 'Q6671777', 'enLabel': 'structure'},
#    {'itemId': 'Q1921834', 'enLabel': 'feature'},
#    {'itemId': 'Q16887380', 'enLabel': 'group'},
#    {'itemId': 'Q517966', 'enLabel': 'structure'},
#    {'itemId': 'Q937228', 'enLabel': 'property'},
#    {'itemId': 'Q483247', 'enLabel': 'phenomenon'},
#    {'itemId': 'Q17553950', 'enLabel': 'object'},
#    {'itemId': 'Q714737', 'enLabel': 'category of being'},
#    {'itemId': 'Q1207505', 'enLabel': 'quality'},
#    {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#    {'itemId': 'Q16722960', 'enLabel': 'phenomenon'},
#    {'itemId': 'Q151885', 'enLabel': 'concept'},
#    {'itemId': 'Q26907166', 'enLabel': 'temporal entity'},
#    {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#    {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#    {'itemId': 'Q4393498', 'enLabel': 'representation'}],
#   'wikiDataClassIds': ['Q17431399',
#    'Q839954',
#    'Q33506',
#    'Q1291195',
#    'Q15642541',
#    'Q14524493',
#    'Q1030034',
#    'Q13226383',
#    'Q5193377',
#    'Q618123',
#    'Q1496967',
#    'Q16686448',
#    'Q271669',
#    'Q2221906',
#    'Q178706',
#    'Q223557',
#    'Q58416391',
#    'Q82794',
#    'Q35120',
#    'Q12766313',
#    'Q17334923',
#    'Q43229',
#    'Q4406616',
#    'Q1454986',
#    'Q58415929',
#    'Q24229398',
#    'Q16334295',
#    'Q16513015',
#    'Q488383',
#    'Q58778',
#    'Q30060700',
#    'Q23958946',
#    'Q1789452',
#    'Q16334298',
#    'Q3505845',
#    'Q6671777',
#    'Q1921834',
#    'Q16887380',
#    'Q517966',
#    'Q937228',
#    'Q483247',
#    'Q17553950',
#    'Q714737',
#    'Q1207505',
#    'Q1190554',
#    'Q16722960',
#    'Q151885',
#    'Q26907166',
#    'Q7184903',
#    'Q2145290',
#    'Q4393498'],
#   'dbPediaTypes': ['Place', 'WorldHeritageSite'],
#   'dbPediaIri': 'http://dbpedia.org/resource/Herculaneum'},
#  {'title': 'Pompeii',
#   'url': 'http://en.wikipedia.org/wiki/Pompeii',
#   'pageRank': 0.018291090534386135,
#   'cosine': 0.5094460836140102,
#   'lang': 'en',
#   'support': [{'wFrom': 175, 'wTo': 175, 'chunk': 0},
#    {'wFrom': 190, 'wTo': 190, 'chunk': 0},
#    {'wFrom': 203, 'wTo': 203, 'chunk': 0},
#    {'wFrom': 209, 'wTo': 209, 'chunk': 0},
#    {'wFrom': 240, 'wTo': 240, 'chunk': 0},
#    {'wFrom': 336, 'wTo': 336, 'chunk': 0},
#    {'wFrom': 368, 'wTo': 368, 'chunk': 0},
#    {'wFrom': 433, 'wTo': 433, 'chunk': 0},
#    {'wFrom': 584, 'wTo': 584, 'chunk': 0},
#    {'wFrom': 901, 'wTo': 901, 'chunk': 0},
#    {'wFrom': 997, 'wTo': 997, 'chunk': 0},
#    {'wFrom': 1028, 'wTo': 1028, 'chunk': 0},
#    {'wFrom': 1073, 'wTo': 1073, 'chunk': 0},
#    {'wFrom': 1140, 'wTo': 1140, 'chunk': 0},
#    {'wFrom': 1190, 'wTo': 1190, 'chunk': 0},
#    {'wFrom': 1358, 'wTo': 1358, 'chunk': 0},
#    {'wFrom': 1400, 'wTo': 1400, 'chunk': 0},
#    {'wFrom': 1624, 'wTo': 1624, 'chunk': 0},
#    {'wFrom': 1736, 'wTo': 1736, 'chunk': 0},
#    {'wFrom': 1845, 'wTo': 1845, 'chunk': 0},
#    {'wFrom': 1850, 'wTo': 1850, 'chunk': 0}],
#   'wikiDataItemId': 'Q43332',
#   'wikiDataClasses': [{'itemId': 'Q15661340', 'enLabel': 'ancient city'},
#    {'itemId': 'Q839954', 'enLabel': 'archaeological site'},
#    {'itemId': 'Q17431399', 'enLabel': 'national museum'},
#    {'itemId': 'Q2974842', 'enLabel': 'lost city'},
#    {'itemId': 'Q1291195', 'enLabel': 'find spot'},
#    {'itemId': 'Q15642541', 'enLabel': 'human-geographic territorial entity'},
#    {'itemId': 'Q14524493', 'enLabel': 'terrain'},
#    {'itemId': 'Q33506', 'enLabel': 'museum'},
#    {'itemId': 'Q74047', 'enLabel': 'ghost town'},
#    {'itemId': 'Q515', 'enLabel': 'city'},
#    {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#    {'itemId': 'Q1496967', 'enLabel': 'territorial entity'},
#    {'itemId': 'Q16686448', 'enLabel': 'artificial entity'},
#    {'itemId': 'Q271669', 'enLabel': 'landform'},
#    {'itemId': 'Q1030034', 'enLabel': 'GLAM'},
#    {'itemId': 'Q13226383', 'enLabel': 'facility'},
#    {'itemId': 'Q5193377', 'enLabel': 'cultural institution'},
#    {'itemId': 'Q22674925', 'enLabel': 'former populated place'},
#    {'itemId': 'Q486972', 'enLabel': 'human settlement'},
#    {'itemId': 'Q177634', 'enLabel': 'community'},
#    {'itemId': 'Q7930989', 'enLabel': 'city/town'},
#    {'itemId': 'Q702492', 'enLabel': 'urban area'},
#    {'itemId': 'Q223557', 'enLabel': 'physical object'},
#    {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#    {'itemId': 'Q82794', 'enLabel': 'geographic region'},
#    {'itemId': 'Q35120', 'enLabel': 'entity'},
#    {'itemId': 'Q12766313', 'enLabel': 'geomorphological unit'},
#    {'itemId': 'Q2221906', 'enLabel': 'geographic location'},
#    {'itemId': 'Q178706', 'enLabel': 'institution'},
#    {'itemId': 'Q15893266', 'enLabel': 'former entity'},
#    {'itemId': 'Q874405', 'enLabel': 'social group'},
#    {'itemId': 'Q16334295', 'enLabel': 'group of humans'},
#    {'itemId': 'Q15042037', 'enLabel': 'statistical territorial entity'},
#    {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#    {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#    {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#    {'itemId': 'Q17334923', 'enLabel': 'location'},
#    {'itemId': 'Q43229', 'enLabel': 'organization'},
#    {'itemId': 'Q19829125', 'enLabel': 'absence'},
#    {'itemId': 'Q58778', 'enLabel': 'system'},
#    {'itemId': 'Q7887142', 'enLabel': 'unit of analysis'},
#    {'itemId': 'Q16334298', 'enLabel': 'living thing group'},
#    {'itemId': 'Q488383', 'enLabel': 'object'},
#    {'itemId': 'Q30060700', 'enLabel': 'object of science'},
#    {'itemId': 'Q24229398', 'enLabel': 'agent'},
#    {'itemId': 'Q16513015', 'enLabel': 'order'},
#    {'itemId': 'Q16889133', 'enLabel': 'class'},
#    {'itemId': 'Q6671777', 'enLabel': 'structure'},
#    {'itemId': 'Q4330518', 'enLabel': 'research object'},
#    {'itemId': 'Q2198779', 'enLabel': 'unit'},
#    {'itemId': 'Q16887380', 'enLabel': 'group'},
#    {'itemId': 'Q517966', 'enLabel': 'structure'},
#    {'itemId': 'Q23958946', 'enLabel': 'individual'},
#    {'itemId': 'Q1789452', 'enLabel': 'criterion'},
#    {'itemId': 'Q3505845', 'enLabel': 'state'},
#    {'itemId': 'Q5127848', 'enLabel': 'class'},
#    {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#    {'itemId': 'Q17553950', 'enLabel': 'object'},
#    {'itemId': 'Q1921834', 'enLabel': 'feature'},
#    {'itemId': 'Q937228', 'enLabel': 'property'},
#    {'itemId': 'Q483247', 'enLabel': 'phenomenon'},
#    {'itemId': 'Q714737', 'enLabel': 'category of being'},
#    {'itemId': 'Q1207505', 'enLabel': 'quality'},
#    {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#    {'itemId': 'Q16722960', 'enLabel': 'phenomenon'},
#    {'itemId': 'Q151885', 'enLabel': 'concept'},
#    {'itemId': 'Q26907166', 'enLabel': 'temporal entity'},
#    {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#    {'itemId': 'Q4393498', 'enLabel': 'representation'}],
#   'wikiDataClassIds': ['Q15661340',
#    'Q839954',
#    'Q17431399',
#    'Q2974842',
#    'Q1291195',
#    'Q15642541',
#    'Q14524493',
#    'Q33506',
#    'Q74047',
#    'Q515',
#    'Q618123',
#    'Q1496967',
#    'Q16686448',
#    'Q271669',
#    'Q1030034',
#    'Q13226383',
#    'Q5193377',
#    'Q22674925',
#    'Q486972',
#    'Q177634',
#    'Q7930989',
#    'Q702492',
#    'Q223557',
#    'Q58416391',
#    'Q82794',
#    'Q35120',
#    'Q12766313',
#    'Q2221906',
#    'Q178706',
#    'Q15893266',
#    'Q874405',
#    'Q16334295',
#    'Q15042037',
#    'Q4406616',
#    'Q1454986',
#    'Q58415929',
#    'Q17334923',
#    'Q43229',
#    'Q19829125',
#    'Q58778',
#    'Q7887142',
#    'Q16334298',
#    'Q488383',
#    'Q30060700',
#    'Q24229398',
#    'Q16513015',
#    'Q16889133',
#    'Q6671777',
#    'Q4330518',
#    'Q2198779',
#    'Q16887380',
#    'Q517966',
#    'Q23958946',
#    'Q1789452',
#    'Q3505845',
#    'Q5127848',
#    'Q7184903',
#    'Q17553950',
#    'Q1921834',
#    'Q937228',
#    'Q483247',
#    'Q714737',
#    'Q1207505',
#    'Q1190554',
#    'Q16722960',
#    'Q151885',
#    'Q26907166',
#    'Q2145290',
#    'Q4393498'],
#   'dbPediaTypes': ['Place', 'WorldHeritageSite'],
#   'dbPediaIri': 'http://dbpedia.org/resource/Pompeii'},
#  {'title': 'Samnites',
#   'url': 'http://en.wikipedia.org/wiki/Samnites',
#   'pageRank': 0.0038154357845719433,
#   'cosine': 0.14869798909851106,
#   'lang': 'en',
#   'support': [{'wFrom': 963, 'wTo': 963, 'chunk': 0},
#    {'wFrom': 967, 'wTo': 967, 'chunk': 0},
#    {'wFrom': 977, 'wTo': 977, 'chunk': 0}],
#   'wikiDataItemId': 'Q500272',
#   'wikiDataClasses': [{'itemId': 'Q2472587', 'enLabel': 'people'},
#    {'itemId': 'Q874405', 'enLabel': 'social group'},
#    {'itemId': 'Q16334295', 'enLabel': 'group of humans'},
#    {'itemId': 'Q58778', 'enLabel': 'system'},
#    {'itemId': 'Q7887142', 'enLabel': 'unit of analysis'},
#    {'itemId': 'Q16334298', 'enLabel': 'living thing group'},
#    {'itemId': 'Q6671777', 'enLabel': 'structure'},
#    {'itemId': 'Q4330518', 'enLabel': 'research object'},
#    {'itemId': 'Q2198779', 'enLabel': 'unit'},
#    {'itemId': 'Q16887380', 'enLabel': 'group'},
#    {'itemId': 'Q517966', 'enLabel': 'structure'},
#    {'itemId': 'Q35120', 'enLabel': 'entity'},
#    {'itemId': 'Q488383', 'enLabel': 'object'},
#    {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#    {'itemId': 'Q17553950', 'enLabel': 'object'},
#    {'itemId': 'Q4406616', 'enLabel': 'concrete object'}],
#   'wikiDataClassIds': ['Q2472587',
#    'Q874405',
#    'Q16334295',
#    'Q58778',
#    'Q7887142',
#    'Q16334298',
#    'Q6671777',
#    'Q4330518',
#    'Q2198779',
#    'Q16887380',
#    'Q517966',
#    'Q35120',
#    'Q488383',
#    'Q7184903',
#    'Q17553950',
#    'Q4406616'],
#   'dbPediaTypes': ['PopulatedPlace', 'Place'],
#   'dbPediaIri': 'http://dbpedia.org/resource/Sabellians'},
#  {'title': 'Lava',
#   'url': 'http://en.wikipedia.org/wiki/Lava',
#   'pageRank': 0.003630996714491836,
#   'cosine': 0.20049486484197385,
#   'lang': 'en',
#   'support': [{'wFrom': 1159, 'wTo': 1159, 'chunk': 0},
#    {'wFrom': 1180, 'wTo': 1180, 'chunk': 0},
#    {'wFrom': 1204, 'wTo': 1204, 'chunk': 0},
#    {'wFrom': 1277, 'wTo': 1277, 'chunk': 0},
#    {'wFrom': 1331, 'wTo': 1331, 'chunk': 0},
#    {'wFrom': 1438, 'wTo': 1438, 'chunk': 0},
#    {'wFrom': 1812, 'wTo': 1812, 'chunk': 0}],
#   'wikiDataItemId': 'Q40157',
#   'wikiDataClasses': [],
#   'wikiDataClassIds': [],
#   'dbPediaTypes': ['Agent', 'Organisation', 'Company', 'RecordLabel'],
#   'dbPediaIri': 'http://dbpedia.org/resource/Lava'},
#  {'title': 'Mount Vesuvius',
#   'url': 'http://en.wikipedia.org/wiki/Mount_Vesuvius',
#   'pageRank': 0.003344867537362839,
#   'cosine': 0.3625857514945056,
#   'lang': 'en',
#   'support': [{'wFrom': 538, 'wTo': 540, 'chunk': 0},
#    {'wFrom': 540, 'wTo': 540, 'chunk': 0},
#    {'wFrom': 1161, 'wTo': 1161, 'chunk': 0},
#    {'wFrom': 1323, 'wTo': 1323, 'chunk': 0},
#    {'wFrom': 1659, 'wTo': 1659, 'chunk': 0}],
#   'wikiDataItemId': 'Q524',
#   'wikiDataClasses': [{'itemId': 'Q1330974', 'enLabel': 'active volcano'},
#    {'itemId': 'Q169358', 'enLabel': 'stratovolcano'},
#    {'itemId': 'Q8072', 'enLabel': 'volcano'},
#    {'itemId': 'Q8502', 'enLabel': 'mountain'},
#    {'itemId': 'Q29025902', 'enLabel': 'volcanic landform'},
#    {'itemId': 'Q14524493', 'enLabel': 'terrain'},
#    {'itemId': 'Q207326', 'enLabel': 'summit'},
#    {'itemId': 'Q35145263', 'enLabel': 'natural geographic object'},
#    {'itemId': 'Q271669', 'enLabel': 'landform'},
#    {'itemId': 'Q2221906', 'enLabel': 'geographic location'},
#    {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#    {'itemId': 'Q16686022', 'enLabel': 'natural physical object'},
#    {'itemId': 'Q12766313', 'enLabel': 'geomorphological unit'},
#    {'itemId': 'Q17334923', 'enLabel': 'location'},
#    {'itemId': 'Q223557', 'enLabel': 'physical object'},
#    {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#    {'itemId': 'Q29651224', 'enLabel': 'natural object'},
#    {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#    {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#    {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#    {'itemId': 'Q488383', 'enLabel': 'object'},
#    {'itemId': 'Q1322005', 'enLabel': 'natural phenomenon'},
#    {'itemId': 'Q58778', 'enLabel': 'system'},
#    {'itemId': 'Q30060700', 'enLabel': 'object of science'},
#    {'itemId': 'Q35120', 'enLabel': 'entity'},
#    {'itemId': 'Q483247', 'enLabel': 'phenomenon'},
#    {'itemId': 'Q6671777', 'enLabel': 'structure'},
#    {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#    {'itemId': 'Q16722960', 'enLabel': 'phenomenon'},
#    {'itemId': 'Q26907166', 'enLabel': 'temporal entity'}],
#   'wikiDataClassIds': ['Q1330974',
#    'Q169358',
#    'Q8072',
#    'Q8502',
#    'Q29025902',
#    'Q14524493',
#    'Q207326',
#    'Q35145263',
#    'Q271669',
#    'Q2221906',
#    'Q618123',
#    'Q16686022',
#    'Q12766313',
#    'Q17334923',
#    'Q223557',
#    'Q58416391',
#    'Q29651224',
#    'Q4406616',
#    'Q1454986',
#    'Q58415929',
#    'Q488383',
#    'Q1322005',
#    'Q58778',
#    'Q30060700',
#    'Q35120',
#    'Q483247',
#    'Q6671777',
#    'Q1190554',
#    'Q16722960',
#    'Q26907166'],
#   'dbPediaTypes': ['Place', 'Mountain', 'NaturalPlace', 'Volcano'],
#   'dbPediaIri': 'http://dbpedia.org/resource/Mount_Vesuvius'},
#  {'title': 'Ancient Rome',
#   'url': 'http://en.wikipedia.org/wiki/Ancient_Rome',
#   'pageRank': 0.0031142185561927574,
#   'cosine': 0.2999609464376098,
#   'lang': 'en',
#   'support': [{'wFrom': 28, 'wTo': 28, 'chunk': 0},
#    {'wFrom': 81, 'wTo': 81, 'chunk': 0},
#    {'wFrom': 92, 'wTo': 92, 'chunk': 0},
#    {'wFrom': 562, 'wTo': 562, 'chunk': 0},
#    {'wFrom': 619, 'wTo': 619, 'chunk': 0},
#    {'wFrom': 784, 'wTo': 784, 'chunk': 0},
#    {'wFrom': 864, 'wTo': 864, 'chunk': 0},
#    {'wFrom': 1039, 'wTo': 1039, 'chunk': 0},
#    {'wFrom': 1053, 'wTo': 1053, 'chunk': 0},
#    {'wFrom': 1053, 'wTo': 1054, 'chunk': 0},
#    {'wFrom': 1075, 'wTo': 1076, 'chunk': 0},
#    {'wFrom': 1076, 'wTo': 1076, 'chunk': 0},
#    {'wFrom': 1083, 'wTo': 1083, 'chunk': 0},
#    {'wFrom': 1632, 'wTo': 1632, 'chunk': 0}],
#   'wikiDataItemId': 'Q1747689',
#   'wikiDataClasses': [{'itemId': 'Q1620908', 'enLabel': 'historical region'},
#    {'itemId': 'Q3502482', 'enLabel': 'cultural region'},
#    {'itemId': 'Q28171280', 'enLabel': 'ancient civilization'},
#    {'itemId': 'Q3024240', 'enLabel': 'historical country'},
#    {'itemId': 'Q82794', 'enLabel': 'geographic region'},
#    {'itemId': 'Q15893266', 'enLabel': 'former entity'},
#    {'itemId': 'Q15642541', 'enLabel': 'human-geographic territorial entity'},
#    {'itemId': 'Q8432', 'enLabel': 'civilization'},
#    {'itemId': 'Q19953632',
#     'enLabel': 'former administrative territorial entity'},
#    {'itemId': 'Q6256', 'enLabel': 'country'},
#    {'itemId': 'Q7275', 'enLabel': 'state'},
#    {'itemId': 'Q2221906', 'enLabel': 'geographic location'},
#    {'itemId': 'Q35120', 'enLabel': 'entity'},
#    {'itemId': 'Q19829125', 'enLabel': 'absence'},
#    {'itemId': 'Q1496967', 'enLabel': 'territorial entity'},
#    {'itemId': 'Q16686448', 'enLabel': 'artificial entity'},
#    {'itemId': 'Q8425', 'enLabel': 'society'},
#    {'itemId': 'Q56061', 'enLabel': 'administrative territorial entity'},
#    {'itemId': 'Q19832712', 'enLabel': 'historical administrative division'},
#    {'itemId': 'Q1048835', 'enLabel': 'political territorial entity'},
#    {'itemId': 'Q43229', 'enLabel': 'organization'},
#    {'itemId': 'Q177634', 'enLabel': 'community'},
#    {'itemId': 'Q155076', 'enLabel': 'juridical person'},
#    {'itemId': 'Q17334923', 'enLabel': 'location'},
#    {'itemId': 'Q16889133', 'enLabel': 'class'},
#    {'itemId': 'Q874405', 'enLabel': 'social group'},
#    {'itemId': 'Q4204519', 'enLabel': 'historical fact'},
#    {'itemId': 'Q24229398', 'enLabel': 'agent'},
#    {'itemId': 'Q16334295', 'enLabel': 'group of humans'},
#    {'itemId': 'Q16513015', 'enLabel': 'order'},
#    {'itemId': 'Q3778211', 'enLabel': 'legal person'},
#    {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#    {'itemId': 'Q5127848', 'enLabel': 'class'},
#    {'itemId': 'Q58778', 'enLabel': 'system'},
#    {'itemId': 'Q7887142', 'enLabel': 'unit of analysis'},
#    {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#    {'itemId': 'Q188572', 'enLabel': 'fact'},
#    {'itemId': 'Q192630', 'enLabel': 'past'},
#    {'itemId': 'Q23958946', 'enLabel': 'individual'},
#    {'itemId': 'Q1789452', 'enLabel': 'criterion'},
#    {'itemId': 'Q16334298', 'enLabel': 'living thing group'},
#    {'itemId': 'Q3505845', 'enLabel': 'state'},
#    {'itemId': 'Q830077', 'enLabel': 'subject'},
#    {'itemId': 'Q223557', 'enLabel': 'physical object'},
#    {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#    {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#    {'itemId': 'Q6671777', 'enLabel': 'structure'},
#    {'itemId': 'Q4330518', 'enLabel': 'research object'},
#    {'itemId': 'Q2198779', 'enLabel': 'unit'},
#    {'itemId': 'Q26907166', 'enLabel': 'temporal entity'},
#    {'itemId': 'Q42848', 'enLabel': 'data'},
#    {'itemId': 'Q2684591', 'enLabel': 'statement'},
#    {'itemId': 'Q11471', 'enLabel': 'time'},
#    {'itemId': 'Q1921834', 'enLabel': 'feature'},
#    {'itemId': 'Q16887380', 'enLabel': 'group'},
#    {'itemId': 'Q517966', 'enLabel': 'structure'},
#    {'itemId': 'Q937228', 'enLabel': 'property'},
#    {'itemId': 'Q483247', 'enLabel': 'phenomenon'},
#    {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#    {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#    {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#    {'itemId': 'Q488383', 'enLabel': 'object'},
#    {'itemId': 'Q11028', 'enLabel': 'information'},
#    {'itemId': 'Q108163', 'enLabel': 'proposition'},
#    {'itemId': 'Q20937557', 'enLabel': 'series'},
#    {'itemId': 'Q17553950', 'enLabel': 'object'},
#    {'itemId': 'Q714737', 'enLabel': 'category of being'},
#    {'itemId': 'Q1207505', 'enLabel': 'quality'},
#    {'itemId': 'Q16722960', 'enLabel': 'phenomenon'},
#    {'itemId': 'Q30060700', 'enLabel': 'object of science'},
#    {'itemId': 'Q41796', 'enLabel': 'sentence'},
#    {'itemId': 'Q246672', 'enLabel': 'mathematical object'},
#    {'itemId': 'Q151885', 'enLabel': 'concept'},
#    {'itemId': 'Q1786828', 'enLabel': 'constituent'},
#    {'itemId': 'Q15916540', 'enLabel': 'semantic unit'},
#    {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#    {'itemId': 'Q5371079', 'enLabel': 'emic unit'},
#    {'itemId': 'Q183046', 'enLabel': 'meaning'},
#    {'itemId': 'Q4393498', 'enLabel': 'representation'},
#    {'itemId': 'Q20817253', 'enLabel': 'linguistic unit'},
#    {'itemId': 'Q16877783', 'enLabel': 'meaning'},
#    {'itemId': 'Q4173967', 'enLabel': 'language unit'},
#    {'itemId': 'Q29651519', 'enLabel': 'mental object'}],
#   'wikiDataClassIds': ['Q1620908',
#    'Q3502482',
#    'Q28171280',
#    'Q3024240',
#    'Q82794',
#    'Q15893266',
#    'Q15642541',
#    'Q8432',
#    'Q19953632',
#    'Q6256',
#    'Q7275',
#    'Q2221906',
#    'Q35120',
#    'Q19829125',
#    'Q1496967',
#    'Q16686448',
#    'Q8425',
#    'Q56061',
#    'Q19832712',
#    'Q1048835',
#    'Q43229',
#    'Q177634',
#    'Q155076',
#    'Q17334923',
#    'Q16889133',
#    'Q874405',
#    'Q4204519',
#    'Q24229398',
#    'Q16334295',
#    'Q16513015',
#    'Q3778211',
#    'Q618123',
#    'Q5127848',
#    'Q58778',
#    'Q7887142',
#    'Q1190554',
#    'Q188572',
#    'Q192630',
#    'Q23958946',
#    'Q1789452',
#    'Q16334298',
#    'Q3505845',
#    'Q830077',
#    'Q223557',
#    'Q58416391',
#    'Q7184903',
#    'Q6671777',
#    'Q4330518',
#    'Q2198779',
#    'Q26907166',
#    'Q42848',
#    'Q2684591',
#    'Q11471',
#    'Q1921834',
#    'Q16887380',
#    'Q517966',
#    'Q937228',
#    'Q483247',
#    'Q4406616',
#    'Q1454986',
#    'Q58415929',
#    'Q488383',
#    'Q11028',
#    'Q108163',
#    'Q20937557',
#    'Q17553950',
#    'Q714737',
#    'Q1207505',
#    'Q16722960',
#    'Q30060700',
#    'Q41796',
#    'Q246672',
#    'Q151885',
#    'Q1786828',
#    'Q15916540',
#    'Q2145290',
#    'Q5371079',
#    'Q183046',
#    'Q4393498',
#    'Q20817253',
#    'Q16877783',
#    'Q4173967',
#    'Q29651519'],
#   'dbPediaTypes': ['PopulatedPlace',
#    'Place',
#    'Country',
#    'Territory',
#    'OldTerritory'],
#   'dbPediaIri': 'http://dbpedia.org/resource/Ancient_Rome'},
#  {'title': 'Boscoreale',
#   'url': 'http://en.wikipedia.org/wiki/Boscoreale',
#   'pageRank': 0.003113899583083107,
#   'cosine': 0.24575084340794787,
#   'lang': 'en',
#   'support': [{'wFrom': 223, 'wTo': 223, 'chunk': 0},
#    {'wFrom': 225, 'wTo': 225, 'chunk': 0},
#    {'wFrom': 275, 'wTo': 275, 'chunk': 0}],
#   'wikiDataItemId': 'Q71845',
#   'wikiDataClasses': [{'itemId': 'Q747074', 'enLabel': 'comune of Italy'},
#    {'itemId': 'Q13221722',
#     'enLabel': 'third-level administrative country subdivision'},
#    {'itemId': 'Q2824645',
#     'enLabel': 'administrative territorial entity of Italy'},
#    {'itemId': 'Q15284', 'enLabel': 'municipality'},
#    {'itemId': 'Q1799794',
#     'enLabel': 'administrative territorial entity of a specific level'},
#    {'itemId': 'Q15916867',
#     'enLabel': 'administrative territorial entity of a single country'},
#    {'itemId': 'Q1048835', 'enLabel': 'political territorial entity'},
#    {'itemId': 'Q2097994', 'enLabel': 'municipal corporation'},
#    {'itemId': 'Q486972', 'enLabel': 'human settlement'},
#    {'itemId': 'Q56061', 'enLabel': 'administrative territorial entity'},
#    {'itemId': 'Q15642541', 'enLabel': 'human-geographic territorial entity'},
#    {'itemId': 'Q6501447', 'enLabel': 'local government'},
#    {'itemId': 'Q82794', 'enLabel': 'geographic region'},
#    {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#    {'itemId': 'Q177634', 'enLabel': 'community'},
#    {'itemId': 'Q1496967', 'enLabel': 'territorial entity'},
#    {'itemId': 'Q16686448', 'enLabel': 'artificial entity'},
#    {'itemId': 'Q7188', 'enLabel': 'government'},
#    {'itemId': 'Q43229', 'enLabel': 'organization'},
#    {'itemId': 'Q2221906', 'enLabel': 'geographic location'},
#    {'itemId': 'Q223557', 'enLabel': 'physical object'},
#    {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#    {'itemId': 'Q874405', 'enLabel': 'social group'},
#    {'itemId': 'Q16334295', 'enLabel': 'group of humans'},
#    {'itemId': 'Q35120', 'enLabel': 'entity'},
#    {'itemId': 'Q7210356', 'enLabel': 'political organisation'},
#    {'itemId': 'Q895526', 'enLabel': 'organ'},
#    {'itemId': 'Q35798', 'enLabel': 'executive branch'},
#    {'itemId': 'Q24229398', 'enLabel': 'agent'},
#    {'itemId': 'Q16513015', 'enLabel': 'order'},
#    {'itemId': 'Q17334923', 'enLabel': 'location'},
#    {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#    {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#    {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#    {'itemId': 'Q58778', 'enLabel': 'system'},
#    {'itemId': 'Q7887142', 'enLabel': 'unit of analysis'},
#    {'itemId': 'Q16334298', 'enLabel': 'living thing group'},
#    {'itemId': 'Q174834', 'enLabel': 'authority'},
#    {'itemId': 'Q2101636', 'enLabel': 'political power'},
#    {'itemId': 'Q15708736', 'enLabel': 'public authority'},
#    {'itemId': 'Q2324993', 'enLabel': 'state power'},
#    {'itemId': 'Q23958946', 'enLabel': 'individual'},
#    {'itemId': 'Q1789452', 'enLabel': 'criterion'},
#    {'itemId': 'Q3505845', 'enLabel': 'state'},
#    {'itemId': 'Q488383', 'enLabel': 'object'},
#    {'itemId': 'Q30060700', 'enLabel': 'object of science'},
#    {'itemId': 'Q6671777', 'enLabel': 'structure'},
#    {'itemId': 'Q4330518', 'enLabel': 'research object'},
#    {'itemId': 'Q2198779', 'enLabel': 'unit'},
#    {'itemId': 'Q16887380', 'enLabel': 'group'},
#    {'itemId': 'Q517966', 'enLabel': 'structure'},
#    {'itemId': 'Q25107', 'enLabel': 'power'},
#    {'itemId': 'Q2659904', 'enLabel': 'government organization'},
#    {'itemId': 'Q1125239', 'enLabel': 'public body'},
#    {'itemId': 'Q1921834', 'enLabel': 'feature'},
#    {'itemId': 'Q937228', 'enLabel': 'property'},
#    {'itemId': 'Q483247', 'enLabel': 'phenomenon'},
#    {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#    {'itemId': 'Q17553950', 'enLabel': 'object'},
#    {'itemId': 'Q18340964', 'enLabel': 'power'},
#    {'itemId': 'Q714737', 'enLabel': 'category of being'},
#    {'itemId': 'Q1207505', 'enLabel': 'quality'},
#    {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#    {'itemId': 'Q16722960', 'enLabel': 'phenomenon'},
#    {'itemId': 'Q151885', 'enLabel': 'concept'},
#    {'itemId': 'Q26907166', 'enLabel': 'temporal entity'},
#    {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#    {'itemId': 'Q4393498', 'enLabel': 'representation'}],
#   'wikiDataClassIds': ['Q747074',
#    'Q13221722',
#    'Q2824645',
#    'Q15284',
#    'Q1799794',
#    'Q15916867',
#    'Q1048835',
#    'Q2097994',
#    'Q486972',
#    'Q56061',
#    'Q15642541',
#    'Q6501447',
#    'Q82794',
#    'Q618123',
#    'Q177634',
#    'Q1496967',
#    'Q16686448',
#    'Q7188',
#    'Q43229',
#    'Q2221906',
#    'Q223557',
#    'Q58416391',
#    'Q874405',
#    'Q16334295',
#    'Q35120',
#    'Q7210356',
#    'Q895526',
#    'Q35798',
#    'Q24229398',
#    'Q16513015',
#    'Q17334923',
#    'Q4406616',
#    'Q1454986',
#    'Q58415929',
#    'Q58778',
#    'Q7887142',
#    'Q16334298',
#    'Q174834',
#    'Q2101636',
#    'Q15708736',
#    'Q2324993',
#    'Q23958946',
#    'Q1789452',
#    'Q3505845',
#    'Q488383',
#    'Q30060700',
#    'Q6671777',
#    'Q4330518',
#    'Q2198779',
#    'Q16887380',
#    'Q517966',
#    'Q25107',
#    'Q2659904',
#    'Q1125239',
#    'Q1921834',
#    'Q937228',
#    'Q483247',
#    'Q7184903',
#    'Q17553950',
#    'Q18340964',
#    'Q714737',
#    'Q1207505',
#    'Q1190554',
#    'Q16722960',
#    'Q151885',
#    'Q26907166',
#    'Q2145290',
#    'Q4393498'],
#   'dbPediaTypes': ['City',
#    'Settlement',
#    'PopulatedPlace',
#    'Place',
#    'AdministrativeRegion',
#    'Region'],
#   'dbPediaIri': 'http://dbpedia.org/resource/Boscoreale'},
#  {'title': 'Skeleton',
#   'url': 'http://en.wikipedia.org/wiki/Skeleton',
#   'pageRank': 0.0027404853711771584,
#   'cosine': 0.22432098003312076,
#   'lang': 'en',
#   'support': [{'wFrom': 1707, 'wTo': 1707, 'chunk': 0},
#    {'wFrom': 1716, 'wTo': 1716, 'chunk': 0},
#    {'wFrom': 1721, 'wTo': 1721, 'chunk': 0},
#    {'wFrom': 1783, 'wTo': 1783, 'chunk': 0},
#    {'wFrom': 1789, 'wTo': 1789, 'chunk': 0},
#    {'wFrom': 1837, 'wTo': 1837, 'chunk': 0},
#    {'wFrom': 52, 'wTo': 52, 'chunk': 1},
#    {'wFrom': 96, 'wTo': 96, 'chunk': 1}],
#   'wikiDataItemId': 'Q7881',
#   'wikiDataClasses': [],
#   'wikiDataClassIds': [],
#   'dbPediaTypes': [],
#   'dbPediaIri': 'http://dbpedia.org/resource/Skeleton'},
#  {'title': 'Campania',
#   'url': 'http://en.wikipedia.org/wiki/Campania',
#   'pageRank': 0.002653586789565017,
#   'cosine': 0.28352691499769916,
#   'lang': 'en',
#   'support': [{'wFrom': 55, 'wTo': 55, 'chunk': 0}],
#   'wikiDataItemId': 'Q1438',
#   'wikiDataClasses': [{'itemId': 'Q16110', 'enLabel': 'region of Italy'},
#    {'itemId': 'Q2824645',
#     'enLabel': 'administrative territorial entity of Italy'},
#    {'itemId': 'Q10864048',
#     'enLabel': 'first-level administrative country subdivision'},
#    {'itemId': 'Q1048835', 'enLabel': 'political territorial entity'},
#    {'itemId': 'Q3455524', 'enLabel': 'administrative region'},
#    {'itemId': 'Q15916867',
#     'enLabel': 'administrative territorial entity of a single country'},
#    {'itemId': 'Q1799794',
#     'enLabel': 'administrative territorial entity of a specific level'},
#    {'itemId': 'Q15642541', 'enLabel': 'human-geographic territorial entity'},
#    {'itemId': 'Q56061', 'enLabel': 'administrative territorial entity'},
#    {'itemId': 'Q1496967', 'enLabel': 'territorial entity'},
#    {'itemId': 'Q16686448', 'enLabel': 'artificial entity'},
#    {'itemId': 'Q82794', 'enLabel': 'geographic region'},
#    {'itemId': 'Q35120', 'enLabel': 'entity'},
#    {'itemId': 'Q2221906', 'enLabel': 'geographic location'},
#    {'itemId': 'Q17334923', 'enLabel': 'location'},
#    {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#    {'itemId': 'Q223557', 'enLabel': 'physical object'},
#    {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#    {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#    {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#    {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#    {'itemId': 'Q488383', 'enLabel': 'object'},
#    {'itemId': 'Q58778', 'enLabel': 'system'},
#    {'itemId': 'Q30060700', 'enLabel': 'object of science'},
#    {'itemId': 'Q6671777', 'enLabel': 'structure'}],
#   'wikiDataClassIds': ['Q16110',
#    'Q2824645',
#    'Q10864048',
#    'Q1048835',
#    'Q3455524',
#    'Q15916867',
#    'Q1799794',
#    'Q15642541',
#    'Q56061',
#    'Q1496967',
#    'Q16686448',
#    'Q82794',
#    'Q35120',
#    'Q2221906',
#    'Q17334923',
#    'Q618123',
#    'Q223557',
#    'Q58416391',
#    'Q4406616',
#    'Q1454986',
#    'Q58415929',
#    'Q488383',
#    'Q58778',
#    'Q30060700',
#    'Q6671777'],
#   'dbPediaTypes': ['PopulatedPlace',
#    'Place',
#    'AdministrativeRegion',
#    'Region'],
#   'dbPediaIri': 'http://dbpedia.org/resource/Campania'},
#  {'title': 'Naples',
#   'url': 'http://en.wikipedia.org/wiki/Naples',
#   'pageRank': 0.002491342969735601,
#   'cosine': 0.2410574134288819,
#   'lang': 'en',
#   'support': [{'wFrom': 207, 'wTo': 207, 'chunk': 0}],
#   'wikiDataItemId': 'Q2634',
#   'wikiDataClasses': [{'itemId': 'Q515', 'enLabel': 'city'},
#    {'itemId': 'Q747074', 'enLabel': 'comune of Italy'},
#    {'itemId': 'Q3024240', 'enLabel': 'historical country'},
#    {'itemId': 'Q1549591', 'enLabel': 'big city'},
#    {'itemId': 'Q486972', 'enLabel': 'human settlement'},
#    {'itemId': 'Q177634', 'enLabel': 'community'},
#    {'itemId': 'Q7930989', 'enLabel': 'city/town'},
#    {'itemId': 'Q702492', 'enLabel': 'urban area'},
#    {'itemId': 'Q13221722',
#     'enLabel': 'third-level administrative country subdivision'},
#    {'itemId': 'Q2824645',
#     'enLabel': 'administrative territorial entity of Italy'},
#    {'itemId': 'Q15284', 'enLabel': 'municipality'},
#    {'itemId': 'Q19953632',
#     'enLabel': 'former administrative territorial entity'},
#    {'itemId': 'Q6256', 'enLabel': 'country'},
#    {'itemId': 'Q7275', 'enLabel': 'state'},
#    {'itemId': 'Q82794', 'enLabel': 'geographic region'},
#    {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#    {'itemId': 'Q874405', 'enLabel': 'social group'},
#    {'itemId': 'Q16334295', 'enLabel': 'group of humans'},
#    {'itemId': 'Q15042037', 'enLabel': 'statistical territorial entity'},
#    {'itemId': 'Q1799794',
#     'enLabel': 'administrative territorial entity of a specific level'},
#    {'itemId': 'Q15916867',
#     'enLabel': 'administrative territorial entity of a single country'},
#    {'itemId': 'Q1048835', 'enLabel': 'political territorial entity'},
#    {'itemId': 'Q2097994', 'enLabel': 'municipal corporation'},
#    {'itemId': 'Q56061', 'enLabel': 'administrative territorial entity'},
#    {'itemId': 'Q15893266', 'enLabel': 'former entity'},
#    {'itemId': 'Q19832712', 'enLabel': 'historical administrative division'},
#    {'itemId': 'Q43229', 'enLabel': 'organization'},
#    {'itemId': 'Q155076', 'enLabel': 'juridical person'},
#    {'itemId': 'Q2221906', 'enLabel': 'geographic location'},
#    {'itemId': 'Q223557', 'enLabel': 'physical object'},
#    {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#    {'itemId': 'Q58778', 'enLabel': 'system'},
#    {'itemId': 'Q7887142', 'enLabel': 'unit of analysis'},
#    {'itemId': 'Q16334298', 'enLabel': 'living thing group'},
#    {'itemId': 'Q15642541', 'enLabel': 'human-geographic territorial entity'},
#    {'itemId': 'Q6501447', 'enLabel': 'local government'},
#    {'itemId': 'Q35120', 'enLabel': 'entity'},
#    {'itemId': 'Q19829125', 'enLabel': 'absence'},
#    {'itemId': 'Q4204519', 'enLabel': 'historical fact'},
#    {'itemId': 'Q24229398', 'enLabel': 'agent'},
#    {'itemId': 'Q16513015', 'enLabel': 'order'},
#    {'itemId': 'Q3778211', 'enLabel': 'legal person'},
#    {'itemId': 'Q17334923', 'enLabel': 'location'},
#    {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#    {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#    {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#    {'itemId': 'Q6671777', 'enLabel': 'structure'},
#    {'itemId': 'Q4330518', 'enLabel': 'research object'},
#    {'itemId': 'Q2198779', 'enLabel': 'unit'},
#    {'itemId': 'Q16887380', 'enLabel': 'group'},
#    {'itemId': 'Q517966', 'enLabel': 'structure'},
#    {'itemId': 'Q1496967', 'enLabel': 'territorial entity'},
#    {'itemId': 'Q16686448', 'enLabel': 'artificial entity'},
#    {'itemId': 'Q7188', 'enLabel': 'government'},
#    {'itemId': 'Q16889133', 'enLabel': 'class'},
#    {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#    {'itemId': 'Q188572', 'enLabel': 'fact'},
#    {'itemId': 'Q192630', 'enLabel': 'past'},
#    {'itemId': 'Q23958946', 'enLabel': 'individual'},
#    {'itemId': 'Q1789452', 'enLabel': 'criterion'},
#    {'itemId': 'Q3505845', 'enLabel': 'state'},
#    {'itemId': 'Q830077', 'enLabel': 'subject'},
#    {'itemId': 'Q488383', 'enLabel': 'object'},
#    {'itemId': 'Q30060700', 'enLabel': 'object of science'},
#    {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#    {'itemId': 'Q17553950', 'enLabel': 'object'},
#    {'itemId': 'Q7210356', 'enLabel': 'political organisation'},
#    {'itemId': 'Q895526', 'enLabel': 'organ'},
#    {'itemId': 'Q35798', 'enLabel': 'executive branch'},
#    {'itemId': 'Q5127848', 'enLabel': 'class'},
#    {'itemId': 'Q26907166', 'enLabel': 'temporal entity'},
#    {'itemId': 'Q42848', 'enLabel': 'data'},
#    {'itemId': 'Q2684591', 'enLabel': 'statement'},
#    {'itemId': 'Q11471', 'enLabel': 'time'},
#    {'itemId': 'Q1921834', 'enLabel': 'feature'},
#    {'itemId': 'Q937228', 'enLabel': 'property'},
#    {'itemId': 'Q483247', 'enLabel': 'phenomenon'},
#    {'itemId': 'Q174834', 'enLabel': 'authority'},
#    {'itemId': 'Q2101636', 'enLabel': 'political power'},
#    {'itemId': 'Q15708736', 'enLabel': 'public authority'},
#    {'itemId': 'Q2324993', 'enLabel': 'state power'},
#    {'itemId': 'Q11028', 'enLabel': 'information'},
#    {'itemId': 'Q108163', 'enLabel': 'proposition'},
#    {'itemId': 'Q20937557', 'enLabel': 'series'},
#    {'itemId': 'Q714737', 'enLabel': 'category of being'},
#    {'itemId': 'Q1207505', 'enLabel': 'quality'},
#    {'itemId': 'Q16722960', 'enLabel': 'phenomenon'},
#    {'itemId': 'Q25107', 'enLabel': 'power'},
#    {'itemId': 'Q2659904', 'enLabel': 'government organization'},
#    {'itemId': 'Q1125239', 'enLabel': 'public body'},
#    {'itemId': 'Q41796', 'enLabel': 'sentence'},
#    {'itemId': 'Q246672', 'enLabel': 'mathematical object'},
#    {'itemId': 'Q151885', 'enLabel': 'concept'},
#    {'itemId': 'Q18340964', 'enLabel': 'power'},
#    {'itemId': 'Q1786828', 'enLabel': 'constituent'},
#    {'itemId': 'Q15916540', 'enLabel': 'semantic unit'},
#    {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#    {'itemId': 'Q5371079', 'enLabel': 'emic unit'},
#    {'itemId': 'Q183046', 'enLabel': 'meaning'},
#    {'itemId': 'Q4393498', 'enLabel': 'representation'},
#    {'itemId': 'Q20817253', 'enLabel': 'linguistic unit'},
#    {'itemId': 'Q16877783', 'enLabel': 'meaning'},
#    {'itemId': 'Q4173967', 'enLabel': 'language unit'},
#    {'itemId': 'Q29651519', 'enLabel': 'mental object'}],
#   'wikiDataClassIds': ['Q515',
#    'Q747074',
#    'Q3024240',
#    'Q1549591',
#    'Q486972',
#    'Q177634',
#    'Q7930989',
#    'Q702492',
#    'Q13221722',
#    'Q2824645',
#    'Q15284',
#    'Q19953632',
#    'Q6256',
#    'Q7275',
#    'Q82794',
#    'Q618123',
#    'Q874405',
#    'Q16334295',
#    'Q15042037',
#    'Q1799794',
#    'Q15916867',
#    'Q1048835',
#    'Q2097994',
#    'Q56061',
#    'Q15893266',
#    'Q19832712',
#    'Q43229',
#    'Q155076',
#    'Q2221906',
#    'Q223557',
#    'Q58416391',
#    'Q58778',
#    'Q7887142',
#    'Q16334298',
#    'Q15642541',
#    'Q6501447',
#    'Q35120',
#    'Q19829125',
#    'Q4204519',
#    'Q24229398',
#    'Q16513015',
#    'Q3778211',
#    'Q17334923',
#    'Q4406616',
#    'Q1454986',
#    'Q58415929',
#    'Q6671777',
#    'Q4330518',
#    'Q2198779',
#    'Q16887380',
#    'Q517966',
#    'Q1496967',
#    'Q16686448',
#    'Q7188',
#    'Q16889133',
#    'Q1190554',
#    'Q188572',
#    'Q192630',
#    'Q23958946',
#    'Q1789452',
#    'Q3505845',
#    'Q830077',
#    'Q488383',
#    'Q30060700',
#    'Q7184903',
#    'Q17553950',
#    'Q7210356',
#    'Q895526',
#    'Q35798',
#    'Q5127848',
#    'Q26907166',
#    'Q42848',
#    'Q2684591',
#    'Q11471',
#    'Q1921834',
#    'Q937228',
#    'Q483247',
#    'Q174834',
#    'Q2101636',
#    'Q15708736',
#    'Q2324993',
#    'Q11028',
#    'Q108163',
#    'Q20937557',
#    'Q714737',
#    'Q1207505',
#    'Q16722960',
#    'Q25107',
#    'Q2659904',
#    'Q1125239',
#    'Q41796',
#    'Q246672',
#    'Q151885',
#    'Q18340964',
#    'Q1786828',
#    'Q15916540',
#    'Q2145290',
#    'Q5371079',
#    'Q183046',
#    'Q4393498',
#    'Q20817253',
#    'Q16877783',
#    'Q4173967',
#    'Q29651519'],
#   'dbPediaTypes': ['City',
#    'Settlement',
#    'PopulatedPlace',
#    'Place',
#    'AdministrativeRegion',
#    'Region'],
#   'dbPediaIri': 'http://dbpedia.org/resource/Naples'},
#  {'title': 'Italy',
#   'url': 'http://en.wikipedia.org/wiki/Italy',
#   'pageRank': 0.0022563201073930025,
#   'cosine': 0.28350418112514525,
#   'lang': 'en',
#   'support': [{'wFrom': 715, 'wTo': 715, 'chunk': 0},
#    {'wFrom': 951, 'wTo': 951, 'chunk': 0}],
#   'wikiDataItemId': 'Q38',
#   'wikiDataClasses': [{'itemId': 'Q3624078', 'enLabel': 'sovereign state'},
#    {'itemId': 'Q6256', 'enLabel': 'country'},
#    {'itemId': 'Q619610', 'enLabel': 'social state'},
#    {'itemId': 'Q179164', 'enLabel': 'unitary state'},
#    {'itemId': 'Q7275', 'enLabel': 'state'},
#    {'itemId': 'Q7270', 'enLabel': 'republic'},
#    {'itemId': 'Q1048835', 'enLabel': 'political territorial entity'},
#    {'itemId': 'Q43229', 'enLabel': 'organization'},
#    {'itemId': 'Q177634', 'enLabel': 'community'},
#    {'itemId': 'Q155076', 'enLabel': 'juridical person'},
#    {'itemId': 'Q7174', 'enLabel': 'democracy'},
#    {'itemId': 'Q15642541', 'enLabel': 'human-geographic territorial entity'},
#    {'itemId': 'Q24229398', 'enLabel': 'agent'},
#    {'itemId': 'Q16334295', 'enLabel': 'group of humans'},
#    {'itemId': 'Q16513015', 'enLabel': 'order'},
#    {'itemId': 'Q874405', 'enLabel': 'social group'},
#    {'itemId': 'Q3778211', 'enLabel': 'legal person'},
#    {'itemId': 'Q28108', 'enLabel': 'political system'},
#    {'itemId': 'Q1496967', 'enLabel': 'territorial entity'},
#    {'itemId': 'Q16686448', 'enLabel': 'artificial entity'},
#    {'itemId': 'Q35120', 'enLabel': 'entity'},
#    {'itemId': 'Q23958946', 'enLabel': 'individual'},
#    {'itemId': 'Q1789452', 'enLabel': 'criterion'},
#    {'itemId': 'Q16334298', 'enLabel': 'living thing group'},
#    {'itemId': 'Q3505845', 'enLabel': 'state'},
#    {'itemId': 'Q58778', 'enLabel': 'system'},
#    {'itemId': 'Q7887142', 'enLabel': 'unit of analysis'},
#    {'itemId': 'Q830077', 'enLabel': 'subject'},
#    {'itemId': 'Q1639378', 'enLabel': 'social system'},
#    {'itemId': 'Q82794', 'enLabel': 'geographic region'},
#    {'itemId': 'Q1921834', 'enLabel': 'feature'},
#    {'itemId': 'Q16887380', 'enLabel': 'group'},
#    {'itemId': 'Q517966', 'enLabel': 'structure'},
#    {'itemId': 'Q937228', 'enLabel': 'property'},
#    {'itemId': 'Q483247', 'enLabel': 'phenomenon'},
#    {'itemId': 'Q6671777', 'enLabel': 'structure'},
#    {'itemId': 'Q4330518', 'enLabel': 'research object'},
#    {'itemId': 'Q2198779', 'enLabel': 'unit'},
#    {'itemId': 'Q2221906', 'enLabel': 'geographic location'},
#    {'itemId': 'Q17553950', 'enLabel': 'object'},
#    {'itemId': 'Q714737', 'enLabel': 'category of being'},
#    {'itemId': 'Q1207505', 'enLabel': 'quality'},
#    {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#    {'itemId': 'Q16722960', 'enLabel': 'phenomenon'},
#    {'itemId': 'Q488383', 'enLabel': 'object'},
#    {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#    {'itemId': 'Q17334923', 'enLabel': 'location'},
#    {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#    {'itemId': 'Q151885', 'enLabel': 'concept'},
#    {'itemId': 'Q26907166', 'enLabel': 'temporal entity'},
#    {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#    {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#    {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#    {'itemId': 'Q223557', 'enLabel': 'physical object'},
#    {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#    {'itemId': 'Q4393498', 'enLabel': 'representation'},
#    {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#    {'itemId': 'Q30060700', 'enLabel': 'object of science'}],
#   'wikiDataClassIds': ['Q3624078',
#    'Q6256',
#    'Q619610',
#    'Q179164',
#    'Q7275',
#    'Q7270',
#    'Q1048835',
#    'Q43229',
#    'Q177634',
#    'Q155076',
#    'Q7174',
#    'Q15642541',
#    'Q24229398',
#    'Q16334295',
#    'Q16513015',
#    'Q874405',
#    'Q3778211',
#    'Q28108',
#    'Q1496967',
#    'Q16686448',
#    'Q35120',
#    'Q23958946',
#    'Q1789452',
#    'Q16334298',
#    'Q3505845',
#    'Q58778',
#    'Q7887142',
#    'Q830077',
#    'Q1639378',
#    'Q82794',
#    'Q1921834',
#    'Q16887380',
#    'Q517966',
#    'Q937228',
#    'Q483247',
#    'Q6671777',
#    'Q4330518',
#    'Q2198779',
#    'Q2221906',
#    'Q17553950',
#    'Q714737',
#    'Q1207505',
#    'Q1190554',
#    'Q16722960',
#    'Q488383',
#    'Q7184903',
#    'Q17334923',
#    'Q4406616',
#    'Q151885',
#    'Q26907166',
#    'Q618123',
#    'Q2145290',
#    'Q58415929',
#    'Q223557',
#    'Q58416391',
#    'Q4393498',
#    'Q1454986',
#    'Q30060700'],
#   'dbPediaTypes': ['PopulatedPlace', 'Place', 'Country'],
#   'dbPediaIri': 'http://dbpedia.org/resource/Italy'},
#  {'title': 'Peristyle',
#   'url': 'http://en.wikipedia.org/wiki/Peristyle',
#   'pageRank': 0.0022272463297215747,
#   'cosine': 0.17891798661997024,
#   'lang': 'en',
#   'support': [{'wFrom': 802, 'wTo': 802, 'chunk': 0}],
#   'wikiDataItemId': 'Q725453',
#   'wikiDataClasses': [{'itemId': 'Q1497384', 'enLabel': 'part of building'},
#    {'itemId': 'Q56052926', 'enLabel': 'building division'},
#    {'itemId': 'Q17334923', 'enLabel': 'location'},
#    {'itemId': 'Q811430', 'enLabel': 'construction'},
#    {'itemId': 'Q15989253', 'enLabel': 'part'},
#    {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#    {'itemId': 'Q8205328', 'enLabel': 'artificial physical object'},
#    {'itemId': 'Q35145743', 'enLabel': 'human-made geographic object'},
#    {'itemId': 'Q386724', 'enLabel': 'work'},
#    {'itemId': 'Q6671777', 'enLabel': 'structure'},
#    {'itemId': 'Q35120', 'enLabel': 'entity'},
#    {'itemId': 'Q223557', 'enLabel': 'physical object'},
#    {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#    {'itemId': 'Q16686448', 'enLabel': 'artificial entity'},
#    {'itemId': 'Q27096235', 'enLabel': 'artificial geographic entity'},
#    {'itemId': 'Q15401930', 'enLabel': 'product'},
#    {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#    {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#    {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#    {'itemId': 'Q27096213', 'enLabel': 'geographic entity'},
#    {'itemId': 'Q488383', 'enLabel': 'object'},
#    {'itemId': 'Q58778', 'enLabel': 'system'},
#    {'itemId': 'Q30060700', 'enLabel': 'object of science'}],
#   'wikiDataClassIds': ['Q1497384',
#    'Q56052926',
#    'Q17334923',
#    'Q811430',
#    'Q15989253',
#    'Q618123',
#    'Q8205328',
#    'Q35145743',
#    'Q386724',
#    'Q6671777',
#    'Q35120',
#    'Q223557',
#    'Q58416391',
#    'Q16686448',
#    'Q27096235',
#    'Q15401930',
#    'Q4406616',
#    'Q1454986',
#    'Q58415929',
#    'Q27096213',
#    'Q488383',
#    'Q58778',
#    'Q30060700'],
#   'dbPediaTypes': [],
#   'dbPediaIri': 'http://dbpedia.org/resource/Peristyle'},
#  {'title': 'Architecture',
#   'url': 'http://en.wikipedia.org/wiki/Architecture',
#   'pageRank': 0.0021981072962756454,
#   'cosine': 0.27032474176319343,
#   'lang': 'en',
#   'support': [{'wFrom': 53, 'wTo': 53, 'chunk': 0},
#    {'wFrom': 125, 'wTo': 125, 'chunk': 0},
#    {'wFrom': 383, 'wTo': 383, 'chunk': 0},
#    {'wFrom': 444, 'wTo': 444, 'chunk': 0},
#    {'wFrom': 564, 'wTo': 564, 'chunk': 0},
#    {'wFrom': 990, 'wTo': 990, 'chunk': 0},
#    {'wFrom': 1080, 'wTo': 1080, 'chunk': 0}],
#   'wikiDataItemId': 'Q12271',
#   'wikiDataClasses': [{'itemId': 'Q11862829',
#     'enLabel': 'academic discipline'},
#    {'itemId': 'Q1047113', 'enLabel': 'specialty'},
#    {'itemId': 'Q9081', 'enLabel': 'knowledge'},
#    {'itemId': 'Q11028', 'enLabel': 'information'},
#    {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#    {'itemId': 'Q488383', 'enLabel': 'object'},
#    {'itemId': 'Q35120', 'enLabel': 'entity'}],
#   'wikiDataClassIds': ['Q11862829',
#    'Q1047113',
#    'Q9081',
#    'Q11028',
#    'Q7184903',
#    'Q488383',
#    'Q35120'],
#   'dbPediaTypes': [],
#   'dbPediaIri': 'http://dbpedia.org/resource/Architecture'},
#  {'title': 'Narrative thread',
#   'url': 'http://en.wikipedia.org/wiki/Narrative_thread',
#   'pageRank': 0.002171050735543616,
#   'cosine': 0.00924343957986453,
#   'lang': 'en',
#   'support': [{'wFrom': 91, 'wTo': 91, 'chunk': 1}],
#   'wikiDataItemId': 'Q6966227',
#   'wikiDataClasses': [],
#   'wikiDataClassIds': [],
#   'dbPediaTypes': [],
#   'dbPediaIri': 'http://dbpedia.org/resource/Narrative_thread'},
#  {'title': 'Archaeology',
#   'url': 'http://en.wikipedia.org/wiki/Archaeology',
#   'pageRank': 0.0021367351922659513,
#   'cosine': 0.24574825221579963,
#   'lang': 'en',
#   'support': [{'wFrom': 339, 'wTo': 339, 'chunk': 0},
#    {'wFrom': 355, 'wTo': 355, 'chunk': 0},
#    {'wFrom': 582, 'wTo': 582, 'chunk': 0},
#    {'wFrom': 1680, 'wTo': 1680, 'chunk': 0}],
#   'wikiDataItemId': 'Q23498',
#   'wikiDataClasses': [{'itemId': 'Q11862829',
#     'enLabel': 'academic discipline'},
#    {'itemId': 'Q4671286', 'enLabel': 'academic major'},
#    {'itemId': 'Q1047113', 'enLabel': 'specialty'},
#    {'itemId': 'Q9081', 'enLabel': 'knowledge'},
#    {'itemId': 'Q11028', 'enLabel': 'information'},
# ...
#    {'itemId': 'Q58778', 'enLabel': 'system'},
#    {'itemId': 'Q30060700', 'enLabel': 'object of science'},
#    {'itemId': 'Q2424752', 'enLabel': 'product'},
#    {'itemId': 'Q837171', 'enLabel': 'financial services'},
#    {'itemId': 'Q6671777', 'enLabel': 'structure'},
#    {'itemId': 'Q28877', 'enLabel': 'goods'},
#    {'itemId': 'Q2897903', 'enLabel': 'goods and services'},
#    {'itemId': 'Q7406919', 'enLabel': 'service'},
#    {'itemId': 'Q2995644', 'enLabel': 'result'},
#    {'itemId': 'Q451967', 'enLabel': 'human action'},
#    {'itemId': 'Q374182', 'enLabel': 'logical consequence'},
#    {'itemId': 'Q3769299', 'enLabel': 'human behaviour'},
#    {'itemId': 'Q4026292', 'enLabel': 'action'},
#    {'itemId': 'Q1914636', 'enLabel': 'activity'},
#    {'itemId': 'Q733541', 'enLabel': 'consequence'},
#    {'itemId': 'Q9332', 'enLabel': 'behavior'},
#    {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#    {'itemId': 'Q26907166', 'enLabel': 'temporal entity'},
#    {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'}],
#   'wikiDataClassIds': ['Q2342494',
#    'Q1643989',
#    'Q488383',
#    'Q223557',
#    'Q190122',
#    'Q35120',
#    'Q4406616',
#    'Q1454986',
#    'Q28038717',
#    'Q15809678',
#    'Q58778',
#    'Q30060700',
#    'Q2424752',
#    'Q837171',
#    'Q6671777',
#    'Q28877',
#    'Q2897903',
#    'Q7406919',
#    'Q2995644',
#    'Q451967',
#    'Q374182',
#    'Q3769299',
#    'Q4026292',
#    'Q1914636',
#    'Q733541',
#    'Q9332',
#    'Q1190554',
#    'Q26907166',
#    'Q58415929'],
#   'dbPediaTypes': ['Currency'],
#   'dbPediaIri': 'http://dbpedia.org/resource/Banknote'},
#  {'title': 'Hoard',
#   'url': 'http://en.wikipedia.org/wiki/Hoard',
#   'pageRank': 0.0008865167395297915,
#   'cosine': 0.07686266919454374,
#   'lang': 'en',
#   'support': [{'wFrom': 1705, 'wTo': 1705, 'chunk': 0}],
#   'wikiDataItemId': 'Q164099',
#   'wikiDataClasses': [],
#   'wikiDataClassIds': [],
#   'dbPediaTypes': [],
#   'dbPediaIri': 'http://dbpedia.org/resource/Hoard'},
#  {'title': 'Intimate relationship',
#   'url': 'http://en.wikipedia.org/wiki/Intimate_relationship',
#   'pageRank': 0.0008756791781863008,
#   'cosine': 0.22026298463023689,
#   'lang': 'en',
#   'support': [{'wFrom': 307, 'wTo': 307, 'chunk': 0},
#    {'wFrom': 1246, 'wTo': 1246, 'chunk': 0},
#    {'wFrom': 88, 'wTo': 88, 'chunk': 1}],
#   'wikiDataItemId': 'Q736922',
#   'wikiDataClasses': [],
#   'wikiDataClassIds': [],
#   'dbPediaTypes': [],
#   'dbPediaIri': 'http://dbpedia.org/resource/Intimate_relationship'},
#  {'title': 'Orbit',
#   'url': 'http://en.wikipedia.org/wiki/Orbit',
#   'pageRank': 0.00086365873235368,
#   'cosine': 0.22421145226756264,
#   'lang': 'en',
#   'support': [{'wFrom': 1763, 'wTo': 1763, 'chunk': 0}],
#   'wikiDataItemId': 'Q4130',
#   'wikiDataClasses': [{'itemId': 'Q2221906', 'enLabel': 'geographic location'},
#    {'itemId': 'Q17334923', 'enLabel': 'location'},
#    {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#    {'itemId': 'Q223557', 'enLabel': 'physical object'},
#    {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#    {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#    {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#    {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#    {'itemId': 'Q488383', 'enLabel': 'object'},
#    {'itemId': 'Q58778', 'enLabel': 'system'},
#    {'itemId': 'Q30060700', 'enLabel': 'object of science'},
#    {'itemId': 'Q35120', 'enLabel': 'entity'},
#    {'itemId': 'Q6671777', 'enLabel': 'structure'}],
#   'wikiDataClassIds': ['Q2221906',
#    'Q17334923',
#    'Q618123',
#    'Q223557',
#    'Q58416391',
#    'Q4406616',
#    'Q1454986',
#    'Q58415929',
#    'Q488383',
#    'Q58778',
#    'Q30060700',
#    'Q35120',
#    'Q6671777'],
#   'dbPediaTypes': ['Agent', 'Organisation', 'Company'],
#   'dbPediaIri': 'http://dbpedia.org/resource/Orbit'},
#  {'title': 'Classical mechanics',
#   'url': 'http://en.wikipedia.org/wiki/Classical_mechanics',
#   'pageRank': 0.0008608505166181186,
#   'cosine': 0.2121669873166339,
#   'lang': 'en',
#   'support': [{'wFrom': 360, 'wTo': 361, 'chunk': 0}],
#   'wikiDataItemId': 'Q11397',
#   'wikiDataClasses': [],
#   'wikiDataClassIds': [],
#   'dbPediaTypes': [],
#   'dbPediaIri': 'http://dbpedia.org/resource/Classical_mechanics'},
#  {'title': 'Convention (norm)',
#   'url': 'http://en.wikipedia.org/wiki/Convention_(norm)',
#   'pageRank': 0.0008577115023005728,
#   'cosine': 0.19319696985340717,
#   'lang': 'en',
#   'support': [{'wFrom': 169, 'wTo': 169, 'chunk': 0}],
#   'wikiDataItemId': 'Q367293',
#   'wikiDataClasses': [],
#   'wikiDataClassIds': [],
#   'dbPediaTypes': [],
#   'dbPediaIri': 'http://dbpedia.org/resource/Convention_(norm)'},
#  {'title': 'Android (operating system)',
#   'url': 'http://en.wikipedia.org/wiki/Android_(operating_system)',
#   'pageRank': 0.0008388490191911401,
#   'cosine': 0.1334148478475758,
#   'lang': 'en',
#   'support': [{'wFrom': 96, 'wTo': 96, 'chunk': 0},
#    {'wFrom': 217, 'wTo': 217, 'chunk': 0},
#    {'wFrom': 250, 'wTo': 250, 'chunk': 0},
#    {'wFrom': 622, 'wTo': 622, 'chunk': 0},
#    {'wFrom': 972, 'wTo': 972, 'chunk': 0},
#    {'wFrom': 1284, 'wTo': 1284, 'chunk': 0},
#    {'wFrom': 1364, 'wTo': 1364, 'chunk': 0},
#    {'wFrom': 1441, 'wTo': 1441, 'chunk': 0},
#    {'wFrom': 1563, 'wTo': 1563, 'chunk': 0},
#    {'wFrom': 1709, 'wTo': 1709, 'chunk': 0},
#    {'wFrom': 1719, 'wTo': 1719, 'chunk': 0},
#    {'wFrom': 1758, 'wTo': 1758, 'chunk': 0},
#    {'wFrom': 1883, 'wTo': 1883, 'chunk': 0},
#    {'wFrom': 27, 'wTo': 27, 'chunk': 1}],
#   'wikiDataItemId': 'Q94',
#   'wikiDataClasses': [{'itemId': 'Q920890',
#     'enLabel': 'mobile operating system'},
#    {'itemId': 'Q9135', 'enLabel': 'operating system'},
#    {'itemId': 'Q21743174', 'enLabel': 'mobile software'},
#    {'itemId': 'Q676202', 'enLabel': 'system software'},
#    {'itemId': 'Q241317', 'enLabel': 'computing platform'},
#    {'itemId': 'Q7397', 'enLabel': 'software'},
#    {'itemId': 'Q15411548', 'enLabel': 'computing infrastructure'},
#    {'itemId': 'Q17537576', 'enLabel': 'creative work'},
#    {'itemId': 'Q2424752', 'enLabel': 'product'},
#    {'itemId': 'Q8148', 'enLabel': 'industry'},
#    {'itemId': 'Q47461344', 'enLabel': 'written work'},
#    {'itemId': 'Q179310', 'enLabel': 'computing'},
#    {'itemId': 'Q121359', 'enLabel': 'infrastructure'},
#    {'itemId': 'Q15621286', 'enLabel': 'intellectual work'},
#    {'itemId': 'Q18593264', 'enLabel': 'item of collection or exhibition'},
#    {'itemId': 'Q28877', 'enLabel': 'goods'},
#    {'itemId': 'Q2897903', 'enLabel': 'goods and services'},
#    {'itemId': 'Q739302', 'enLabel': 'production'},
#    {'itemId': 'Q386724', 'enLabel': 'work'},
#    {'itemId': 'Q1914636', 'enLabel': 'activity'},
#    {'itemId': 'Q21503252', 'enLabel': 'instance of'},
#    {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#    {'itemId': 'Q2995644', 'enLabel': 'result'},
#    {'itemId': 'Q3249551', 'enLabel': 'process'},
#    {'itemId': 'Q15401930', 'enLabel': 'product'},
#    {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#    {'itemId': 'Q58778', 'enLabel': 'system'},
#    {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#    {'itemId': 'Q30060700', 'enLabel': 'object of science'},
#    {'itemId': 'Q374182', 'enLabel': 'logical consequence'},
#    {'itemId': 'Q20937557', 'enLabel': 'series'},
#    {'itemId': 'Q1150070', 'enLabel': 'change'},
#    {'itemId': 'Q16686448', 'enLabel': 'artificial entity'},
#    {'itemId': 'Q26907166', 'enLabel': 'temporal entity'},
#    {'itemId': 'Q6671777', 'enLabel': 'structure'},
#    {'itemId': 'Q488383', 'enLabel': 'object'},
#    {'itemId': 'Q733541', 'enLabel': 'consequence'},
#    {'itemId': 'Q16887380', 'enLabel': 'group'},
#    {'itemId': 'Q5915039', 'enLabel': 'inconstancy'},
#    {'itemId': 'Q35120', 'enLabel': 'entity'},
#    {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#    {'itemId': 'Q17553950', 'enLabel': 'object'},
#    {'itemId': 'Q937228', 'enLabel': 'property'},
#    {'itemId': 'Q714737', 'enLabel': 'category of being'},
#    {'itemId': 'Q1207505', 'enLabel': 'quality'},
#    {'itemId': 'Q151885', 'enLabel': 'concept'},
#    {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#    {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#    {'itemId': 'Q4393498', 'enLabel': 'representation'}],
#   'wikiDataClassIds': ['Q920890',
#    'Q9135',
#    'Q21743174',
#    'Q676202',
#    'Q241317',
#    'Q7397',
#    'Q15411548',
#    'Q17537576',
#    'Q2424752',
#    'Q8148',
#    'Q47461344',
#    'Q179310',
#    'Q121359',
#    'Q15621286',
#    'Q18593264',
#    'Q28877',
#    'Q2897903',
#    'Q739302',
#    'Q386724',
#    'Q1914636',
#    'Q21503252',
#    'Q1454986',
#    'Q2995644',
#    'Q3249551',
#    'Q15401930',
#    'Q1190554',
#    'Q58778',
#    'Q4406616',
#    'Q30060700',
#    'Q374182',
#    'Q20937557',
#    'Q1150070',
#    'Q16686448',
#    'Q26907166',
#    'Q6671777',
#    'Q488383',
#    'Q733541',
#    'Q16887380',
#    'Q5915039',
#    'Q35120',
#    'Q58415929',
#    'Q17553950',
#    'Q937228',
#    'Q714737',
#    'Q1207505',
#    'Q151885',
#    'Q7184903',
#    'Q2145290',
#    'Q4393498'],
#   'dbPediaTypes': ['Work', 'Software'],
#   'dbPediaIri': 'http://dbpedia.org/resource/Android_(operating_system)'},
#  {'title': 'Debate',
#   'url': 'http://en.wikipedia.org/wiki/Debate',
#   'pageRank': 0.0008365598106211138,
#   'cosine': 0.2023126404666659,
#   'lang': 'en',
#   'support': [{'wFrom': 78, 'wTo': 78, 'chunk': 0}],
#   'wikiDataItemId': 'Q179875',
#   'wikiDataClasses': [],
#   'wikiDataClassIds': [],
#   'dbPediaTypes': [],
#   'dbPediaIri': 'http://dbpedia.org/resource/Debate'},
#  {'title': 'States of Germany',
#   'url': 'http://en.wikipedia.org/wiki/States_of_Germany',
#   'pageRank': 0.0008345743315678053,
#   'cosine': 0.20874743307230503,
#   'lang': 'en',
#   'support': [{'wFrom': 257, 'wTo': 257, 'chunk': 0}],
#   'wikiDataItemId': 'Q1221156',
#   'wikiDataClasses': [{'itemId': 'Q28872924',
#     'enLabel': 'designation for an administrative territorial entity of a single country'},
#    {'itemId': 'Q15617994',
#     'enLabel': 'designation for an administrative territorial entity'},
#    {'itemId': 'Q217594', 'enLabel': 'class (set theory)'},
#    {'itemId': 'Q246672', 'enLabel': 'mathematical object'},
#    {'itemId': 'Q16889133', 'enLabel': 'class'},
#    {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#    {'itemId': 'Q5127848', 'enLabel': 'class'},
#    {'itemId': 'Q488383', 'enLabel': 'object'},
#    {'itemId': 'Q35120', 'enLabel': 'entity'}],
#   'wikiDataClassIds': ['Q28872924',
#    'Q15617994',
#    'Q217594',
#    'Q246672',
#    'Q16889133',
#    'Q7184903',
#    'Q5127848',
#    'Q488383',
#    'Q35120'],
#   'dbPediaTypes': [],
#   'dbPediaIri': 'http://dbpedia.org/resource/States_of_Germany'},
#  {'title': 'Child abandonment',
#   'url': 'http://en.wikipedia.org/wiki/Child_abandonment',
#   'pageRank': 0.0008226437276308301,
#   'cosine': 0.24466395911063074,
#   'lang': 'en',
#   'support': [{'wFrom': 1787, 'wTo': 1787, 'chunk': 0}],
#   'wikiDataItemId': 'Q202415',
#   'wikiDataClasses': [{'itemId': 'Q1724915', 'enLabel': 'use'},
#    {'itemId': 'Q451967', 'enLabel': 'human action'},
#    {'itemId': 'Q937228', 'enLabel': 'property'},
#    {'itemId': 'Q3769299', 'enLabel': 'human behaviour'},
#    {'itemId': 'Q4026292', 'enLabel': 'action'},
#    {'itemId': 'Q1914636', 'enLabel': 'activity'},
#    {'itemId': 'Q714737', 'enLabel': 'category of being'},
#    {'itemId': 'Q1207505', 'enLabel': 'quality'},
#    {'itemId': 'Q9332', 'enLabel': 'behavior'},
#    {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#    {'itemId': 'Q151885', 'enLabel': 'concept'},
#    {'itemId': 'Q35120', 'enLabel': 'entity'},
#    {'itemId': 'Q26907166', 'enLabel': 'temporal entity'},
#    {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#    {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#    {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#    {'itemId': 'Q488383', 'enLabel': 'object'},
#    {'itemId': 'Q4393498', 'enLabel': 'representation'}],
#   'wikiDataClassIds': ['Q1724915',
#    'Q451967',
#    'Q937228',
#    'Q3769299',
#    'Q4026292',
#    'Q1914636',
#    'Q714737',
#    'Q1207505',
#    'Q9332',
#    'Q1190554',
#    'Q151885',
#    'Q35120',
#    'Q26907166',
#    'Q7184903',
#    'Q2145290',
#    'Q58415929',
#    'Q488383',
#    'Q4393498'],
#   'dbPediaTypes': [],
#   'dbPediaIri': 'http://dbpedia.org/resource/Child_abandonment'},
#  {'title': 'Symbiosis',
#   'url': 'http://en.wikipedia.org/wiki/Symbiosis',
#   'pageRank': 0.0008055513487893248,
#   'cosine': 0.21653634411729575,
#   'lang': 'en',
#   'support': [{'wFrom': 781, 'wTo': 781, 'chunk': 0},
#    {'wFrom': 876, 'wTo': 876, 'chunk': 0}],
#   'wikiDataItemId': 'Q121610',
#   'wikiDataClasses': [],
#   'wikiDataClassIds': [],
#   'dbPediaTypes': [],
#   'dbPediaIri': 'http://dbpedia.org/resource/Symbiosis'},
#  {'title': 'Street',
#   'url': 'http://en.wikipedia.org/wiki/Street',
#   'pageRank': 0.0008015379125250906,
#   'cosine': 0.21390245603352487,
#   'lang': 'en',
#   'support': [{'wFrom': 1580, 'wTo': 1580, 'chunk': 0}],
#   'wikiDataItemId': 'Q79007',
#   'wikiDataClasses': [],
#   'wikiDataClassIds': [],
#   'dbPediaTypes': ['PopulatedPlace', 'Place'],
#   'dbPediaIri': 'http://dbpedia.org/resource/Street'},
#  {'title': 'Fact',
#   'url': 'http://en.wikipedia.org/wiki/Fact',
#   'pageRank': 0.0007979679955828611,
#   'cosine': 0.255090747699011,
#   'lang': 'en',
#   'support': [{'wFrom': 115, 'wTo': 115, 'chunk': 0},
#    {'wFrom': 608, 'wTo': 608, 'chunk': 0},
#    {'wFrom': 1187, 'wTo': 1187, 'chunk': 0},
#    {'wFrom': 1263, 'wTo': 1263, 'chunk': 0},
#    {'wFrom': 1311, 'wTo': 1311, 'chunk': 0},
#    {'wFrom': 1425, 'wTo': 1425, 'chunk': 0},
#    {'wFrom': 1669, 'wTo': 1669, 'chunk': 0}],
#   'wikiDataItemId': 'Q188572',
#   'wikiDataClasses': [],
#   'wikiDataClassIds': [],
#   'dbPediaTypes': [],
#   'dbPediaIri': 'http://dbpedia.org/resource/Fact'},
#  {'title': 'Witness',
#   'url': 'http://en.wikipedia.org/wiki/Witness',
#   'pageRank': 0.0007844500367621678,
#   'cosine': 0.19392077732358493,
#   'lang': 'en',
#   'support': [{'wFrom': 1103, 'wTo': 1103, 'chunk': 0}],
#   'wikiDataItemId': 'Q196939',
#   'wikiDataClasses': [],
#   'wikiDataClassIds': [],
#   'dbPediaTypes': ['Work', 'Album', 'MusicalWork'],
#   'dbPediaIri': 'http://dbpedia.org/resource/Witness'},
#  {'title': 'Multiverse',
#   'url': 'http://en.wikipedia.org/wiki/Multiverse',
#   'pageRank': 0.0007819466003039575,
#   'cosine': 0.2030278987262624,
#   'lang': 'en',
#   'support': [{'wFrom': 851, 'wTo': 851, 'chunk': 0},
#    {'wFrom': 1512, 'wTo': 1512, 'chunk': 0},
#    {'wFrom': 1760, 'wTo': 1760, 'chunk': 0}],
#   'wikiDataItemId': 'Q3327819',
#   'wikiDataClasses': [{'itemId': 'Q41719', 'enLabel': 'hypothesis'},
#    {'itemId': 'Q108163', 'enLabel': 'proposition'},
#    {'itemId': 'Q321703', 'enLabel': 'premise'},
#    {'itemId': 'Q11028', 'enLabel': 'information'},
#    {'itemId': 'Q41796', 'enLabel': 'sentence'},
#    {'itemId': 'Q246672', 'enLabel': 'mathematical object'},
#    {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#    {'itemId': 'Q1786828', 'enLabel': 'constituent'},
#    {'itemId': 'Q15916540', 'enLabel': 'semantic unit'},
#    {'itemId': 'Q488383', 'enLabel': 'object'},
#    {'itemId': 'Q5371079', 'enLabel': 'emic unit'},
#    {'itemId': 'Q183046', 'enLabel': 'meaning'},
#    {'itemId': 'Q35120', 'enLabel': 'entity'},
#    {'itemId': 'Q16889133', 'enLabel': 'class'},
#    {'itemId': 'Q20817253', 'enLabel': 'linguistic unit'},
#    {'itemId': 'Q16877783', 'enLabel': 'meaning'},
#    {'itemId': 'Q5127848', 'enLabel': 'class'},
#    {'itemId': 'Q4173967', 'enLabel': 'language unit'},
#    {'itemId': 'Q151885', 'enLabel': 'concept'},
#    {'itemId': 'Q29651519', 'enLabel': 'mental object'},
#    {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#    {'itemId': 'Q4393498', 'enLabel': 'representation'},
#    {'itemId': 'Q937228', 'enLabel': 'property'},
#    {'itemId': 'Q714737', 'enLabel': 'category of being'},
#    {'itemId': 'Q1207505', 'enLabel': 'quality'}],
#   'wikiDataClassIds': ['Q41719',
#    'Q108163',
#    'Q321703',
#    'Q11028',
#    'Q41796',
#    'Q246672',
#    'Q7184903',
#    'Q1786828',
#    'Q15916540',
#    'Q488383',
#    'Q5371079',
#    'Q183046',
#    'Q35120',
#    'Q16889133',
#    'Q20817253',
#    'Q16877783',
#    'Q5127848',
#    'Q4173967',
#    'Q151885',
#    'Q29651519',
#    'Q2145290',
#    'Q4393498',
#    'Q937228',
#    'Q714737',
#    'Q1207505'],
#   'dbPediaTypes': [],
#   'dbPediaIri': 'http://dbpedia.org/resource/Multiverse'}]

# %%
wikification_filter(res, "SIMPLE", in_place=False)
# Out:
# {'concepts': [{'title': 'Herculaneum',
#    'url': 'http://en.wikipedia.org/wiki/Herculaneum',
#    'pageRank': 0.03739412937379306,
#    'cosine': 0.6801656584737229,
#    'lang': 'en'},
#   {'title': 'Pompeii',
#    'url': 'http://en.wikipedia.org/wiki/Pompeii',
#    'pageRank': 0.018291090534386135,
#    'cosine': 0.5094460836140102,
#    'lang': 'en'},
#   {'title': 'Samnites',
#    'url': 'http://en.wikipedia.org/wiki/Samnites',
#    'pageRank': 0.0038154357845719433,
#    'cosine': 0.14869798909851106,
#    'lang': 'en'},
#   {'title': 'Lava',
#    'url': 'http://en.wikipedia.org/wiki/Lava',
#    'pageRank': 0.003630996714491836,
#    'cosine': 0.20049486484197385,
#    'lang': 'en'},
#   {'title': 'Mount Vesuvius',
#    'url': 'http://en.wikipedia.org/wiki/Mount_Vesuvius',
#    'pageRank': 0.003344867537362839,
#    'cosine': 0.3625857514945056,
#    'lang': 'en'},
#   {'title': 'Ancient Rome',
#    'url': 'http://en.wikipedia.org/wiki/Ancient_Rome',
#    'pageRank': 0.0031142185561927574,
#    'cosine': 0.2999609464376098,
#    'lang': 'en'},
#   {'title': 'Boscoreale',
#    'url': 'http://en.wikipedia.org/wiki/Boscoreale',
#    'pageRank': 0.003113899583083107,
#    'cosine': 0.24575084340794787,
#    'lang': 'en'},
#   {'title': 'Skeleton',
#    'url': 'http://en.wikipedia.org/wiki/Skeleton',
#    'pageRank': 0.0027404853711771584,
#    'cosine': 0.22432098003312076,
#    'lang': 'en'},
#   {'title': 'Campania',
#    'url': 'http://en.wikipedia.org/wiki/Campania',
#    'pageRank': 0.002653586789565017,
#    'cosine': 0.28352691499769916,
#    'lang': 'en'},
#   {'title': 'Naples',
#    'url': 'http://en.wikipedia.org/wiki/Naples',
#    'pageRank': 0.002491342969735601,
#    'cosine': 0.2410574134288819,
#    'lang': 'en'},
#   {'title': 'Italy',
#    'url': 'http://en.wikipedia.org/wiki/Italy',
#    'pageRank': 0.0022563201073930025,
#    'cosine': 0.28350418112514525,
#    'lang': 'en'},
#   {'title': 'Peristyle',
#    'url': 'http://en.wikipedia.org/wiki/Peristyle',
#    'pageRank': 0.0022272463297215747,
#    'cosine': 0.17891798661997024,
#    'lang': 'en'},
#   {'title': 'Architecture',
#    'url': 'http://en.wikipedia.org/wiki/Architecture',
#    'pageRank': 0.0021981072962756454,
#    'cosine': 0.27032474176319343,
#    'lang': 'en'},
#   {'title': 'Narrative thread',
#    'url': 'http://en.wikipedia.org/wiki/Narrative_thread',
#    'pageRank': 0.002171050735543616,
#    'cosine': 0.00924343957986453,
#    'lang': 'en'},
#   {'title': 'Archaeology',
#    'url': 'http://en.wikipedia.org/wiki/Archaeology',
#    'pageRank': 0.0021367351922659513,
#    'cosine': 0.24574825221579963,
#    'lang': 'en'},
#   {'title': 'Wood',
#    'url': 'http://en.wikipedia.org/wiki/Wood',
#    'pageRank': 0.0021168250728762147,
#    'cosine': 0.26215564938985225,
#    'lang': 'en'},
#   {'title': 'Ferry',
#    'url': 'http://en.wikipedia.org/wiki/Ferry',
#    'pageRank': 0.0021134991636813515,
#    'cosine': 0.012632742062447272,
#    'lang': 'en'},
#   {'title': 'Basilica',
#    'url': 'http://en.wikipedia.org/wiki/Basilica',
#    'pageRank': 0.0020660031936228286,
#    'cosine': 0.20542492823870775,
#    'lang': 'en'},
#   {'title': 'Social War (91–88 BC)',
#    'url': 'http://en.wikipedia.org/wiki/Social_War_(91%e2%80%9388_BC)',
#    'pageRank': 0.002025536516692804,
#    'cosine': 0.18125475332075547,
#    'lang': 'en'},
#   {'title': 'Osci',
#    'url': 'http://en.wikipedia.org/wiki/Osci',
#    'pageRank': 0.0019940337144914717,
#    'cosine': 0.19781805024448035,
#    'lang': 'en'},
#   {'title': 'Italic peoples',
#    'url': 'http://en.wikipedia.org/wiki/Italic_peoples',
#    'pageRank': 0.0019886342695803957,
#    'cosine': 0.1810461655169992,
#    'lang': 'en'},
#   {'title': 'Earthquake',
#    'url': 'http://en.wikipedia.org/wiki/Earthquake',
#    'pageRank': 0.0019629152035331213,
#    'cosine': 0.2080731241745892,
#    'lang': 'en'},
#   {'title': 'Amphitheatre',
#    'url': 'http://en.wikipedia.org/wiki/Amphitheatre',
#    'pageRank': 0.001962003575124254,
#    'cosine': 0.1172295706799371,
#    'lang': 'en'},
#   {'title': 'Roman art',
#    'url': 'http://en.wikipedia.org/wiki/Roman_art',
#    'pageRank': 0.0019047280974254874,
#    'cosine': 0.32333329495899815,
#    'lang': 'en'},
#   {'title': 'Fresco',
#    'url': 'http://en.wikipedia.org/wiki/Fresco',
#    'pageRank': 0.001901336779711824,
#    'cosine': 0.23097053337387713,
#    'lang': 'en'},
#   {'title': 'Mediterranean Sea',
#    'url': 'http://en.wikipedia.org/wiki/Mediterranean_Sea',
#    'pageRank': 0.0018278414723031347,
#    'cosine': 0.22713276222651937,
#    'lang': 'en'},
#   {'title': 'Earth',
#    'url': 'http://en.wikipedia.org/wiki/Earth',
#    'pageRank': 0.0017079127210227329,
#    'cosine': 0.25004965149267083,
#    'lang': 'en'},
#   {'title': 'Eruption of Mount Vesuvius in 79',
#    'url': 'http://en.wikipedia.org/wiki/Eruption_of_Mount_Vesuvius_in_79',
#    'pageRank': 0.0016833515204172254,
#    'cosine': 0.4495078060354746,
#    'lang': 'en'},
#   {'title': 'Common Era',
#    'url': 'http://en.wikipedia.org/wiki/Common_Era',
#    'pageRank': 0.0016794360972681613,
#    'cosine': 0.21154679577624724,
#    'lang': 'en'},
#   {'title': 'Artifact (archaeology)',
#    'url': 'http://en.wikipedia.org/wiki/Artifact_(archaeology)',
#    'pageRank': 0.0016709840977548573,
#    'cosine': 0.1375952927556312,
#    'lang': 'en'},
#   {'title': 'Fall of Constantinople',
#    'url': 'http://en.wikipedia.org/wiki/Fall_of_Constantinople',
#    'pageRank': 0.0016690802426994544,
#    'cosine': 0.27359064923539245,
#    'lang': 'en'},
#   {'title': 'Evolution',
#    'url': 'http://en.wikipedia.org/wiki/Evolution',
#    'pageRank': 0.0016548063723995352,
#    'cosine': 0.2658431088319354,
#    'lang': 'en'},
#   {'title': 'Black Sea',
#    'url': 'http://en.wikipedia.org/wiki/Black_Sea',
#    'pageRank': 0.0016507961374971547,
#    'cosine': 0.19758102064842917,
#    'lang': 'en'},
#   {'title': 'World War II',
#    'url': 'http://en.wikipedia.org/wiki/World_War_II',
#    'pageRank': 0.0016169805923597577,
#    'cosine': 0.24829532881266386,
#    'lang': 'en'},
#   {'title': 'Roman Forum',
#    'url': 'http://en.wikipedia.org/wiki/Roman_Forum',
#    'pageRank': 0.0016141911644866852,
#    'cosine': 0.22412397278246204,
#    'lang': 'en'},
#   {'title': 'Indigenous peoples of the Americas',
#    'url': 'http://en.wikipedia.org/wiki/Indigenous_peoples_of_the_Americas',
#    'pageRank': 0.0016048817570528291,
#    'cosine': 0.25746772254098954,
#    'lang': 'en'},
#   {'title': 'World War I',
#    'url': 'http://en.wikipedia.org/wiki/World_War_I',
#    'pageRank': 0.0015940799792024053,
#    'cosine': 0.28599097876969704,
#    'lang': 'en'},
#   {'title': 'Hera',
#    'url': 'http://en.wikipedia.org/wiki/Hera',
#    'pageRank': 0.0015781112759245203,
#    'cosine': 0.17226566032090224,
#    'lang': 'en'},
#   {'title': 'Music',
#    'url': 'http://en.wikipedia.org/wiki/Music',
#    'pageRank': 0.001566260285599245,
#    'cosine': 0.2422027603918984,
#    'lang': 'en'},
#   {'title': 'Politics',
#    'url': 'http://en.wikipedia.org/wiki/Politics',
#    'pageRank': 0.0015468397409083587,
#    'cosine': 0.23941956415536883,
#    'lang': 'en'},
#   {'title': 'Excavation (archaeology)',
#    'url': 'http://en.wikipedia.org/wiki/Excavation_(archaeology)',
#    'pageRank': 0.001537444862786543,
#    'cosine': 0.23913857553652612,
#    'lang': 'en'},
#   {'title': 'Justice',
#    'url': 'http://en.wikipedia.org/wiki/Justice',
#    'pageRank': 0.0015106646427266608,
#    'cosine': 0.2615308286756574,
#    'lang': 'en'},
#   {'title': 'Construction',
#    'url': 'http://en.wikipedia.org/wiki/Construction',
#    'pageRank': 0.001507664317353702,
#    'cosine': 0.22319800372903717,
#    'lang': 'en'},
#   {'title': "St. Peter's Basilica",
#    'url': 'http://en.wikipedia.org/wiki/St%2e_Peter%27s_Basilica',
#    'pageRank': 0.001493166967750368,
#    'cosine': 0.2652850032712951,
#    'lang': 'en'},
#   {'title': 'Cremation',
#    'url': 'http://en.wikipedia.org/wiki/Cremation',
#    'pageRank': 0.001484957655942921,
#    'cosine': 0.22473485595699622,
#    'lang': 'en'},
#   {'title': 'History',
#    'url': 'http://en.wikipedia.org/wiki/History',
#    'pageRank': 0.0014817900915661383,
#    'cosine': 0.2739179332438741,
#    'lang': 'en'},
#   {'title': 'Ancient Roman architecture',
#    'url': 'http://en.wikipedia.org/wiki/Ancient_Roman_architecture',
#    'pageRank': 0.0014772236077924008,
#    'cosine': 0.3103278400534977,
#    'lang': 'en'},
#   {'title': 'Anno Domini',
#    'url': 'http://en.wikipedia.org/wiki/Anno_Domini',
#    'pageRank': 0.0014719635624400975,
#    'cosine': 0.19781137628433765,
#    'lang': 'en'},
#   {'title': 'Holy See',
#    'url': 'http://en.wikipedia.org/wiki/Holy_See',
#    'pageRank': 0.001467600785277054,
#    'cosine': 0.19497132282564908,
#    'lang': 'en'},
#   {'title': 'House',
#    'url': 'http://en.wikipedia.org/wiki/House',
#    'pageRank': 0.0014662889427947971,
#    'cosine': 0.23865940256583462,
#    'lang': 'en'},
#   {'title': 'Water',
#    'url': 'http://en.wikipedia.org/wiki/Water',
#    'pageRank': 0.0014495727787557685,
#    'cosine': 0.22389967095188798,
#    'lang': 'en'},
#   {'title': 'Scientific method',
#    'url': 'http://en.wikipedia.org/wiki/Scientific_method',
#    'pageRank': 0.0014418125008711456,
#    'cosine': 0.3068871625308146,
#    'lang': 'en'},
#   {'title': 'Textile',
#    'url': 'http://en.wikipedia.org/wiki/Textile',
#    'pageRank': 0.001434765130082446,
#    'cosine': 0.18361378768331596,
#    'lang': 'en'},
#   {'title': 'Hermetic seal',
#    'url': 'http://en.wikipedia.org/wiki/Hermetic_seal',
#    'pageRank': 0.0014330228054529974,
#    'cosine': 0.1420598609365879,
#    'lang': 'en'},
#   {'title': 'Building',
#    'url': 'http://en.wikipedia.org/wiki/Building',
#    'pageRank': 0.0014239001162581436,
#    'cosine': 0.18935878745861856,
#    'lang': 'en'},
#   {'title': 'Monument',
#    'url': 'http://en.wikipedia.org/wiki/Monument',
#    'pageRank': 0.0014210727862546913,
#    'cosine': 0.242248506732765,
#    'lang': 'en'},
#   {'title': 'Time',
#    'url': 'http://en.wikipedia.org/wiki/Time',
#    'pageRank': 0.0013968766118885553,
#    'cosine': 0.3017937553795153,
#    'lang': 'en'},
#   {'title': 'Sense',
#    'url': 'http://en.wikipedia.org/wiki/Sense',
#    'pageRank': 0.0013968135210855504,
#    'cosine': 0.26176269414267145,
#    'lang': 'en'},
#   {'title': 'Music hall',
#    'url': 'http://en.wikipedia.org/wiki/Music_hall',
#    'pageRank': 0.0013942644106661394,
#    'cosine': 0.20710779205507238,
#    'lang': 'en'},
#   {'title': 'Navigation',
#    'url': 'http://en.wikipedia.org/wiki/Navigation',
#    'pageRank': 0.0013799193926563957,
#    'cosine': 0.21992641473161872,
#    'lang': 'en'},
#   {'title': 'Theatre',
#    'url': 'http://en.wikipedia.org/wiki/Theatre',
#    'pageRank': 0.0013788904659461632,
#    'cosine': 0.25993480519865264,
#    'lang': 'en'},
#   {'title': 'Absolute monarchy',
#    'url': 'http://en.wikipedia.org/wiki/Absolute_monarchy',
#    'pageRank': 0.0013745492288008351,
#    'cosine': 0.2123072813111192,
#    'lang': 'en'},
#   {'title': 'Caliphate',
#    'url': 'http://en.wikipedia.org/wiki/Caliphate',
#    'pageRank': 0.0013704226877925218,
#    'cosine': 0.26568173431825565,
#    'lang': 'en'},
#   {'title': 'Light',
#    'url': 'http://en.wikipedia.org/wiki/Light',
#    'pageRank': 0.001368391813947159,
#    'cosine': 0.22081187908447308,
#    'lang': 'en'},
#   {'title': 'Head of state',
#    'url': 'http://en.wikipedia.org/wiki/Head_of_state',
#    'pageRank': 0.0013650386009247696,
#    'cosine': 0.2672274041556534,
#    'lang': 'en'},
#   {'title': 'Rationalism',
#    'url': 'http://en.wikipedia.org/wiki/Rationalism',
#    'pageRank': 0.001348362775637323,
#    'cosine': 0.27743007121515706,
#    'lang': 'en'},
#   {'title': 'Google Earth',
#    'url': 'http://en.wikipedia.org/wiki/Google_Earth',
#    'pageRank': 0.0013460763038550638,
#    'cosine': 0.12940588061041897,
#    'lang': 'en'},
#   {'title': 'Franco-Prussian War',
#    'url': 'http://en.wikipedia.org/wiki/Franco-Prussian_War',
#    'pageRank': 0.001346064259837163,
#    'cosine': 0.22907970853426074,
#    'lang': 'en'},
#   {'title': "Hadrian's Wall",
#    'url': 'http://en.wikipedia.org/wiki/Hadrian%27s_Wall',
#    'pageRank': 0.0013416646924345242,
#    'cosine': 0.19442953891477913,
#    'lang': 'en'},
#   {'title': 'Circa',
#    'url': 'http://en.wikipedia.org/wiki/Circa',
#    'pageRank': 0.0013245950489813479,
#    'cosine': 0.06271969042175222,
#    'lang': 'en'},
#   {'title': 'Perspective (graphical)',
#    'url': 'http://en.wikipedia.org/wiki/Perspective_(graphical)',
#    'pageRank': 0.001323002401177422,
#    'cosine': 0.22855583263194948,
#    'lang': 'en'},
#   {'title': 'Soul',
#    'url': 'http://en.wikipedia.org/wiki/Soul',
#    'pageRank': 0.0013165251711783278,
#    'cosine': 0.23806138261205556,
#    'lang': 'en'},
#   {'title': 'Canning',
#    'url': 'http://en.wikipedia.org/wiki/Canning',
#    'pageRank': 0.0013121490309785675,
#    'cosine': 0.20382335722427986,
#    'lang': 'en'},
#   {'title': 'Roman citizenship',
#    'url': 'http://en.wikipedia.org/wiki/Roman_citizenship',
#    'pageRank': 0.0013104669733007433,
#    'cosine': 0.19365540852410942,
#    'lang': 'en'},
#   {'title': 'Stained glass',
#    'url': 'http://en.wikipedia.org/wiki/Stained_glass',
#    'pageRank': 0.0013095039311152375,
#    'cosine': 0.16599737089152133,
#    'lang': 'en'},
#   {'title': 'Founding of Rome',
#    'url': 'http://en.wikipedia.org/wiki/Founding_of_Rome',
#    'pageRank': 0.001309263681385328,
#    'cosine': 0.26185064954870596,
#    'lang': 'en'},
#   {'title': 'Poverty',
#    'url': 'http://en.wikipedia.org/wiki/Poverty',
#    'pageRank': 0.0013021746638844354,
#    'cosine': 0.2499705901622043,
#    'lang': 'en'},
#   {'title': 'Google',
#    'url': 'http://en.wikipedia.org/wiki/Google',
#    'pageRank': 0.0012954751906384039,
#    'cosine': 0.14866337622932912,
#    'lang': 'en'},
#   {'title': 'Sister city',
#    'url': 'http://en.wikipedia.org/wiki/Sister_city',
#    'pageRank': 0.001263796774759772,
#    'cosine': 0.1768070599692937,
#    'lang': 'en'},
#   {'title': 'Court',
#    'url': 'http://en.wikipedia.org/wiki/Court',
#    'pageRank': 0.0012441983326692855,
#    'cosine': 0.1587808675556546,
#    'lang': 'en'},
#   {'title': 'Space',
#    'url': 'http://en.wikipedia.org/wiki/Space',
#    'pageRank': 0.0012366713212598622,
#    'cosine': 0.2574720962430597,
#    'lang': 'en'},
#   {'title': 'Emigration',
#    'url': 'http://en.wikipedia.org/wiki/Emigration',
#    'pageRank': 0.00123445829238827,
#    'cosine': 0.14826049095763807,
#    'lang': 'en'},
#   {'title': 'Life',
#    'url': 'http://en.wikipedia.org/wiki/Life',
#    'pageRank': 0.0012339840342346774,
#    'cosine': 0.2887660399060021,
#    'lang': 'en'},
#   {'title': 'Gregorian calendar',
#    'url': 'http://en.wikipedia.org/wiki/Gregorian_calendar',
#    'pageRank': 0.0012329525145692197,
#    'cosine': 0.19712383865435196,
#    'lang': 'en'},
#   {'title': 'Heraldry',
#    'url': 'http://en.wikipedia.org/wiki/Heraldry',
#    'pageRank': 0.0012217464941412532,
#    'cosine': 0.2281746030766854,
#    'lang': 'en'},
#   {'title': 'Cartography',
#    'url': 'http://en.wikipedia.org/wiki/Cartography',
#    'pageRank': 0.0012052130000114205,
#    'cosine': 0.2465544857811703,
#    'lang': 'en'},
#   {'title': 'Diminutive',
#    'url': 'http://en.wikipedia.org/wiki/Diminutive',
#    'pageRank': 0.0012016299485850877,
#    'cosine': 0.10688903218127818,
#    'lang': 'en'},
#   {'title': 'Mind',
#    'url': 'http://en.wikipedia.org/wiki/Mind',
#    'pageRank': 0.0011957870193007396,
#    'cosine': 0.25151767576330286,
#    'lang': 'en'},
#   {'title': 'Information',
#    'url': 'http://en.wikipedia.org/wiki/Information',
#    'pageRank': 0.0011918646924416456,
#    'cosine': 0.22184924604033232,
#    'lang': 'en'},
#   {'title': 'Anthropomorphism',
#    'url': 'http://en.wikipedia.org/wiki/Anthropomorphism',
#    'pageRank': 0.0011896806107651757,
#    'cosine': 0.2568007464517041,
#    'lang': 'en'},
#   {'title': 'Photography',
#    'url': 'http://en.wikipedia.org/wiki/Photography',
#    'pageRank': 0.0011778838585665857,
#    'cosine': 0.22731832857278095,
#    'lang': 'en'},
#   {'title': 'Environmentalism',
#    'url': 'http://en.wikipedia.org/wiki/Environmentalism',
#    'pageRank': 0.001176818276362753,
#    'cosine': 0.2450188360391272,
#    'lang': 'en'},
#   {'title': 'Knowledge',
#    'url': 'http://en.wikipedia.org/wiki/Knowledge',
#    'pageRank': 0.001165491455515877,
#    'cosine': 0.21992354755978105,
#    'lang': 'en'},
#   {'title': 'Interior design',
#    'url': 'http://en.wikipedia.org/wiki/Interior_design',
#    'pageRank': 0.0011557872104928644,
#    'cosine': 0.2352923694570443,
#    'lang': 'en'},
#   {'title': 'Auditorium',
#    'url': 'http://en.wikipedia.org/wiki/Auditorium',
#    'pageRank': 0.0011168231610391998,
#    'cosine': 0.15014555821700018,
#    'lang': 'en'},
#   {'title': 'City',
#    'url': 'http://en.wikipedia.org/wiki/City',
#    'pageRank': 0.0011134305091114697,
#    'cosine': 0.29682176589817966,
#    'lang': 'en'},
#   {'title': 'Bone',
#    'url': 'http://en.wikipedia.org/wiki/Bone',
#    'pageRank': 0.0011131894091061852,
#    'cosine': 0.15837760458700278,
#    'lang': 'en'},
#   {'title': 'Lawsuit',
#    'url': 'http://en.wikipedia.org/wiki/Lawsuit',
#    'pageRank': 0.0011064177466224635,
#    'cosine': 0.2385836104271846,
#    'lang': 'en'},
#   {'title': 'Stratum',
#    'url': 'http://en.wikipedia.org/wiki/Stratum',
#    'pageRank': 0.001080256636807523,
#    'cosine': 0.11397011164909075,
#    'lang': 'en'},
#   {'title': 'Civitas',
#    'url': 'http://en.wikipedia.org/wiki/Civitas',
#    'pageRank': 0.0010458766989707169,
#    'cosine': 0.1822229672839839,
#    'lang': 'en'},
#   {'title': 'Nun',
#    'url': 'http://en.wikipedia.org/wiki/Nun',
#    'pageRank': 0.0010310238145534423,
#    'cosine': 0.21727206090023346,
#    'lang': 'en'},
#   {'title': 'Door',
#    'url': 'http://en.wikipedia.org/wiki/Door',
#    'pageRank': 0.001029263919871693,
#    'cosine': 0.18456911827767158,
#    'lang': 'en'},
#   {'title': 'Hope',
#    'url': 'http://en.wikipedia.org/wiki/Hope',
#    'pageRank': 0.0010258740095466623,
#    'cosine': 0.24188607836560608,
#    'lang': 'en'},
#   {'title': 'Public art',
#    'url': 'http://en.wikipedia.org/wiki/Public_art',
#    'pageRank': 0.0010247876475297543,
#    'cosine': 0.23366983463870292,
#    'lang': 'en'},
#   {'title': 'Decomposition',
#    'url': 'http://en.wikipedia.org/wiki/Decomposition',
#    'pageRank': 0.0010134473814363242,
#    'cosine': 0.21005411886034717,
#    'lang': 'en'},
#   {'title': 'Number',
#    'url': 'http://en.wikipedia.org/wiki/Number',
#    'pageRank': 0.0010024477151369068,
#    'cosine': 0.21322476797616507,
#    'lang': 'en'},
#   {'title': 'Mansion',
#    'url': 'http://en.wikipedia.org/wiki/Mansion',
#    'pageRank': 0.0009908972137165988,
#    'cosine': 0.21651518114725396,
#    'lang': 'en'},
#   {'title': '1755 Lisbon earthquake',
#    'url': 'http://en.wikipedia.org/wiki/1755_Lisbon_earthquake',
#    'pageRank': 0.0009698849663484052,
#    'cosine': 0.2191778610081852,
#    'lang': 'en'},
#   {'title': 'Leisure',
#    'url': 'http://en.wikipedia.org/wiki/Leisure',
#    'pageRank': 0.0009619963322051146,
#    'cosine': 0.18972403093661655,
#    'lang': 'en'},
#   {'title': 'Sawmill',
#    'url': 'http://en.wikipedia.org/wiki/Sawmill',
#    'pageRank': 0.0009384078987321306,
#    'cosine': 0.18009235919987288,
#    'lang': 'en'},
#   {'title': 'Triangle',
#    'url': 'http://en.wikipedia.org/wiki/Triangle',
#    'pageRank': 0.0009353553509518436,
#    'cosine': 0.1780837115810943,
#    'lang': 'en'},
#   {'title': 'Seawall',
#    'url': 'http://en.wikipedia.org/wiki/Seawall',
#    'pageRank': 0.0009317181338775957,
#    'cosine': 0.19309876237609572,
#    'lang': 'en'},
#   {'title': 'Revelation',
#    'url': 'http://en.wikipedia.org/wiki/Revelation',
#    'pageRank': 0.0009206364469185057,
#    'cosine': 0.22999921996810066,
#    'lang': 'en'},
#   {'title': 'Cognition',
#    'url': 'http://en.wikipedia.org/wiki/Cognition',
#    'pageRank': 0.0009167009956869486,
#    'cosine': 0.22267267396524687,
#    'lang': 'en'},
#   {'title': 'Professor',
#    'url': 'http://en.wikipedia.org/wiki/Professor',
#    'pageRank': 0.0009163595150894241,
#    'cosine': 0.16374449544056477,
#    'lang': 'en'},
#   {'title': 'Beam (structure)',
#    'url': 'http://en.wikipedia.org/wiki/Beam_(structure)',
#    'pageRank': 0.0009138002228483707,
#    'cosine': 0.1349593075476274,
#    'lang': 'en'},
#   {'title': 'Half-life',
#    'url': 'http://en.wikipedia.org/wiki/Half-life',
#    'pageRank': 0.0009129282499247208,
#    'cosine': 0.13474175169029864,
#    'lang': 'en'},
#   {'title': 'Determinism',
#    'url': 'http://en.wikipedia.org/wiki/Determinism',
#    'pageRank': 0.0008887747419643942,
#    'cosine': 0.25290352596453697,
#    'lang': 'en'},
#   {'title': 'Banknote',
#    'url': 'http://en.wikipedia.org/wiki/Banknote',
#    'pageRank': 0.000887987447124895,
#    'cosine': 0.21127925161575475,
#    'lang': 'en'},
#   {'title': 'Hoard',
#    'url': 'http://en.wikipedia.org/wiki/Hoard',
#    'pageRank': 0.0008865167395297915,
#    'cosine': 0.07686266919454374,
#    'lang': 'en'},
#   {'title': 'Intimate relationship',
#    'url': 'http://en.wikipedia.org/wiki/Intimate_relationship',
#    'pageRank': 0.0008756791781863008,
#    'cosine': 0.22026298463023689,
#    'lang': 'en'},
#   {'title': 'Orbit',
#    'url': 'http://en.wikipedia.org/wiki/Orbit',
#    'pageRank': 0.00086365873235368,
#    'cosine': 0.22421145226756264,
#    'lang': 'en'},
#   {'title': 'Classical mechanics',
#    'url': 'http://en.wikipedia.org/wiki/Classical_mechanics',
#    'pageRank': 0.0008608505166181186,
#    'cosine': 0.2121669873166339,
#    'lang': 'en'},
#   {'title': 'Convention (norm)',
#    'url': 'http://en.wikipedia.org/wiki/Convention_(norm)',
#    'pageRank': 0.0008577115023005728,
#    'cosine': 0.19319696985340717,
#    'lang': 'en'},
#   {'title': 'Android (operating system)',
#    'url': 'http://en.wikipedia.org/wiki/Android_(operating_system)',
#    'pageRank': 0.0008388490191911401,
#    'cosine': 0.1334148478475758,
#    'lang': 'en'},
#   {'title': 'Debate',
#    'url': 'http://en.wikipedia.org/wiki/Debate',
#    'pageRank': 0.0008365598106211138,
#    'cosine': 0.2023126404666659,
#    'lang': 'en'},
#   {'title': 'States of Germany',
#    'url': 'http://en.wikipedia.org/wiki/States_of_Germany',
#    'pageRank': 0.0008345743315678053,
#    'cosine': 0.20874743307230503,
#    'lang': 'en'},
#   {'title': 'Child abandonment',
#    'url': 'http://en.wikipedia.org/wiki/Child_abandonment',
#    'pageRank': 0.0008226437276308301,
#    'cosine': 0.24466395911063074,
#    'lang': 'en'},
#   {'title': 'Symbiosis',
#    'url': 'http://en.wikipedia.org/wiki/Symbiosis',
#    'pageRank': 0.0008055513487893248,
#    'cosine': 0.21653634411729575,
#    'lang': 'en'},
#   {'title': 'Street',
#    'url': 'http://en.wikipedia.org/wiki/Street',
#    'pageRank': 0.0008015379125250906,
#    'cosine': 0.21390245603352487,
#    'lang': 'en'},
#   {'title': 'Fact',
#    'url': 'http://en.wikipedia.org/wiki/Fact',
#    'pageRank': 0.0007979679955828611,
#    'cosine': 0.255090747699011,
#    'lang': 'en'},
#   {'title': 'Witness',
#    'url': 'http://en.wikipedia.org/wiki/Witness',
#    'pageRank': 0.0007844500367621678,
#    'cosine': 0.19392077732358493,
#    'lang': 'en'},
#   {'title': 'Multiverse',
#    'url': 'http://en.wikipedia.org/wiki/Multiverse',
#    'pageRank': 0.0007819466003039575,
#    'cosine': 0.2030278987262624,
#    'lang': 'en'}]}

# %%
wikification_filter(res, "CLASSIC", in_place=False)
# Out:
# {'concepts': [{'title': 'Herculaneum',
#    'url': 'http://en.wikipedia.org/wiki/Herculaneum',
#    'pageRank': 0.03739412937379306,
#    'cosine': 0.6801656584737229,
#    'lang': 'en',
#    'wikiDataItemId': 'Q178813',
#    'wikiDataClasses': [{'itemId': 'Q17431399', 'enLabel': 'national museum'},
#     {'itemId': 'Q839954', 'enLabel': 'archaeological site'},
#     {'itemId': 'Q33506', 'enLabel': 'museum'},
#     {'itemId': 'Q1291195', 'enLabel': 'find spot'},
#     {'itemId': 'Q15642541', 'enLabel': 'human-geographic territorial entity'},
#     {'itemId': 'Q14524493', 'enLabel': 'terrain'},
#     {'itemId': 'Q1030034', 'enLabel': 'GLAM'},
#     {'itemId': 'Q13226383', 'enLabel': 'facility'},
#     {'itemId': 'Q5193377', 'enLabel': 'cultural institution'},
#     {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#     {'itemId': 'Q1496967', 'enLabel': 'territorial entity'},
#     {'itemId': 'Q16686448', 'enLabel': 'artificial entity'},
#     {'itemId': 'Q271669', 'enLabel': 'landform'},
#     {'itemId': 'Q2221906', 'enLabel': 'geographic location'},
#     {'itemId': 'Q178706', 'enLabel': 'institution'},
#     {'itemId': 'Q223557', 'enLabel': 'physical object'},
#     {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#     {'itemId': 'Q82794', 'enLabel': 'geographic region'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q12766313', 'enLabel': 'geomorphological unit'},
#     {'itemId': 'Q17334923', 'enLabel': 'location'},
#     {'itemId': 'Q43229', 'enLabel': 'organization'},
#     {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#     {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#     {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#     {'itemId': 'Q24229398', 'enLabel': 'agent'},
#     {'itemId': 'Q16334295', 'enLabel': 'group of humans'},
#     {'itemId': 'Q16513015', 'enLabel': 'order'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q30060700', 'enLabel': 'object of science'},
#     {'itemId': 'Q23958946', 'enLabel': 'individual'},
#     {'itemId': 'Q1789452', 'enLabel': 'criterion'},
#     {'itemId': 'Q16334298', 'enLabel': 'living thing group'},
#     {'itemId': 'Q3505845', 'enLabel': 'state'},
#     {'itemId': 'Q6671777', 'enLabel': 'structure'},
#     {'itemId': 'Q1921834', 'enLabel': 'feature'},
#     {'itemId': 'Q16887380', 'enLabel': 'group'},
#     {'itemId': 'Q517966', 'enLabel': 'structure'},
#     {'itemId': 'Q937228', 'enLabel': 'property'},
#     {'itemId': 'Q483247', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q17553950', 'enLabel': 'object'},
#     {'itemId': 'Q714737', 'enLabel': 'category of being'},
#     {'itemId': 'Q1207505', 'enLabel': 'quality'},
#     {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#     {'itemId': 'Q16722960', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q151885', 'enLabel': 'concept'},
#     {'itemId': 'Q26907166', 'enLabel': 'temporal entity'},
#     {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#     {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#     {'itemId': 'Q4393498', 'enLabel': 'representation'}],
#    'wikiDataClassIds': ['Q17431399',
#     'Q839954',
#     'Q33506',
#     'Q1291195',
#     'Q15642541',
#     'Q14524493',
#     'Q1030034',
#     'Q13226383',
#     'Q5193377',
#     'Q618123',
#     'Q1496967',
#     'Q16686448',
#     'Q271669',
#     'Q2221906',
#     'Q178706',
#     'Q223557',
#     'Q58416391',
#     'Q82794',
#     'Q35120',
#     'Q12766313',
#     'Q17334923',
#     'Q43229',
#     'Q4406616',
#     'Q1454986',
#     'Q58415929',
#     'Q24229398',
#     'Q16334295',
#     'Q16513015',
#     'Q488383',
#     'Q58778',
#     'Q30060700',
#     'Q23958946',
#     'Q1789452',
#     'Q16334298',
#     'Q3505845',
#     'Q6671777',
#     'Q1921834',
#     'Q16887380',
#     'Q517966',
#     'Q937228',
#     'Q483247',
#     'Q17553950',
#     'Q714737',
#     'Q1207505',
#     'Q1190554',
#     'Q16722960',
#     'Q151885',
#     'Q26907166',
#     'Q7184903',
#     'Q2145290',
#     'Q4393498'],
#    'dbPediaTypes': ['Place', 'WorldHeritageSite'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Herculaneum'},
#   {'title': 'Pompeii',
#    'url': 'http://en.wikipedia.org/wiki/Pompeii',
#    'pageRank': 0.018291090534386135,
#    'cosine': 0.5094460836140102,
#    'lang': 'en',
#    'wikiDataItemId': 'Q43332',
#    'wikiDataClasses': [{'itemId': 'Q15661340', 'enLabel': 'ancient city'},
#     {'itemId': 'Q839954', 'enLabel': 'archaeological site'},
#     {'itemId': 'Q17431399', 'enLabel': 'national museum'},
#     {'itemId': 'Q2974842', 'enLabel': 'lost city'},
#     {'itemId': 'Q1291195', 'enLabel': 'find spot'},
#     {'itemId': 'Q15642541', 'enLabel': 'human-geographic territorial entity'},
#     {'itemId': 'Q14524493', 'enLabel': 'terrain'},
#     {'itemId': 'Q33506', 'enLabel': 'museum'},
#     {'itemId': 'Q74047', 'enLabel': 'ghost town'},
#     {'itemId': 'Q515', 'enLabel': 'city'},
#     {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#     {'itemId': 'Q1496967', 'enLabel': 'territorial entity'},
#     {'itemId': 'Q16686448', 'enLabel': 'artificial entity'},
#     {'itemId': 'Q271669', 'enLabel': 'landform'},
#     {'itemId': 'Q1030034', 'enLabel': 'GLAM'},
#     {'itemId': 'Q13226383', 'enLabel': 'facility'},
#     {'itemId': 'Q5193377', 'enLabel': 'cultural institution'},
#     {'itemId': 'Q22674925', 'enLabel': 'former populated place'},
#     {'itemId': 'Q486972', 'enLabel': 'human settlement'},
#     {'itemId': 'Q177634', 'enLabel': 'community'},
#     {'itemId': 'Q7930989', 'enLabel': 'city/town'},
#     {'itemId': 'Q702492', 'enLabel': 'urban area'},
#     {'itemId': 'Q223557', 'enLabel': 'physical object'},
#     {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#     {'itemId': 'Q82794', 'enLabel': 'geographic region'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q12766313', 'enLabel': 'geomorphological unit'},
#     {'itemId': 'Q2221906', 'enLabel': 'geographic location'},
#     {'itemId': 'Q178706', 'enLabel': 'institution'},
#     {'itemId': 'Q15893266', 'enLabel': 'former entity'},
#     {'itemId': 'Q874405', 'enLabel': 'social group'},
#     {'itemId': 'Q16334295', 'enLabel': 'group of humans'},
#     {'itemId': 'Q15042037', 'enLabel': 'statistical territorial entity'},
#     {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#     {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#     {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#     {'itemId': 'Q17334923', 'enLabel': 'location'},
#     {'itemId': 'Q43229', 'enLabel': 'organization'},
#     {'itemId': 'Q19829125', 'enLabel': 'absence'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q7887142', 'enLabel': 'unit of analysis'},
#     {'itemId': 'Q16334298', 'enLabel': 'living thing group'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q30060700', 'enLabel': 'object of science'},
#     {'itemId': 'Q24229398', 'enLabel': 'agent'},
#     {'itemId': 'Q16513015', 'enLabel': 'order'},
#     {'itemId': 'Q16889133', 'enLabel': 'class'},
#     {'itemId': 'Q6671777', 'enLabel': 'structure'},
#     {'itemId': 'Q4330518', 'enLabel': 'research object'},
#     {'itemId': 'Q2198779', 'enLabel': 'unit'},
#     {'itemId': 'Q16887380', 'enLabel': 'group'},
#     {'itemId': 'Q517966', 'enLabel': 'structure'},
#     {'itemId': 'Q23958946', 'enLabel': 'individual'},
#     {'itemId': 'Q1789452', 'enLabel': 'criterion'},
#     {'itemId': 'Q3505845', 'enLabel': 'state'},
#     {'itemId': 'Q5127848', 'enLabel': 'class'},
#     {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#     {'itemId': 'Q17553950', 'enLabel': 'object'},
#     {'itemId': 'Q1921834', 'enLabel': 'feature'},
#     {'itemId': 'Q937228', 'enLabel': 'property'},
#     {'itemId': 'Q483247', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q714737', 'enLabel': 'category of being'},
#     {'itemId': 'Q1207505', 'enLabel': 'quality'},
#     {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#     {'itemId': 'Q16722960', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q151885', 'enLabel': 'concept'},
#     {'itemId': 'Q26907166', 'enLabel': 'temporal entity'},
#     {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#     {'itemId': 'Q4393498', 'enLabel': 'representation'}],
#    'wikiDataClassIds': ['Q15661340',
#     'Q839954',
#     'Q17431399',
#     'Q2974842',
#     'Q1291195',
#     'Q15642541',
#     'Q14524493',
#     'Q33506',
#     'Q74047',
#     'Q515',
#     'Q618123',
#     'Q1496967',
#     'Q16686448',
#     'Q271669',
#     'Q1030034',
#     'Q13226383',
#     'Q5193377',
#     'Q22674925',
#     'Q486972',
#     'Q177634',
#     'Q7930989',
#     'Q702492',
#     'Q223557',
#     'Q58416391',
#     'Q82794',
#     'Q35120',
#     'Q12766313',
#     'Q2221906',
#     'Q178706',
#     'Q15893266',
#     'Q874405',
#     'Q16334295',
#     'Q15042037',
#     'Q4406616',
#     'Q1454986',
#     'Q58415929',
#     'Q17334923',
#     'Q43229',
#     'Q19829125',
#     'Q58778',
#     'Q7887142',
#     'Q16334298',
#     'Q488383',
#     'Q30060700',
#     'Q24229398',
#     'Q16513015',
#     'Q16889133',
#     'Q6671777',
#     'Q4330518',
#     'Q2198779',
#     'Q16887380',
#     'Q517966',
#     'Q23958946',
#     'Q1789452',
#     'Q3505845',
#     'Q5127848',
#     'Q7184903',
#     'Q17553950',
#     'Q1921834',
#     'Q937228',
#     'Q483247',
#     'Q714737',
#     'Q1207505',
#     'Q1190554',
#     'Q16722960',
#     'Q151885',
#     'Q26907166',
#     'Q2145290',
#     'Q4393498'],
#    'dbPediaTypes': ['Place', 'WorldHeritageSite'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Pompeii'},
#   {'title': 'Samnites',
#    'url': 'http://en.wikipedia.org/wiki/Samnites',
#    'pageRank': 0.0038154357845719433,
#    'cosine': 0.14869798909851106,
#    'lang': 'en',
#    'wikiDataItemId': 'Q500272',
#    'wikiDataClasses': [{'itemId': 'Q2472587', 'enLabel': 'people'},
#     {'itemId': 'Q874405', 'enLabel': 'social group'},
#     {'itemId': 'Q16334295', 'enLabel': 'group of humans'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q7887142', 'enLabel': 'unit of analysis'},
#     {'itemId': 'Q16334298', 'enLabel': 'living thing group'},
#     {'itemId': 'Q6671777', 'enLabel': 'structure'},
#     {'itemId': 'Q4330518', 'enLabel': 'research object'},
#     {'itemId': 'Q2198779', 'enLabel': 'unit'},
#     {'itemId': 'Q16887380', 'enLabel': 'group'},
#     {'itemId': 'Q517966', 'enLabel': 'structure'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#     {'itemId': 'Q17553950', 'enLabel': 'object'},
#     {'itemId': 'Q4406616', 'enLabel': 'concrete object'}],
#    'wikiDataClassIds': ['Q2472587',
#     'Q874405',
#     'Q16334295',
#     'Q58778',
#     'Q7887142',
#     'Q16334298',
#     'Q6671777',
#     'Q4330518',
#     'Q2198779',
#     'Q16887380',
#     'Q517966',
#     'Q35120',
#     'Q488383',
#     'Q7184903',
#     'Q17553950',
#     'Q4406616'],
#    'dbPediaTypes': ['PopulatedPlace', 'Place'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Sabellians'},
#   {'title': 'Lava',
#    'url': 'http://en.wikipedia.org/wiki/Lava',
#    'pageRank': 0.003630996714491836,
#    'cosine': 0.20049486484197385,
#    'lang': 'en',
#    'wikiDataItemId': 'Q40157',
#    'wikiDataClasses': [],
#    'wikiDataClassIds': [],
#    'dbPediaTypes': ['Agent', 'Organisation', 'Company', 'RecordLabel'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Lava'},
#   {'title': 'Mount Vesuvius',
#    'url': 'http://en.wikipedia.org/wiki/Mount_Vesuvius',
#    'pageRank': 0.003344867537362839,
#    'cosine': 0.3625857514945056,
#    'lang': 'en',
#    'wikiDataItemId': 'Q524',
#    'wikiDataClasses': [{'itemId': 'Q1330974', 'enLabel': 'active volcano'},
#     {'itemId': 'Q169358', 'enLabel': 'stratovolcano'},
#     {'itemId': 'Q8072', 'enLabel': 'volcano'},
#     {'itemId': 'Q8502', 'enLabel': 'mountain'},
#     {'itemId': 'Q29025902', 'enLabel': 'volcanic landform'},
#     {'itemId': 'Q14524493', 'enLabel': 'terrain'},
#     {'itemId': 'Q207326', 'enLabel': 'summit'},
#     {'itemId': 'Q35145263', 'enLabel': 'natural geographic object'},
#     {'itemId': 'Q271669', 'enLabel': 'landform'},
#     {'itemId': 'Q2221906', 'enLabel': 'geographic location'},
#     {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#     {'itemId': 'Q16686022', 'enLabel': 'natural physical object'},
#     {'itemId': 'Q12766313', 'enLabel': 'geomorphological unit'},
#     {'itemId': 'Q17334923', 'enLabel': 'location'},
#     {'itemId': 'Q223557', 'enLabel': 'physical object'},
#     {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#     {'itemId': 'Q29651224', 'enLabel': 'natural object'},
#     {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#     {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#     {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q1322005', 'enLabel': 'natural phenomenon'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q30060700', 'enLabel': 'object of science'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q483247', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q6671777', 'enLabel': 'structure'},
#     {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#     {'itemId': 'Q16722960', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q26907166', 'enLabel': 'temporal entity'}],
#    'wikiDataClassIds': ['Q1330974',
#     'Q169358',
#     'Q8072',
#     'Q8502',
#     'Q29025902',
#     'Q14524493',
#     'Q207326',
#     'Q35145263',
#     'Q271669',
#     'Q2221906',
#     'Q618123',
#     'Q16686022',
#     'Q12766313',
#     'Q17334923',
#     'Q223557',
#     'Q58416391',
#     'Q29651224',
#     'Q4406616',
#     'Q1454986',
#     'Q58415929',
#     'Q488383',
#     'Q1322005',
#     'Q58778',
#     'Q30060700',
#     'Q35120',
#     'Q483247',
#     'Q6671777',
#     'Q1190554',
#     'Q16722960',
#     'Q26907166'],
#    'dbPediaTypes': ['Place', 'Mountain', 'NaturalPlace', 'Volcano'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Mount_Vesuvius'},
#   {'title': 'Ancient Rome',
#    'url': 'http://en.wikipedia.org/wiki/Ancient_Rome',
#    'pageRank': 0.0031142185561927574,
#    'cosine': 0.2999609464376098,
#    'lang': 'en',
#    'wikiDataItemId': 'Q1747689',
#    'wikiDataClasses': [{'itemId': 'Q1620908', 'enLabel': 'historical region'},
#     {'itemId': 'Q3502482', 'enLabel': 'cultural region'},
#     {'itemId': 'Q28171280', 'enLabel': 'ancient civilization'},
#     {'itemId': 'Q3024240', 'enLabel': 'historical country'},
#     {'itemId': 'Q82794', 'enLabel': 'geographic region'},
#     {'itemId': 'Q15893266', 'enLabel': 'former entity'},
#     {'itemId': 'Q15642541', 'enLabel': 'human-geographic territorial entity'},
#     {'itemId': 'Q8432', 'enLabel': 'civilization'},
#     {'itemId': 'Q19953632',
#      'enLabel': 'former administrative territorial entity'},
#     {'itemId': 'Q6256', 'enLabel': 'country'},
#     {'itemId': 'Q7275', 'enLabel': 'state'},
#     {'itemId': 'Q2221906', 'enLabel': 'geographic location'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q19829125', 'enLabel': 'absence'},
#     {'itemId': 'Q1496967', 'enLabel': 'territorial entity'},
#     {'itemId': 'Q16686448', 'enLabel': 'artificial entity'},
#     {'itemId': 'Q8425', 'enLabel': 'society'},
#     {'itemId': 'Q56061', 'enLabel': 'administrative territorial entity'},
#     {'itemId': 'Q19832712', 'enLabel': 'historical administrative division'},
#     {'itemId': 'Q1048835', 'enLabel': 'political territorial entity'},
#     {'itemId': 'Q43229', 'enLabel': 'organization'},
#     {'itemId': 'Q177634', 'enLabel': 'community'},
#     {'itemId': 'Q155076', 'enLabel': 'juridical person'},
#     {'itemId': 'Q17334923', 'enLabel': 'location'},
#     {'itemId': 'Q16889133', 'enLabel': 'class'},
#     {'itemId': 'Q874405', 'enLabel': 'social group'},
#     {'itemId': 'Q4204519', 'enLabel': 'historical fact'},
#     {'itemId': 'Q24229398', 'enLabel': 'agent'},
#     {'itemId': 'Q16334295', 'enLabel': 'group of humans'},
#     {'itemId': 'Q16513015', 'enLabel': 'order'},
#     {'itemId': 'Q3778211', 'enLabel': 'legal person'},
#     {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#     {'itemId': 'Q5127848', 'enLabel': 'class'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q7887142', 'enLabel': 'unit of analysis'},
#     {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#     {'itemId': 'Q188572', 'enLabel': 'fact'},
#     {'itemId': 'Q192630', 'enLabel': 'past'},
#     {'itemId': 'Q23958946', 'enLabel': 'individual'},
#     {'itemId': 'Q1789452', 'enLabel': 'criterion'},
#     {'itemId': 'Q16334298', 'enLabel': 'living thing group'},
#     {'itemId': 'Q3505845', 'enLabel': 'state'},
#     {'itemId': 'Q830077', 'enLabel': 'subject'},
#     {'itemId': 'Q223557', 'enLabel': 'physical object'},
#     {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#     {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#     {'itemId': 'Q6671777', 'enLabel': 'structure'},
#     {'itemId': 'Q4330518', 'enLabel': 'research object'},
#     {'itemId': 'Q2198779', 'enLabel': 'unit'},
#     {'itemId': 'Q26907166', 'enLabel': 'temporal entity'},
#     {'itemId': 'Q42848', 'enLabel': 'data'},
#     {'itemId': 'Q2684591', 'enLabel': 'statement'},
#     {'itemId': 'Q11471', 'enLabel': 'time'},
#     {'itemId': 'Q1921834', 'enLabel': 'feature'},
#     {'itemId': 'Q16887380', 'enLabel': 'group'},
#     {'itemId': 'Q517966', 'enLabel': 'structure'},
#     {'itemId': 'Q937228', 'enLabel': 'property'},
#     {'itemId': 'Q483247', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#     {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#     {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q11028', 'enLabel': 'information'},
#     {'itemId': 'Q108163', 'enLabel': 'proposition'},
#     {'itemId': 'Q20937557', 'enLabel': 'series'},
#     {'itemId': 'Q17553950', 'enLabel': 'object'},
#     {'itemId': 'Q714737', 'enLabel': 'category of being'},
#     {'itemId': 'Q1207505', 'enLabel': 'quality'},
#     {'itemId': 'Q16722960', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q30060700', 'enLabel': 'object of science'},
#     {'itemId': 'Q41796', 'enLabel': 'sentence'},
#     {'itemId': 'Q246672', 'enLabel': 'mathematical object'},
#     {'itemId': 'Q151885', 'enLabel': 'concept'},
#     {'itemId': 'Q1786828', 'enLabel': 'constituent'},
#     {'itemId': 'Q15916540', 'enLabel': 'semantic unit'},
#     {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#     {'itemId': 'Q5371079', 'enLabel': 'emic unit'},
#     {'itemId': 'Q183046', 'enLabel': 'meaning'},
#     {'itemId': 'Q4393498', 'enLabel': 'representation'},
#     {'itemId': 'Q20817253', 'enLabel': 'linguistic unit'},
#     {'itemId': 'Q16877783', 'enLabel': 'meaning'},
#     {'itemId': 'Q4173967', 'enLabel': 'language unit'},
#     {'itemId': 'Q29651519', 'enLabel': 'mental object'}],
#    'wikiDataClassIds': ['Q1620908',
#     'Q3502482',
#     'Q28171280',
#     'Q3024240',
#     'Q82794',
#     'Q15893266',
#     'Q15642541',
#     'Q8432',
#     'Q19953632',
#     'Q6256',
#     'Q7275',
#     'Q2221906',
#     'Q35120',
#     'Q19829125',
#     'Q1496967',
#     'Q16686448',
#     'Q8425',
#     'Q56061',
#     'Q19832712',
#     'Q1048835',
#     'Q43229',
#     'Q177634',
#     'Q155076',
#     'Q17334923',
#     'Q16889133',
#     'Q874405',
#     'Q4204519',
#     'Q24229398',
#     'Q16334295',
#     'Q16513015',
#     'Q3778211',
#     'Q618123',
#     'Q5127848',
#     'Q58778',
#     'Q7887142',
#     'Q1190554',
#     'Q188572',
#     'Q192630',
#     'Q23958946',
#     'Q1789452',
#     'Q16334298',
#     'Q3505845',
#     'Q830077',
#     'Q223557',
#     'Q58416391',
#     'Q7184903',
#     'Q6671777',
#     'Q4330518',
#     'Q2198779',
#     'Q26907166',
#     'Q42848',
#     'Q2684591',
#     'Q11471',
#     'Q1921834',
#     'Q16887380',
#     'Q517966',
#     'Q937228',
#     'Q483247',
#     'Q4406616',
#     'Q1454986',
#     'Q58415929',
#     'Q488383',
#     'Q11028',
#     'Q108163',
#     'Q20937557',
#     'Q17553950',
#     'Q714737',
#     'Q1207505',
#     'Q16722960',
#     'Q30060700',
#     'Q41796',
#     'Q246672',
#     'Q151885',
#     'Q1786828',
#     'Q15916540',
#     'Q2145290',
#     'Q5371079',
#     'Q183046',
#     'Q4393498',
#     'Q20817253',
#     'Q16877783',
#     'Q4173967',
#     'Q29651519'],
#    'dbPediaTypes': ['PopulatedPlace',
#     'Place',
#     'Country',
#     'Territory',
#     'OldTerritory'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Ancient_Rome'},
#   {'title': 'Boscoreale',
#    'url': 'http://en.wikipedia.org/wiki/Boscoreale',
#    'pageRank': 0.003113899583083107,
#    'cosine': 0.24575084340794787,
#    'lang': 'en',
#    'wikiDataItemId': 'Q71845',
#    'wikiDataClasses': [{'itemId': 'Q747074', 'enLabel': 'comune of Italy'},
#     {'itemId': 'Q13221722',
#      'enLabel': 'third-level administrative country subdivision'},
#     {'itemId': 'Q2824645',
#      'enLabel': 'administrative territorial entity of Italy'},
#     {'itemId': 'Q15284', 'enLabel': 'municipality'},
#     {'itemId': 'Q1799794',
#      'enLabel': 'administrative territorial entity of a specific level'},
#     {'itemId': 'Q15916867',
#      'enLabel': 'administrative territorial entity of a single country'},
#     {'itemId': 'Q1048835', 'enLabel': 'political territorial entity'},
#     {'itemId': 'Q2097994', 'enLabel': 'municipal corporation'},
#     {'itemId': 'Q486972', 'enLabel': 'human settlement'},
#     {'itemId': 'Q56061', 'enLabel': 'administrative territorial entity'},
#     {'itemId': 'Q15642541', 'enLabel': 'human-geographic territorial entity'},
#     {'itemId': 'Q6501447', 'enLabel': 'local government'},
#     {'itemId': 'Q82794', 'enLabel': 'geographic region'},
#     {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#     {'itemId': 'Q177634', 'enLabel': 'community'},
#     {'itemId': 'Q1496967', 'enLabel': 'territorial entity'},
#     {'itemId': 'Q16686448', 'enLabel': 'artificial entity'},
#     {'itemId': 'Q7188', 'enLabel': 'government'},
#     {'itemId': 'Q43229', 'enLabel': 'organization'},
#     {'itemId': 'Q2221906', 'enLabel': 'geographic location'},
#     {'itemId': 'Q223557', 'enLabel': 'physical object'},
#     {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#     {'itemId': 'Q874405', 'enLabel': 'social group'},
#     {'itemId': 'Q16334295', 'enLabel': 'group of humans'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q7210356', 'enLabel': 'political organisation'},
#     {'itemId': 'Q895526', 'enLabel': 'organ'},
#     {'itemId': 'Q35798', 'enLabel': 'executive branch'},
#     {'itemId': 'Q24229398', 'enLabel': 'agent'},
#     {'itemId': 'Q16513015', 'enLabel': 'order'},
#     {'itemId': 'Q17334923', 'enLabel': 'location'},
#     {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#     {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#     {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q7887142', 'enLabel': 'unit of analysis'},
#     {'itemId': 'Q16334298', 'enLabel': 'living thing group'},
#     {'itemId': 'Q174834', 'enLabel': 'authority'},
#     {'itemId': 'Q2101636', 'enLabel': 'political power'},
#     {'itemId': 'Q15708736', 'enLabel': 'public authority'},
#     {'itemId': 'Q2324993', 'enLabel': 'state power'},
#     {'itemId': 'Q23958946', 'enLabel': 'individual'},
#     {'itemId': 'Q1789452', 'enLabel': 'criterion'},
#     {'itemId': 'Q3505845', 'enLabel': 'state'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q30060700', 'enLabel': 'object of science'},
#     {'itemId': 'Q6671777', 'enLabel': 'structure'},
#     {'itemId': 'Q4330518', 'enLabel': 'research object'},
#     {'itemId': 'Q2198779', 'enLabel': 'unit'},
#     {'itemId': 'Q16887380', 'enLabel': 'group'},
#     {'itemId': 'Q517966', 'enLabel': 'structure'},
#     {'itemId': 'Q25107', 'enLabel': 'power'},
#     {'itemId': 'Q2659904', 'enLabel': 'government organization'},
#     {'itemId': 'Q1125239', 'enLabel': 'public body'},
#     {'itemId': 'Q1921834', 'enLabel': 'feature'},
#     {'itemId': 'Q937228', 'enLabel': 'property'},
#     {'itemId': 'Q483247', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#     {'itemId': 'Q17553950', 'enLabel': 'object'},
#     {'itemId': 'Q18340964', 'enLabel': 'power'},
#     {'itemId': 'Q714737', 'enLabel': 'category of being'},
#     {'itemId': 'Q1207505', 'enLabel': 'quality'},
#     {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#     {'itemId': 'Q16722960', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q151885', 'enLabel': 'concept'},
#     {'itemId': 'Q26907166', 'enLabel': 'temporal entity'},
#     {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#     {'itemId': 'Q4393498', 'enLabel': 'representation'}],
#    'wikiDataClassIds': ['Q747074',
#     'Q13221722',
#     'Q2824645',
#     'Q15284',
#     'Q1799794',
#     'Q15916867',
#     'Q1048835',
#     'Q2097994',
#     'Q486972',
#     'Q56061',
#     'Q15642541',
#     'Q6501447',
#     'Q82794',
#     'Q618123',
#     'Q177634',
#     'Q1496967',
#     'Q16686448',
#     'Q7188',
#     'Q43229',
#     'Q2221906',
#     'Q223557',
#     'Q58416391',
#     'Q874405',
#     'Q16334295',
#     'Q35120',
#     'Q7210356',
#     'Q895526',
#     'Q35798',
#     'Q24229398',
#     'Q16513015',
#     'Q17334923',
#     'Q4406616',
#     'Q1454986',
#     'Q58415929',
#     'Q58778',
#     'Q7887142',
#     'Q16334298',
#     'Q174834',
#     'Q2101636',
#     'Q15708736',
#     'Q2324993',
#     'Q23958946',
#     'Q1789452',
#     'Q3505845',
#     'Q488383',
#     'Q30060700',
#     'Q6671777',
#     'Q4330518',
#     'Q2198779',
#     'Q16887380',
#     'Q517966',
#     'Q25107',
#     'Q2659904',
#     'Q1125239',
#     'Q1921834',
#     'Q937228',
#     'Q483247',
#     'Q7184903',
#     'Q17553950',
#     'Q18340964',
#     'Q714737',
#     'Q1207505',
#     'Q1190554',
#     'Q16722960',
#     'Q151885',
#     'Q26907166',
#     'Q2145290',
#     'Q4393498'],
#    'dbPediaTypes': ['City',
#     'Settlement',
#     'PopulatedPlace',
#     'Place',
#     'AdministrativeRegion',
#     'Region'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Boscoreale'},
#   {'title': 'Skeleton',
#    'url': 'http://en.wikipedia.org/wiki/Skeleton',
#    'pageRank': 0.0027404853711771584,
#    'cosine': 0.22432098003312076,
#    'lang': 'en',
#    'wikiDataItemId': 'Q7881',
#    'wikiDataClasses': [],
#    'wikiDataClassIds': [],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/Skeleton'},
#   {'title': 'Campania',
#    'url': 'http://en.wikipedia.org/wiki/Campania',
#    'pageRank': 0.002653586789565017,
#    'cosine': 0.28352691499769916,
#    'lang': 'en',
#    'wikiDataItemId': 'Q1438',
#    'wikiDataClasses': [{'itemId': 'Q16110', 'enLabel': 'region of Italy'},
#     {'itemId': 'Q2824645',
#      'enLabel': 'administrative territorial entity of Italy'},
#     {'itemId': 'Q10864048',
#      'enLabel': 'first-level administrative country subdivision'},
#     {'itemId': 'Q1048835', 'enLabel': 'political territorial entity'},
#     {'itemId': 'Q3455524', 'enLabel': 'administrative region'},
#     {'itemId': 'Q15916867',
#      'enLabel': 'administrative territorial entity of a single country'},
#     {'itemId': 'Q1799794',
#      'enLabel': 'administrative territorial entity of a specific level'},
#     {'itemId': 'Q15642541', 'enLabel': 'human-geographic territorial entity'},
#     {'itemId': 'Q56061', 'enLabel': 'administrative territorial entity'},
#     {'itemId': 'Q1496967', 'enLabel': 'territorial entity'},
#     {'itemId': 'Q16686448', 'enLabel': 'artificial entity'},
#     {'itemId': 'Q82794', 'enLabel': 'geographic region'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q2221906', 'enLabel': 'geographic location'},
#     {'itemId': 'Q17334923', 'enLabel': 'location'},
#     {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#     {'itemId': 'Q223557', 'enLabel': 'physical object'},
#     {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#     {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#     {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#     {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q30060700', 'enLabel': 'object of science'},
#     {'itemId': 'Q6671777', 'enLabel': 'structure'}],
#    'wikiDataClassIds': ['Q16110',
#     'Q2824645',
#     'Q10864048',
#     'Q1048835',
#     'Q3455524',
#     'Q15916867',
#     'Q1799794',
#     'Q15642541',
#     'Q56061',
#     'Q1496967',
#     'Q16686448',
#     'Q82794',
#     'Q35120',
#     'Q2221906',
#     'Q17334923',
#     'Q618123',
#     'Q223557',
#     'Q58416391',
#     'Q4406616',
#     'Q1454986',
#     'Q58415929',
#     'Q488383',
#     'Q58778',
#     'Q30060700',
#     'Q6671777'],
#    'dbPediaTypes': ['PopulatedPlace',
#     'Place',
#     'AdministrativeRegion',
#     'Region'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Campania'},
#   {'title': 'Naples',
#    'url': 'http://en.wikipedia.org/wiki/Naples',
#    'pageRank': 0.002491342969735601,
#    'cosine': 0.2410574134288819,
#    'lang': 'en',
#    'wikiDataItemId': 'Q2634',
#    'wikiDataClasses': [{'itemId': 'Q515', 'enLabel': 'city'},
#     {'itemId': 'Q747074', 'enLabel': 'comune of Italy'},
#     {'itemId': 'Q3024240', 'enLabel': 'historical country'},
#     {'itemId': 'Q1549591', 'enLabel': 'big city'},
#     {'itemId': 'Q486972', 'enLabel': 'human settlement'},
#     {'itemId': 'Q177634', 'enLabel': 'community'},
#     {'itemId': 'Q7930989', 'enLabel': 'city/town'},
#     {'itemId': 'Q702492', 'enLabel': 'urban area'},
#     {'itemId': 'Q13221722',
#      'enLabel': 'third-level administrative country subdivision'},
#     {'itemId': 'Q2824645',
#      'enLabel': 'administrative territorial entity of Italy'},
#     {'itemId': 'Q15284', 'enLabel': 'municipality'},
#     {'itemId': 'Q19953632',
#      'enLabel': 'former administrative territorial entity'},
#     {'itemId': 'Q6256', 'enLabel': 'country'},
#     {'itemId': 'Q7275', 'enLabel': 'state'},
#     {'itemId': 'Q82794', 'enLabel': 'geographic region'},
#     {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#     {'itemId': 'Q874405', 'enLabel': 'social group'},
#     {'itemId': 'Q16334295', 'enLabel': 'group of humans'},
#     {'itemId': 'Q15042037', 'enLabel': 'statistical territorial entity'},
#     {'itemId': 'Q1799794',
#      'enLabel': 'administrative territorial entity of a specific level'},
#     {'itemId': 'Q15916867',
#      'enLabel': 'administrative territorial entity of a single country'},
#     {'itemId': 'Q1048835', 'enLabel': 'political territorial entity'},
#     {'itemId': 'Q2097994', 'enLabel': 'municipal corporation'},
#     {'itemId': 'Q56061', 'enLabel': 'administrative territorial entity'},
#     {'itemId': 'Q15893266', 'enLabel': 'former entity'},
#     {'itemId': 'Q19832712', 'enLabel': 'historical administrative division'},
#     {'itemId': 'Q43229', 'enLabel': 'organization'},
#     {'itemId': 'Q155076', 'enLabel': 'juridical person'},
#     {'itemId': 'Q2221906', 'enLabel': 'geographic location'},
#     {'itemId': 'Q223557', 'enLabel': 'physical object'},
#     {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q7887142', 'enLabel': 'unit of analysis'},
#     {'itemId': 'Q16334298', 'enLabel': 'living thing group'},
#     {'itemId': 'Q15642541', 'enLabel': 'human-geographic territorial entity'},
#     {'itemId': 'Q6501447', 'enLabel': 'local government'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q19829125', 'enLabel': 'absence'},
#     {'itemId': 'Q4204519', 'enLabel': 'historical fact'},
#     {'itemId': 'Q24229398', 'enLabel': 'agent'},
#     {'itemId': 'Q16513015', 'enLabel': 'order'},
#     {'itemId': 'Q3778211', 'enLabel': 'legal person'},
#     {'itemId': 'Q17334923', 'enLabel': 'location'},
#     {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#     {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#     {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#     {'itemId': 'Q6671777', 'enLabel': 'structure'},
#     {'itemId': 'Q4330518', 'enLabel': 'research object'},
#     {'itemId': 'Q2198779', 'enLabel': 'unit'},
#     {'itemId': 'Q16887380', 'enLabel': 'group'},
#     {'itemId': 'Q517966', 'enLabel': 'structure'},
#     {'itemId': 'Q1496967', 'enLabel': 'territorial entity'},
#     {'itemId': 'Q16686448', 'enLabel': 'artificial entity'},
#     {'itemId': 'Q7188', 'enLabel': 'government'},
#     {'itemId': 'Q16889133', 'enLabel': 'class'},
#     {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#     {'itemId': 'Q188572', 'enLabel': 'fact'},
#     {'itemId': 'Q192630', 'enLabel': 'past'},
#     {'itemId': 'Q23958946', 'enLabel': 'individual'},
#     {'itemId': 'Q1789452', 'enLabel': 'criterion'},
#     {'itemId': 'Q3505845', 'enLabel': 'state'},
#     {'itemId': 'Q830077', 'enLabel': 'subject'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q30060700', 'enLabel': 'object of science'},
#     {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#     {'itemId': 'Q17553950', 'enLabel': 'object'},
#     {'itemId': 'Q7210356', 'enLabel': 'political organisation'},
#     {'itemId': 'Q895526', 'enLabel': 'organ'},
#     {'itemId': 'Q35798', 'enLabel': 'executive branch'},
#     {'itemId': 'Q5127848', 'enLabel': 'class'},
#     {'itemId': 'Q26907166', 'enLabel': 'temporal entity'},
#     {'itemId': 'Q42848', 'enLabel': 'data'},
#     {'itemId': 'Q2684591', 'enLabel': 'statement'},
#     {'itemId': 'Q11471', 'enLabel': 'time'},
#     {'itemId': 'Q1921834', 'enLabel': 'feature'},
#     {'itemId': 'Q937228', 'enLabel': 'property'},
#     {'itemId': 'Q483247', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q174834', 'enLabel': 'authority'},
#     {'itemId': 'Q2101636', 'enLabel': 'political power'},
#     {'itemId': 'Q15708736', 'enLabel': 'public authority'},
#     {'itemId': 'Q2324993', 'enLabel': 'state power'},
#     {'itemId': 'Q11028', 'enLabel': 'information'},
#     {'itemId': 'Q108163', 'enLabel': 'proposition'},
#     {'itemId': 'Q20937557', 'enLabel': 'series'},
#     {'itemId': 'Q714737', 'enLabel': 'category of being'},
#     {'itemId': 'Q1207505', 'enLabel': 'quality'},
#     {'itemId': 'Q16722960', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q25107', 'enLabel': 'power'},
#     {'itemId': 'Q2659904', 'enLabel': 'government organization'},
#     {'itemId': 'Q1125239', 'enLabel': 'public body'},
#     {'itemId': 'Q41796', 'enLabel': 'sentence'},
#     {'itemId': 'Q246672', 'enLabel': 'mathematical object'},
#     {'itemId': 'Q151885', 'enLabel': 'concept'},
#     {'itemId': 'Q18340964', 'enLabel': 'power'},
#     {'itemId': 'Q1786828', 'enLabel': 'constituent'},
#     {'itemId': 'Q15916540', 'enLabel': 'semantic unit'},
#     {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#     {'itemId': 'Q5371079', 'enLabel': 'emic unit'},
#     {'itemId': 'Q183046', 'enLabel': 'meaning'},
#     {'itemId': 'Q4393498', 'enLabel': 'representation'},
#     {'itemId': 'Q20817253', 'enLabel': 'linguistic unit'},
#     {'itemId': 'Q16877783', 'enLabel': 'meaning'},
#     {'itemId': 'Q4173967', 'enLabel': 'language unit'},
#     {'itemId': 'Q29651519', 'enLabel': 'mental object'}],
#    'wikiDataClassIds': ['Q515',
#     'Q747074',
#     'Q3024240',
#     'Q1549591',
#     'Q486972',
#     'Q177634',
#     'Q7930989',
#     'Q702492',
#     'Q13221722',
#     'Q2824645',
#     'Q15284',
#     'Q19953632',
#     'Q6256',
#     'Q7275',
#     'Q82794',
#     'Q618123',
#     'Q874405',
#     'Q16334295',
#     'Q15042037',
#     'Q1799794',
#     'Q15916867',
#     'Q1048835',
#     'Q2097994',
#     'Q56061',
#     'Q15893266',
#     'Q19832712',
#     'Q43229',
#     'Q155076',
#     'Q2221906',
#     'Q223557',
#     'Q58416391',
#     'Q58778',
#     'Q7887142',
#     'Q16334298',
#     'Q15642541',
#     'Q6501447',
#     'Q35120',
#     'Q19829125',
#     'Q4204519',
#     'Q24229398',
#     'Q16513015',
#     'Q3778211',
#     'Q17334923',
#     'Q4406616',
#     'Q1454986',
#     'Q58415929',
#     'Q6671777',
#     'Q4330518',
#     'Q2198779',
#     'Q16887380',
#     'Q517966',
#     'Q1496967',
#     'Q16686448',
#     'Q7188',
#     'Q16889133',
#     'Q1190554',
#     'Q188572',
#     'Q192630',
#     'Q23958946',
#     'Q1789452',
#     'Q3505845',
#     'Q830077',
#     'Q488383',
#     'Q30060700',
#     'Q7184903',
#     'Q17553950',
#     'Q7210356',
#     'Q895526',
#     'Q35798',
#     'Q5127848',
#     'Q26907166',
#     'Q42848',
#     'Q2684591',
#     'Q11471',
#     'Q1921834',
#     'Q937228',
#     'Q483247',
#     'Q174834',
#     'Q2101636',
#     'Q15708736',
#     'Q2324993',
#     'Q11028',
#     'Q108163',
#     'Q20937557',
#     'Q714737',
#     'Q1207505',
#     'Q16722960',
#     'Q25107',
#     'Q2659904',
#     'Q1125239',
#     'Q41796',
#     'Q246672',
#     'Q151885',
#     'Q18340964',
#     'Q1786828',
#     'Q15916540',
#     'Q2145290',
#     'Q5371079',
#     'Q183046',
#     'Q4393498',
#     'Q20817253',
#     'Q16877783',
#     'Q4173967',
#     'Q29651519'],
#    'dbPediaTypes': ['City',
#     'Settlement',
#     'PopulatedPlace',
#     'Place',
#     'AdministrativeRegion',
#     'Region'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Naples'},
#   {'title': 'Italy',
#    'url': 'http://en.wikipedia.org/wiki/Italy',
#    'pageRank': 0.0022563201073930025,
#    'cosine': 0.28350418112514525,
#    'lang': 'en',
#    'wikiDataItemId': 'Q38',
#    'wikiDataClasses': [{'itemId': 'Q3624078', 'enLabel': 'sovereign state'},
#     {'itemId': 'Q6256', 'enLabel': 'country'},
#     {'itemId': 'Q619610', 'enLabel': 'social state'},
#     {'itemId': 'Q179164', 'enLabel': 'unitary state'},
#     {'itemId': 'Q7275', 'enLabel': 'state'},
#     {'itemId': 'Q7270', 'enLabel': 'republic'},
#     {'itemId': 'Q1048835', 'enLabel': 'political territorial entity'},
#     {'itemId': 'Q43229', 'enLabel': 'organization'},
#     {'itemId': 'Q177634', 'enLabel': 'community'},
#     {'itemId': 'Q155076', 'enLabel': 'juridical person'},
#     {'itemId': 'Q7174', 'enLabel': 'democracy'},
#     {'itemId': 'Q15642541', 'enLabel': 'human-geographic territorial entity'},
#     {'itemId': 'Q24229398', 'enLabel': 'agent'},
#     {'itemId': 'Q16334295', 'enLabel': 'group of humans'},
#     {'itemId': 'Q16513015', 'enLabel': 'order'},
#     {'itemId': 'Q874405', 'enLabel': 'social group'},
#     {'itemId': 'Q3778211', 'enLabel': 'legal person'},
#     {'itemId': 'Q28108', 'enLabel': 'political system'},
#     {'itemId': 'Q1496967', 'enLabel': 'territorial entity'},
#     {'itemId': 'Q16686448', 'enLabel': 'artificial entity'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q23958946', 'enLabel': 'individual'},
#     {'itemId': 'Q1789452', 'enLabel': 'criterion'},
#     {'itemId': 'Q16334298', 'enLabel': 'living thing group'},
#     {'itemId': 'Q3505845', 'enLabel': 'state'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q7887142', 'enLabel': 'unit of analysis'},
#     {'itemId': 'Q830077', 'enLabel': 'subject'},
#     {'itemId': 'Q1639378', 'enLabel': 'social system'},
#     {'itemId': 'Q82794', 'enLabel': 'geographic region'},
#     {'itemId': 'Q1921834', 'enLabel': 'feature'},
#     {'itemId': 'Q16887380', 'enLabel': 'group'},
#     {'itemId': 'Q517966', 'enLabel': 'structure'},
#     {'itemId': 'Q937228', 'enLabel': 'property'},
#     {'itemId': 'Q483247', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q6671777', 'enLabel': 'structure'},
#     {'itemId': 'Q4330518', 'enLabel': 'research object'},
#     {'itemId': 'Q2198779', 'enLabel': 'unit'},
#     {'itemId': 'Q2221906', 'enLabel': 'geographic location'},
#     {'itemId': 'Q17553950', 'enLabel': 'object'},
#     {'itemId': 'Q714737', 'enLabel': 'category of being'},
#     {'itemId': 'Q1207505', 'enLabel': 'quality'},
#     {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#     {'itemId': 'Q16722960', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#     {'itemId': 'Q17334923', 'enLabel': 'location'},
#     {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#     {'itemId': 'Q151885', 'enLabel': 'concept'},
#     {'itemId': 'Q26907166', 'enLabel': 'temporal entity'},
#     {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#     {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#     {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#     {'itemId': 'Q223557', 'enLabel': 'physical object'},
#     {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#     {'itemId': 'Q4393498', 'enLabel': 'representation'},
#     {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#     {'itemId': 'Q30060700', 'enLabel': 'object of science'}],
#    'wikiDataClassIds': ['Q3624078',
#     'Q6256',
#     'Q619610',
#     'Q179164',
#     'Q7275',
#     'Q7270',
#     'Q1048835',
#     'Q43229',
#     'Q177634',
#     'Q155076',
#     'Q7174',
#     'Q15642541',
#     'Q24229398',
#     'Q16334295',
#     'Q16513015',
#     'Q874405',
#     'Q3778211',
#     'Q28108',
#     'Q1496967',
#     'Q16686448',
#     'Q35120',
#     'Q23958946',
#     'Q1789452',
#     'Q16334298',
#     'Q3505845',
#     'Q58778',
#     'Q7887142',
#     'Q830077',
#     'Q1639378',
#     'Q82794',
#     'Q1921834',
#     'Q16887380',
#     'Q517966',
#     'Q937228',
#     'Q483247',
#     'Q6671777',
#     'Q4330518',
#     'Q2198779',
#     'Q2221906',
#     'Q17553950',
#     'Q714737',
#     'Q1207505',
#     'Q1190554',
#     'Q16722960',
#     'Q488383',
#     'Q7184903',
#     'Q17334923',
#     'Q4406616',
#     'Q151885',
#     'Q26907166',
#     'Q618123',
#     'Q2145290',
#     'Q58415929',
#     'Q223557',
#     'Q58416391',
#     'Q4393498',
#     'Q1454986',
#     'Q30060700'],
#    'dbPediaTypes': ['PopulatedPlace', 'Place', 'Country'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Italy'},
#   {'title': 'Peristyle',
#    'url': 'http://en.wikipedia.org/wiki/Peristyle',
#    'pageRank': 0.0022272463297215747,
#    'cosine': 0.17891798661997024,
#    'lang': 'en',
#    'wikiDataItemId': 'Q725453',
#    'wikiDataClasses': [{'itemId': 'Q1497384', 'enLabel': 'part of building'},
#     {'itemId': 'Q56052926', 'enLabel': 'building division'},
#     {'itemId': 'Q17334923', 'enLabel': 'location'},
#     {'itemId': 'Q811430', 'enLabel': 'construction'},
#     {'itemId': 'Q15989253', 'enLabel': 'part'},
#     {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#     {'itemId': 'Q8205328', 'enLabel': 'artificial physical object'},
#     {'itemId': 'Q35145743', 'enLabel': 'human-made geographic object'},
#     {'itemId': 'Q386724', 'enLabel': 'work'},
#     {'itemId': 'Q6671777', 'enLabel': 'structure'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q223557', 'enLabel': 'physical object'},
#     {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#     {'itemId': 'Q16686448', 'enLabel': 'artificial entity'},
#     {'itemId': 'Q27096235', 'enLabel': 'artificial geographic entity'},
#     {'itemId': 'Q15401930', 'enLabel': 'product'},
#     {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#     {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#     {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#     {'itemId': 'Q27096213', 'enLabel': 'geographic entity'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q30060700', 'enLabel': 'object of science'}],
#    'wikiDataClassIds': ['Q1497384',
#     'Q56052926',
#     'Q17334923',
#     'Q811430',
#     'Q15989253',
#     'Q618123',
#     'Q8205328',
#     'Q35145743',
#     'Q386724',
#     'Q6671777',
#     'Q35120',
#     'Q223557',
#     'Q58416391',
#     'Q16686448',
#     'Q27096235',
#     'Q15401930',
#     'Q4406616',
#     'Q1454986',
#     'Q58415929',
#     'Q27096213',
#     'Q488383',
#     'Q58778',
#     'Q30060700'],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/Peristyle'},
#   {'title': 'Architecture',
#    'url': 'http://en.wikipedia.org/wiki/Architecture',
#    'pageRank': 0.0021981072962756454,
#    'cosine': 0.27032474176319343,
#    'lang': 'en',
#    'wikiDataItemId': 'Q12271',
#    'wikiDataClasses': [{'itemId': 'Q11862829',
#      'enLabel': 'academic discipline'},
#     {'itemId': 'Q1047113', 'enLabel': 'specialty'},
#     {'itemId': 'Q9081', 'enLabel': 'knowledge'},
#     {'itemId': 'Q11028', 'enLabel': 'information'},
#     {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'}],
#    'wikiDataClassIds': ['Q11862829',
#     'Q1047113',
#     'Q9081',
#     'Q11028',
#     'Q7184903',
#     'Q488383',
#     'Q35120'],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/Architecture'},
#   {'title': 'Narrative thread',
#    'url': 'http://en.wikipedia.org/wiki/Narrative_thread',
#    'pageRank': 0.002171050735543616,
#    'cosine': 0.00924343957986453,
#    'lang': 'en',
#    'wikiDataItemId': 'Q6966227',
#    'wikiDataClasses': [],
#    'wikiDataClassIds': [],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/Narrative_thread'},
#   {'title': 'Archaeology',
#    'url': 'http://en.wikipedia.org/wiki/Archaeology',
#    'pageRank': 0.0021367351922659513,
#    'cosine': 0.24574825221579963,
#    'lang': 'en',
#    'wikiDataItemId': 'Q23498',
#    'wikiDataClasses': [{'itemId': 'Q11862829',
#      'enLabel': 'academic discipline'},
#     {'itemId': 'Q4671286', 'enLabel': 'academic major'},
#     {'itemId': 'Q1047113', 'enLabel': 'specialty'},
#     {'itemId': 'Q9081', 'enLabel': 'knowledge'},
#     {'itemId': 'Q11028', 'enLabel': 'information'},
#     {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'}],
#    'wikiDataClassIds': ['Q11862829',
#     'Q4671286',
#     'Q1047113',
#     'Q9081',
#     'Q11028',
#     'Q7184903',
#     'Q488383',
#     'Q35120'],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/Archaeology'},
#   {'title': 'Wood',
#    'url': 'http://en.wikipedia.org/wiki/Wood',
#    'pageRank': 0.0021168250728762147,
#    'cosine': 0.26215564938985225,
#    'lang': 'en',
#    'wikiDataItemId': 'Q287',
#    'wikiDataClasses': [{'itemId': 'Q214609', 'enLabel': 'base material'},
#     {'itemId': 'Q2424752', 'enLabel': 'product'},
#     {'itemId': 'Q28555911', 'enLabel': 'ordinary matter'},
#     {'itemId': 'Q28877', 'enLabel': 'goods'},
#     {'itemId': 'Q2897903', 'enLabel': 'goods and services'},
#     {'itemId': 'Q6005984', 'enLabel': 'baryonic matter'},
#     {'itemId': 'Q2995644', 'enLabel': 'result'},
#     {'itemId': 'Q28921572', 'enLabel': 'common matter'},
#     {'itemId': 'Q374182', 'enLabel': 'logical consequence'},
#     {'itemId': 'Q35758', 'enLabel': 'matter'},
#     {'itemId': 'Q733541', 'enLabel': 'consequence'},
#     {'itemId': 'Q28728771', 'enLabel': 'material substance'},
#     {'itemId': 'Q28732711', 'enLabel': 'physical substance'},
#     {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#     {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q30060700', 'enLabel': 'object of science'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q6671777', 'enLabel': 'structure'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'}],
#    'wikiDataClassIds': ['Q214609',
#     'Q2424752',
#     'Q28555911',
#     'Q28877',
#     'Q2897903',
#     'Q6005984',
#     'Q2995644',
#     'Q28921572',
#     'Q374182',
#     'Q35758',
#     'Q733541',
#     'Q28728771',
#     'Q28732711',
#     'Q1454986',
#     'Q4406616',
#     'Q58778',
#     'Q30060700',
#     'Q488383',
#     'Q6671777',
#     'Q35120'],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/Wood'},
#   {'title': 'Ferry',
#    'url': 'http://en.wikipedia.org/wiki/Ferry',
#    'pageRank': 0.0021134991636813515,
#    'cosine': 0.012632742062447272,
#    'lang': 'en',
#    'wikiDataItemId': 'Q25653',
#    'wikiDataClasses': [{'itemId': 'Q2235308', 'enLabel': 'ship type'},
#     {'itemId': 'Q16335899', 'enLabel': 'watercraft type'},
#     {'itemId': 'Q21522908', 'enLabel': 'Wikidata instance class'},
#     {'itemId': 'Q21522864',
#      'enLabel': 'class or metaclass of Wikidata ontology'}],
#    'wikiDataClassIds': ['Q2235308', 'Q16335899', 'Q21522908', 'Q21522864'],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/Ferry'},
#   {'title': 'Basilica',
#    'url': 'http://en.wikipedia.org/wiki/Basilica',
#    'pageRank': 0.0020660031936228286,
#    'cosine': 0.20542492823870775,
#    'lang': 'en',
#    'wikiDataItemId': 'Q163687',
#    'wikiDataClasses': [],
#    'wikiDataClassIds': [],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/Basilica'},
#   {'title': 'Social War (91–88 BC)',
#    'url': 'http://en.wikipedia.org/wiki/Social_War_(91%e2%80%9388_BC)',
#    'pageRank': 0.002025536516692804,
#    'cosine': 0.18125475332075547,
#    'lang': 'en',
#    'wikiDataItemId': 'Q677316',
#    'wikiDataClasses': [{'itemId': 'Q198', 'enLabel': 'war'},
#     {'itemId': 'Q350604', 'enLabel': 'armed conflict'},
#     {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#     {'itemId': 'Q19829125', 'enLabel': 'absence'},
#     {'itemId': 'Q180684', 'enLabel': 'conflict'},
#     {'itemId': 'Q26907166', 'enLabel': 'temporal entity'},
#     {'itemId': 'Q16889133', 'enLabel': 'class'},
#     {'itemId': 'Q11023058', 'enLabel': 'interpersonal communication'},
#     {'itemId': 'Q363948', 'enLabel': 'contradiction'},
#     {'itemId': 'Q52948', 'enLabel': 'interaction'},
# ...
#     {'itemId': 'Q9081', 'enLabel': 'knowledge'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q937228', 'enLabel': 'property'},
#     {'itemId': 'Q11028', 'enLabel': 'information'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q714737', 'enLabel': 'category of being'},
#     {'itemId': 'Q1207505', 'enLabel': 'quality'}],
#    'wikiDataClassIds': ['Q49447',
#     'Q131841',
#     'Q20978643',
#     'Q151885',
#     'Q2145290',
#     'Q595523',
#     'Q7184903',
#     'Q4393498',
#     'Q9081',
#     'Q488383',
#     'Q937228',
#     'Q11028',
#     'Q35120',
#     'Q714737',
#     'Q1207505'],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/Determinism'},
#   {'title': 'Banknote',
#    'url': 'http://en.wikipedia.org/wiki/Banknote',
#    'pageRank': 0.000887987447124895,
#    'cosine': 0.21127925161575475,
#    'lang': 'en',
#    'wikiDataItemId': 'Q47433',
#    'wikiDataClasses': [{'itemId': 'Q2342494', 'enLabel': 'collectable'},
#     {'itemId': 'Q1643989', 'enLabel': 'legal tender'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q223557', 'enLabel': 'physical object'},
#     {'itemId': 'Q190122', 'enLabel': 'promissory note'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#     {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#     {'itemId': 'Q28038717', 'enLabel': 'Negotiable instrument'},
#     {'itemId': 'Q15809678', 'enLabel': 'financial product'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q30060700', 'enLabel': 'object of science'},
#     {'itemId': 'Q2424752', 'enLabel': 'product'},
#     {'itemId': 'Q837171', 'enLabel': 'financial services'},
#     {'itemId': 'Q6671777', 'enLabel': 'structure'},
#     {'itemId': 'Q28877', 'enLabel': 'goods'},
#     {'itemId': 'Q2897903', 'enLabel': 'goods and services'},
#     {'itemId': 'Q7406919', 'enLabel': 'service'},
#     {'itemId': 'Q2995644', 'enLabel': 'result'},
#     {'itemId': 'Q451967', 'enLabel': 'human action'},
#     {'itemId': 'Q374182', 'enLabel': 'logical consequence'},
#     {'itemId': 'Q3769299', 'enLabel': 'human behaviour'},
#     {'itemId': 'Q4026292', 'enLabel': 'action'},
#     {'itemId': 'Q1914636', 'enLabel': 'activity'},
#     {'itemId': 'Q733541', 'enLabel': 'consequence'},
#     {'itemId': 'Q9332', 'enLabel': 'behavior'},
#     {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#     {'itemId': 'Q26907166', 'enLabel': 'temporal entity'},
#     {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'}],
#    'wikiDataClassIds': ['Q2342494',
#     'Q1643989',
#     'Q488383',
#     'Q223557',
#     'Q190122',
#     'Q35120',
#     'Q4406616',
#     'Q1454986',
#     'Q28038717',
#     'Q15809678',
#     'Q58778',
#     'Q30060700',
#     'Q2424752',
#     'Q837171',
#     'Q6671777',
#     'Q28877',
#     'Q2897903',
#     'Q7406919',
#     'Q2995644',
#     'Q451967',
#     'Q374182',
#     'Q3769299',
#     'Q4026292',
#     'Q1914636',
#     'Q733541',
#     'Q9332',
#     'Q1190554',
#     'Q26907166',
#     'Q58415929'],
#    'dbPediaTypes': ['Currency'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Banknote'},
#   {'title': 'Hoard',
#    'url': 'http://en.wikipedia.org/wiki/Hoard',
#    'pageRank': 0.0008865167395297915,
#    'cosine': 0.07686266919454374,
#    'lang': 'en',
#    'wikiDataItemId': 'Q164099',
#    'wikiDataClasses': [],
#    'wikiDataClassIds': [],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/Hoard'},
#   {'title': 'Intimate relationship',
#    'url': 'http://en.wikipedia.org/wiki/Intimate_relationship',
#    'pageRank': 0.0008756791781863008,
#    'cosine': 0.22026298463023689,
#    'lang': 'en',
#    'wikiDataItemId': 'Q736922',
#    'wikiDataClasses': [],
#    'wikiDataClassIds': [],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/Intimate_relationship'},
#   {'title': 'Orbit',
#    'url': 'http://en.wikipedia.org/wiki/Orbit',
#    'pageRank': 0.00086365873235368,
#    'cosine': 0.22421145226756264,
#    'lang': 'en',
#    'wikiDataItemId': 'Q4130',
#    'wikiDataClasses': [{'itemId': 'Q2221906',
#      'enLabel': 'geographic location'},
#     {'itemId': 'Q17334923', 'enLabel': 'location'},
#     {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#     {'itemId': 'Q223557', 'enLabel': 'physical object'},
#     {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#     {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#     {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#     {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q30060700', 'enLabel': 'object of science'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q6671777', 'enLabel': 'structure'}],
#    'wikiDataClassIds': ['Q2221906',
#     'Q17334923',
#     'Q618123',
#     'Q223557',
#     'Q58416391',
#     'Q4406616',
#     'Q1454986',
#     'Q58415929',
#     'Q488383',
#     'Q58778',
#     'Q30060700',
#     'Q35120',
#     'Q6671777'],
#    'dbPediaTypes': ['Agent', 'Organisation', 'Company'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Orbit'},
#   {'title': 'Classical mechanics',
#    'url': 'http://en.wikipedia.org/wiki/Classical_mechanics',
#    'pageRank': 0.0008608505166181186,
#    'cosine': 0.2121669873166339,
#    'lang': 'en',
#    'wikiDataItemId': 'Q11397',
#    'wikiDataClasses': [],
#    'wikiDataClassIds': [],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/Classical_mechanics'},
#   {'title': 'Convention (norm)',
#    'url': 'http://en.wikipedia.org/wiki/Convention_(norm)',
#    'pageRank': 0.0008577115023005728,
#    'cosine': 0.19319696985340717,
#    'lang': 'en',
#    'wikiDataItemId': 'Q367293',
#    'wikiDataClasses': [],
#    'wikiDataClassIds': [],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/Convention_(norm)'},
#   {'title': 'Android (operating system)',
#    'url': 'http://en.wikipedia.org/wiki/Android_(operating_system)',
#    'pageRank': 0.0008388490191911401,
#    'cosine': 0.1334148478475758,
#    'lang': 'en',
#    'wikiDataItemId': 'Q94',
#    'wikiDataClasses': [{'itemId': 'Q920890',
#      'enLabel': 'mobile operating system'},
#     {'itemId': 'Q9135', 'enLabel': 'operating system'},
#     {'itemId': 'Q21743174', 'enLabel': 'mobile software'},
#     {'itemId': 'Q676202', 'enLabel': 'system software'},
#     {'itemId': 'Q241317', 'enLabel': 'computing platform'},
#     {'itemId': 'Q7397', 'enLabel': 'software'},
#     {'itemId': 'Q15411548', 'enLabel': 'computing infrastructure'},
#     {'itemId': 'Q17537576', 'enLabel': 'creative work'},
#     {'itemId': 'Q2424752', 'enLabel': 'product'},
#     {'itemId': 'Q8148', 'enLabel': 'industry'},
#     {'itemId': 'Q47461344', 'enLabel': 'written work'},
#     {'itemId': 'Q179310', 'enLabel': 'computing'},
#     {'itemId': 'Q121359', 'enLabel': 'infrastructure'},
#     {'itemId': 'Q15621286', 'enLabel': 'intellectual work'},
#     {'itemId': 'Q18593264', 'enLabel': 'item of collection or exhibition'},
#     {'itemId': 'Q28877', 'enLabel': 'goods'},
#     {'itemId': 'Q2897903', 'enLabel': 'goods and services'},
#     {'itemId': 'Q739302', 'enLabel': 'production'},
#     {'itemId': 'Q386724', 'enLabel': 'work'},
#     {'itemId': 'Q1914636', 'enLabel': 'activity'},
#     {'itemId': 'Q21503252', 'enLabel': 'instance of'},
#     {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#     {'itemId': 'Q2995644', 'enLabel': 'result'},
#     {'itemId': 'Q3249551', 'enLabel': 'process'},
#     {'itemId': 'Q15401930', 'enLabel': 'product'},
#     {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#     {'itemId': 'Q30060700', 'enLabel': 'object of science'},
#     {'itemId': 'Q374182', 'enLabel': 'logical consequence'},
#     {'itemId': 'Q20937557', 'enLabel': 'series'},
#     {'itemId': 'Q1150070', 'enLabel': 'change'},
#     {'itemId': 'Q16686448', 'enLabel': 'artificial entity'},
#     {'itemId': 'Q26907166', 'enLabel': 'temporal entity'},
#     {'itemId': 'Q6671777', 'enLabel': 'structure'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q733541', 'enLabel': 'consequence'},
#     {'itemId': 'Q16887380', 'enLabel': 'group'},
#     {'itemId': 'Q5915039', 'enLabel': 'inconstancy'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#     {'itemId': 'Q17553950', 'enLabel': 'object'},
#     {'itemId': 'Q937228', 'enLabel': 'property'},
#     {'itemId': 'Q714737', 'enLabel': 'category of being'},
#     {'itemId': 'Q1207505', 'enLabel': 'quality'},
#     {'itemId': 'Q151885', 'enLabel': 'concept'},
#     {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#     {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#     {'itemId': 'Q4393498', 'enLabel': 'representation'}],
#    'wikiDataClassIds': ['Q920890',
#     'Q9135',
#     'Q21743174',
#     'Q676202',
#     'Q241317',
#     'Q7397',
#     'Q15411548',
#     'Q17537576',
#     'Q2424752',
#     'Q8148',
#     'Q47461344',
#     'Q179310',
#     'Q121359',
#     'Q15621286',
#     'Q18593264',
#     'Q28877',
#     'Q2897903',
#     'Q739302',
#     'Q386724',
#     'Q1914636',
#     'Q21503252',
#     'Q1454986',
#     'Q2995644',
#     'Q3249551',
#     'Q15401930',
#     'Q1190554',
#     'Q58778',
#     'Q4406616',
#     'Q30060700',
#     'Q374182',
#     'Q20937557',
#     'Q1150070',
#     'Q16686448',
#     'Q26907166',
#     'Q6671777',
#     'Q488383',
#     'Q733541',
#     'Q16887380',
#     'Q5915039',
#     'Q35120',
#     'Q58415929',
#     'Q17553950',
#     'Q937228',
#     'Q714737',
#     'Q1207505',
#     'Q151885',
#     'Q7184903',
#     'Q2145290',
#     'Q4393498'],
#    'dbPediaTypes': ['Work', 'Software'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Android_(operating_system)'},
#   {'title': 'Debate',
#    'url': 'http://en.wikipedia.org/wiki/Debate',
#    'pageRank': 0.0008365598106211138,
#    'cosine': 0.2023126404666659,
#    'lang': 'en',
#    'wikiDataItemId': 'Q179875',
#    'wikiDataClasses': [],
#    'wikiDataClassIds': [],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/Debate'},
#   {'title': 'States of Germany',
#    'url': 'http://en.wikipedia.org/wiki/States_of_Germany',
#    'pageRank': 0.0008345743315678053,
#    'cosine': 0.20874743307230503,
#    'lang': 'en',
#    'wikiDataItemId': 'Q1221156',
#    'wikiDataClasses': [{'itemId': 'Q28872924',
#      'enLabel': 'designation for an administrative territorial entity of a single country'},
#     {'itemId': 'Q15617994',
#      'enLabel': 'designation for an administrative territorial entity'},
#     {'itemId': 'Q217594', 'enLabel': 'class (set theory)'},
#     {'itemId': 'Q246672', 'enLabel': 'mathematical object'},
#     {'itemId': 'Q16889133', 'enLabel': 'class'},
#     {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#     {'itemId': 'Q5127848', 'enLabel': 'class'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'}],
#    'wikiDataClassIds': ['Q28872924',
#     'Q15617994',
#     'Q217594',
#     'Q246672',
#     'Q16889133',
#     'Q7184903',
#     'Q5127848',
#     'Q488383',
#     'Q35120'],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/States_of_Germany'},
#   {'title': 'Child abandonment',
#    'url': 'http://en.wikipedia.org/wiki/Child_abandonment',
#    'pageRank': 0.0008226437276308301,
#    'cosine': 0.24466395911063074,
#    'lang': 'en',
#    'wikiDataItemId': 'Q202415',
#    'wikiDataClasses': [{'itemId': 'Q1724915', 'enLabel': 'use'},
#     {'itemId': 'Q451967', 'enLabel': 'human action'},
#     {'itemId': 'Q937228', 'enLabel': 'property'},
#     {'itemId': 'Q3769299', 'enLabel': 'human behaviour'},
#     {'itemId': 'Q4026292', 'enLabel': 'action'},
#     {'itemId': 'Q1914636', 'enLabel': 'activity'},
#     {'itemId': 'Q714737', 'enLabel': 'category of being'},
#     {'itemId': 'Q1207505', 'enLabel': 'quality'},
#     {'itemId': 'Q9332', 'enLabel': 'behavior'},
#     {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#     {'itemId': 'Q151885', 'enLabel': 'concept'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q26907166', 'enLabel': 'temporal entity'},
#     {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#     {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#     {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q4393498', 'enLabel': 'representation'}],
#    'wikiDataClassIds': ['Q1724915',
#     'Q451967',
#     'Q937228',
#     'Q3769299',
#     'Q4026292',
#     'Q1914636',
#     'Q714737',
#     'Q1207505',
#     'Q9332',
#     'Q1190554',
#     'Q151885',
#     'Q35120',
#     'Q26907166',
#     'Q7184903',
#     'Q2145290',
#     'Q58415929',
#     'Q488383',
#     'Q4393498'],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/Child_abandonment'},
#   {'title': 'Symbiosis',
#    'url': 'http://en.wikipedia.org/wiki/Symbiosis',
#    'pageRank': 0.0008055513487893248,
#    'cosine': 0.21653634411729575,
#    'lang': 'en',
#    'wikiDataItemId': 'Q121610',
#    'wikiDataClasses': [],
#    'wikiDataClassIds': [],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/Symbiosis'},
#   {'title': 'Street',
#    'url': 'http://en.wikipedia.org/wiki/Street',
#    'pageRank': 0.0008015379125250906,
#    'cosine': 0.21390245603352487,
#    'lang': 'en',
#    'wikiDataItemId': 'Q79007',
#    'wikiDataClasses': [],
#    'wikiDataClassIds': [],
#    'dbPediaTypes': ['PopulatedPlace', 'Place'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Street'},
#   {'title': 'Fact',
#    'url': 'http://en.wikipedia.org/wiki/Fact',
#    'pageRank': 0.0007979679955828611,
#    'cosine': 0.255090747699011,
#    'lang': 'en',
#    'wikiDataItemId': 'Q188572',
#    'wikiDataClasses': [],
#    'wikiDataClassIds': [],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/Fact'},
#   {'title': 'Witness',
#    'url': 'http://en.wikipedia.org/wiki/Witness',
#    'pageRank': 0.0007844500367621678,
#    'cosine': 0.19392077732358493,
#    'lang': 'en',
#    'wikiDataItemId': 'Q196939',
#    'wikiDataClasses': [],
#    'wikiDataClassIds': [],
#    'dbPediaTypes': ['Work', 'Album', 'MusicalWork'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Witness'},
#   {'title': 'Multiverse',
#    'url': 'http://en.wikipedia.org/wiki/Multiverse',
#    'pageRank': 0.0007819466003039575,
#    'cosine': 0.2030278987262624,
#    'lang': 'en',
#    'wikiDataItemId': 'Q3327819',
#    'wikiDataClasses': [{'itemId': 'Q41719', 'enLabel': 'hypothesis'},
#     {'itemId': 'Q108163', 'enLabel': 'proposition'},
#     {'itemId': 'Q321703', 'enLabel': 'premise'},
#     {'itemId': 'Q11028', 'enLabel': 'information'},
#     {'itemId': 'Q41796', 'enLabel': 'sentence'},
#     {'itemId': 'Q246672', 'enLabel': 'mathematical object'},
#     {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#     {'itemId': 'Q1786828', 'enLabel': 'constituent'},
#     {'itemId': 'Q15916540', 'enLabel': 'semantic unit'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q5371079', 'enLabel': 'emic unit'},
#     {'itemId': 'Q183046', 'enLabel': 'meaning'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q16889133', 'enLabel': 'class'},
#     {'itemId': 'Q20817253', 'enLabel': 'linguistic unit'},
#     {'itemId': 'Q16877783', 'enLabel': 'meaning'},
#     {'itemId': 'Q5127848', 'enLabel': 'class'},
#     {'itemId': 'Q4173967', 'enLabel': 'language unit'},
#     {'itemId': 'Q151885', 'enLabel': 'concept'},
#     {'itemId': 'Q29651519', 'enLabel': 'mental object'},
#     {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#     {'itemId': 'Q4393498', 'enLabel': 'representation'},
#     {'itemId': 'Q937228', 'enLabel': 'property'},
#     {'itemId': 'Q714737', 'enLabel': 'category of being'},
#     {'itemId': 'Q1207505', 'enLabel': 'quality'}],
#    'wikiDataClassIds': ['Q41719',
#     'Q108163',
#     'Q321703',
#     'Q11028',
#     'Q41796',
#     'Q246672',
#     'Q7184903',
#     'Q1786828',
#     'Q15916540',
#     'Q488383',
#     'Q5371079',
#     'Q183046',
#     'Q35120',
#     'Q16889133',
#     'Q20817253',
#     'Q16877783',
#     'Q5127848',
#     'Q4173967',
#     'Q151885',
#     'Q29651519',
#     'Q2145290',
#     'Q4393498',
#     'Q937228',
#     'Q714737',
#     'Q1207505'],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/Multiverse'}]}

# %%
res
# Out:
# {'concepts': [{'title': 'Herculaneum',
#    'url': 'http://en.wikipedia.org/wiki/Herculaneum',
#    'pageRank': 0.03739412937379306,
#    'cosine': 0.6801656584737229,
#    'lang': 'en',
#    'support': [{'wFrom': 25, 'wTo': 25, 'chunk': 0},
#     {'wFrom': 65, 'wTo': 65, 'chunk': 0},
#     {'wFrom': 165, 'wTo': 165, 'chunk': 0},
#     {'wFrom': 197, 'wTo': 197, 'chunk': 0},
#     {'wFrom': 242, 'wTo': 242, 'chunk': 0},
#     {'wFrom': 292, 'wTo': 292, 'chunk': 0},
#     {'wFrom': 352, 'wTo': 352, 'chunk': 0},
#     {'wFrom': 363, 'wTo': 363, 'chunk': 0},
#     {'wFrom': 392, 'wTo': 392, 'chunk': 0},
#     {'wFrom': 446, 'wTo': 446, 'chunk': 0},
#     {'wFrom': 578, 'wTo': 578, 'chunk': 0},
#     {'wFrom': 704, 'wTo': 704, 'chunk': 0},
#     {'wFrom': 848, 'wTo': 848, 'chunk': 0},
#     {'wFrom': 891, 'wTo': 891, 'chunk': 0},
#     {'wFrom': 910, 'wTo': 910, 'chunk': 0},
#     {'wFrom': 920, 'wTo': 920, 'chunk': 0},
#     {'wFrom': 943, 'wTo': 943, 'chunk': 0},
#     {'wFrom': 970, 'wTo': 970, 'chunk': 0},
#     {'wFrom': 980, 'wTo': 980, 'chunk': 0},
#     {'wFrom': 1005, 'wTo': 1005, 'chunk': 0},
#     {'wFrom': 1010, 'wTo': 1010, 'chunk': 0},
#     {'wFrom': 1015, 'wTo': 1015, 'chunk': 0},
#     {'wFrom': 1035, 'wTo': 1035, 'chunk': 0},
#     {'wFrom': 1050, 'wTo': 1050, 'chunk': 0},
#     {'wFrom': 1100, 'wTo': 1100, 'chunk': 0},
#     {'wFrom': 1120, 'wTo': 1120, 'chunk': 0},
#     {'wFrom': 1151, 'wTo': 1151, 'chunk': 0},
#     {'wFrom': 1253, 'wTo': 1253, 'chunk': 0},
#     {'wFrom': 1362, 'wTo': 1362, 'chunk': 0},
#     {'wFrom': 1407, 'wTo': 1407, 'chunk': 0},
#     {'wFrom': 1582, 'wTo': 1582, 'chunk': 0},
#     {'wFrom': 1655, 'wTo': 1655, 'chunk': 0},
#     {'wFrom': 1694, 'wTo': 1694, 'chunk': 0},
#     {'wFrom': 1816, 'wTo': 1816, 'chunk': 0}],
#    'wikiDataItemId': 'Q178813',
#    'wikiDataClasses': [{'itemId': 'Q17431399', 'enLabel': 'national museum'},
#     {'itemId': 'Q839954', 'enLabel': 'archaeological site'},
#     {'itemId': 'Q33506', 'enLabel': 'museum'},
#     {'itemId': 'Q1291195', 'enLabel': 'find spot'},
#     {'itemId': 'Q15642541', 'enLabel': 'human-geographic territorial entity'},
#     {'itemId': 'Q14524493', 'enLabel': 'terrain'},
#     {'itemId': 'Q1030034', 'enLabel': 'GLAM'},
#     {'itemId': 'Q13226383', 'enLabel': 'facility'},
#     {'itemId': 'Q5193377', 'enLabel': 'cultural institution'},
#     {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#     {'itemId': 'Q1496967', 'enLabel': 'territorial entity'},
#     {'itemId': 'Q16686448', 'enLabel': 'artificial entity'},
#     {'itemId': 'Q271669', 'enLabel': 'landform'},
#     {'itemId': 'Q2221906', 'enLabel': 'geographic location'},
#     {'itemId': 'Q178706', 'enLabel': 'institution'},
#     {'itemId': 'Q223557', 'enLabel': 'physical object'},
#     {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#     {'itemId': 'Q82794', 'enLabel': 'geographic region'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q12766313', 'enLabel': 'geomorphological unit'},
#     {'itemId': 'Q17334923', 'enLabel': 'location'},
#     {'itemId': 'Q43229', 'enLabel': 'organization'},
#     {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#     {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#     {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#     {'itemId': 'Q24229398', 'enLabel': 'agent'},
#     {'itemId': 'Q16334295', 'enLabel': 'group of humans'},
#     {'itemId': 'Q16513015', 'enLabel': 'order'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q30060700', 'enLabel': 'object of science'},
#     {'itemId': 'Q23958946', 'enLabel': 'individual'},
#     {'itemId': 'Q1789452', 'enLabel': 'criterion'},
#     {'itemId': 'Q16334298', 'enLabel': 'living thing group'},
#     {'itemId': 'Q3505845', 'enLabel': 'state'},
#     {'itemId': 'Q6671777', 'enLabel': 'structure'},
#     {'itemId': 'Q1921834', 'enLabel': 'feature'},
#     {'itemId': 'Q16887380', 'enLabel': 'group'},
#     {'itemId': 'Q517966', 'enLabel': 'structure'},
#     {'itemId': 'Q937228', 'enLabel': 'property'},
#     {'itemId': 'Q483247', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q17553950', 'enLabel': 'object'},
#     {'itemId': 'Q714737', 'enLabel': 'category of being'},
#     {'itemId': 'Q1207505', 'enLabel': 'quality'},
#     {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#     {'itemId': 'Q16722960', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q151885', 'enLabel': 'concept'},
#     {'itemId': 'Q26907166', 'enLabel': 'temporal entity'},
#     {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#     {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#     {'itemId': 'Q4393498', 'enLabel': 'representation'}],
#    'wikiDataClassIds': ['Q17431399',
#     'Q839954',
#     'Q33506',
#     'Q1291195',
#     'Q15642541',
#     'Q14524493',
#     'Q1030034',
#     'Q13226383',
#     'Q5193377',
#     'Q618123',
#     'Q1496967',
#     'Q16686448',
#     'Q271669',
#     'Q2221906',
#     'Q178706',
#     'Q223557',
#     'Q58416391',
#     'Q82794',
#     'Q35120',
#     'Q12766313',
#     'Q17334923',
#     'Q43229',
#     'Q4406616',
#     'Q1454986',
#     'Q58415929',
#     'Q24229398',
#     'Q16334295',
#     'Q16513015',
#     'Q488383',
#     'Q58778',
#     'Q30060700',
#     'Q23958946',
#     'Q1789452',
#     'Q16334298',
#     'Q3505845',
#     'Q6671777',
#     'Q1921834',
#     'Q16887380',
#     'Q517966',
#     'Q937228',
#     'Q483247',
#     'Q17553950',
#     'Q714737',
#     'Q1207505',
#     'Q1190554',
#     'Q16722960',
#     'Q151885',
#     'Q26907166',
#     'Q7184903',
#     'Q2145290',
#     'Q4393498'],
#    'dbPediaTypes': ['Place', 'WorldHeritageSite'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Herculaneum'},
#   {'title': 'Pompeii',
#    'url': 'http://en.wikipedia.org/wiki/Pompeii',
#    'pageRank': 0.018291090534386135,
#    'cosine': 0.5094460836140102,
#    'lang': 'en',
#    'support': [{'wFrom': 175, 'wTo': 175, 'chunk': 0},
#     {'wFrom': 190, 'wTo': 190, 'chunk': 0},
#     {'wFrom': 203, 'wTo': 203, 'chunk': 0},
#     {'wFrom': 209, 'wTo': 209, 'chunk': 0},
#     {'wFrom': 240, 'wTo': 240, 'chunk': 0},
#     {'wFrom': 336, 'wTo': 336, 'chunk': 0},
#     {'wFrom': 368, 'wTo': 368, 'chunk': 0},
#     {'wFrom': 433, 'wTo': 433, 'chunk': 0},
#     {'wFrom': 584, 'wTo': 584, 'chunk': 0},
#     {'wFrom': 901, 'wTo': 901, 'chunk': 0},
#     {'wFrom': 997, 'wTo': 997, 'chunk': 0},
#     {'wFrom': 1028, 'wTo': 1028, 'chunk': 0},
#     {'wFrom': 1073, 'wTo': 1073, 'chunk': 0},
#     {'wFrom': 1140, 'wTo': 1140, 'chunk': 0},
#     {'wFrom': 1190, 'wTo': 1190, 'chunk': 0},
#     {'wFrom': 1358, 'wTo': 1358, 'chunk': 0},
#     {'wFrom': 1400, 'wTo': 1400, 'chunk': 0},
#     {'wFrom': 1624, 'wTo': 1624, 'chunk': 0},
#     {'wFrom': 1736, 'wTo': 1736, 'chunk': 0},
#     {'wFrom': 1845, 'wTo': 1845, 'chunk': 0},
#     {'wFrom': 1850, 'wTo': 1850, 'chunk': 0}],
#    'wikiDataItemId': 'Q43332',
#    'wikiDataClasses': [{'itemId': 'Q15661340', 'enLabel': 'ancient city'},
#     {'itemId': 'Q839954', 'enLabel': 'archaeological site'},
#     {'itemId': 'Q17431399', 'enLabel': 'national museum'},
#     {'itemId': 'Q2974842', 'enLabel': 'lost city'},
#     {'itemId': 'Q1291195', 'enLabel': 'find spot'},
#     {'itemId': 'Q15642541', 'enLabel': 'human-geographic territorial entity'},
#     {'itemId': 'Q14524493', 'enLabel': 'terrain'},
#     {'itemId': 'Q33506', 'enLabel': 'museum'},
#     {'itemId': 'Q74047', 'enLabel': 'ghost town'},
#     {'itemId': 'Q515', 'enLabel': 'city'},
#     {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#     {'itemId': 'Q1496967', 'enLabel': 'territorial entity'},
#     {'itemId': 'Q16686448', 'enLabel': 'artificial entity'},
#     {'itemId': 'Q271669', 'enLabel': 'landform'},
#     {'itemId': 'Q1030034', 'enLabel': 'GLAM'},
#     {'itemId': 'Q13226383', 'enLabel': 'facility'},
#     {'itemId': 'Q5193377', 'enLabel': 'cultural institution'},
#     {'itemId': 'Q22674925', 'enLabel': 'former populated place'},
#     {'itemId': 'Q486972', 'enLabel': 'human settlement'},
#     {'itemId': 'Q177634', 'enLabel': 'community'},
#     {'itemId': 'Q7930989', 'enLabel': 'city/town'},
#     {'itemId': 'Q702492', 'enLabel': 'urban area'},
#     {'itemId': 'Q223557', 'enLabel': 'physical object'},
#     {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#     {'itemId': 'Q82794', 'enLabel': 'geographic region'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q12766313', 'enLabel': 'geomorphological unit'},
#     {'itemId': 'Q2221906', 'enLabel': 'geographic location'},
#     {'itemId': 'Q178706', 'enLabel': 'institution'},
#     {'itemId': 'Q15893266', 'enLabel': 'former entity'},
#     {'itemId': 'Q874405', 'enLabel': 'social group'},
#     {'itemId': 'Q16334295', 'enLabel': 'group of humans'},
#     {'itemId': 'Q15042037', 'enLabel': 'statistical territorial entity'},
#     {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#     {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#     {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#     {'itemId': 'Q17334923', 'enLabel': 'location'},
#     {'itemId': 'Q43229', 'enLabel': 'organization'},
#     {'itemId': 'Q19829125', 'enLabel': 'absence'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q7887142', 'enLabel': 'unit of analysis'},
#     {'itemId': 'Q16334298', 'enLabel': 'living thing group'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q30060700', 'enLabel': 'object of science'},
#     {'itemId': 'Q24229398', 'enLabel': 'agent'},
#     {'itemId': 'Q16513015', 'enLabel': 'order'},
#     {'itemId': 'Q16889133', 'enLabel': 'class'},
#     {'itemId': 'Q6671777', 'enLabel': 'structure'},
#     {'itemId': 'Q4330518', 'enLabel': 'research object'},
#     {'itemId': 'Q2198779', 'enLabel': 'unit'},
#     {'itemId': 'Q16887380', 'enLabel': 'group'},
#     {'itemId': 'Q517966', 'enLabel': 'structure'},
#     {'itemId': 'Q23958946', 'enLabel': 'individual'},
#     {'itemId': 'Q1789452', 'enLabel': 'criterion'},
#     {'itemId': 'Q3505845', 'enLabel': 'state'},
#     {'itemId': 'Q5127848', 'enLabel': 'class'},
#     {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#     {'itemId': 'Q17553950', 'enLabel': 'object'},
#     {'itemId': 'Q1921834', 'enLabel': 'feature'},
#     {'itemId': 'Q937228', 'enLabel': 'property'},
#     {'itemId': 'Q483247', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q714737', 'enLabel': 'category of being'},
#     {'itemId': 'Q1207505', 'enLabel': 'quality'},
#     {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#     {'itemId': 'Q16722960', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q151885', 'enLabel': 'concept'},
#     {'itemId': 'Q26907166', 'enLabel': 'temporal entity'},
#     {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#     {'itemId': 'Q4393498', 'enLabel': 'representation'}],
#    'wikiDataClassIds': ['Q15661340',
#     'Q839954',
#     'Q17431399',
#     'Q2974842',
#     'Q1291195',
#     'Q15642541',
#     'Q14524493',
#     'Q33506',
#     'Q74047',
#     'Q515',
#     'Q618123',
#     'Q1496967',
#     'Q16686448',
#     'Q271669',
#     'Q1030034',
#     'Q13226383',
#     'Q5193377',
#     'Q22674925',
#     'Q486972',
#     'Q177634',
#     'Q7930989',
#     'Q702492',
#     'Q223557',
#     'Q58416391',
#     'Q82794',
#     'Q35120',
#     'Q12766313',
#     'Q2221906',
#     'Q178706',
#     'Q15893266',
#     'Q874405',
#     'Q16334295',
#     'Q15042037',
#     'Q4406616',
#     'Q1454986',
#     'Q58415929',
#     'Q17334923',
#     'Q43229',
#     'Q19829125',
#     'Q58778',
#     'Q7887142',
#     'Q16334298',
#     'Q488383',
#     'Q30060700',
#     'Q24229398',
#     'Q16513015',
#     'Q16889133',
#     'Q6671777',
#     'Q4330518',
#     'Q2198779',
#     'Q16887380',
#     'Q517966',
#     'Q23958946',
#     'Q1789452',
#     'Q3505845',
#     'Q5127848',
#     'Q7184903',
#     'Q17553950',
#     'Q1921834',
#     'Q937228',
#     'Q483247',
#     'Q714737',
#     'Q1207505',
#     'Q1190554',
#     'Q16722960',
#     'Q151885',
#     'Q26907166',
#     'Q2145290',
#     'Q4393498'],
#    'dbPediaTypes': ['Place', 'WorldHeritageSite'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Pompeii'},
#   {'title': 'Samnites',
#    'url': 'http://en.wikipedia.org/wiki/Samnites',
#    'pageRank': 0.0038154357845719433,
#    'cosine': 0.14869798909851106,
#    'lang': 'en',
#    'support': [{'wFrom': 963, 'wTo': 963, 'chunk': 0},
#     {'wFrom': 967, 'wTo': 967, 'chunk': 0},
#     {'wFrom': 977, 'wTo': 977, 'chunk': 0}],
#    'wikiDataItemId': 'Q500272',
#    'wikiDataClasses': [{'itemId': 'Q2472587', 'enLabel': 'people'},
#     {'itemId': 'Q874405', 'enLabel': 'social group'},
#     {'itemId': 'Q16334295', 'enLabel': 'group of humans'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q7887142', 'enLabel': 'unit of analysis'},
#     {'itemId': 'Q16334298', 'enLabel': 'living thing group'},
#     {'itemId': 'Q6671777', 'enLabel': 'structure'},
#     {'itemId': 'Q4330518', 'enLabel': 'research object'},
#     {'itemId': 'Q2198779', 'enLabel': 'unit'},
#     {'itemId': 'Q16887380', 'enLabel': 'group'},
#     {'itemId': 'Q517966', 'enLabel': 'structure'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#     {'itemId': 'Q17553950', 'enLabel': 'object'},
#     {'itemId': 'Q4406616', 'enLabel': 'concrete object'}],
#    'wikiDataClassIds': ['Q2472587',
#     'Q874405',
#     'Q16334295',
#     'Q58778',
#     'Q7887142',
#     'Q16334298',
#     'Q6671777',
#     'Q4330518',
#     'Q2198779',
#     'Q16887380',
#     'Q517966',
#     'Q35120',
#     'Q488383',
#     'Q7184903',
#     'Q17553950',
#     'Q4406616'],
#    'dbPediaTypes': ['PopulatedPlace', 'Place'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Sabellians'},
#   {'title': 'Lava',
#    'url': 'http://en.wikipedia.org/wiki/Lava',
#    'pageRank': 0.003630996714491836,
#    'cosine': 0.20049486484197385,
#    'lang': 'en',
#    'support': [{'wFrom': 1159, 'wTo': 1159, 'chunk': 0},
#     {'wFrom': 1180, 'wTo': 1180, 'chunk': 0},
#     {'wFrom': 1204, 'wTo': 1204, 'chunk': 0},
#     {'wFrom': 1277, 'wTo': 1277, 'chunk': 0},
#     {'wFrom': 1331, 'wTo': 1331, 'chunk': 0},
#     {'wFrom': 1438, 'wTo': 1438, 'chunk': 0},
#     {'wFrom': 1812, 'wTo': 1812, 'chunk': 0}],
#    'wikiDataItemId': 'Q40157',
#    'wikiDataClasses': [],
#    'wikiDataClassIds': [],
#    'dbPediaTypes': ['Agent', 'Organisation', 'Company', 'RecordLabel'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Lava'},
#   {'title': 'Mount Vesuvius',
#    'url': 'http://en.wikipedia.org/wiki/Mount_Vesuvius',
#    'pageRank': 0.003344867537362839,
#    'cosine': 0.3625857514945056,
#    'lang': 'en',
#    'support': [{'wFrom': 538, 'wTo': 540, 'chunk': 0},
#     {'wFrom': 540, 'wTo': 540, 'chunk': 0},
#     {'wFrom': 1161, 'wTo': 1161, 'chunk': 0},
#     {'wFrom': 1323, 'wTo': 1323, 'chunk': 0},
#     {'wFrom': 1659, 'wTo': 1659, 'chunk': 0}],
#    'wikiDataItemId': 'Q524',
#    'wikiDataClasses': [{'itemId': 'Q1330974', 'enLabel': 'active volcano'},
#     {'itemId': 'Q169358', 'enLabel': 'stratovolcano'},
#     {'itemId': 'Q8072', 'enLabel': 'volcano'},
#     {'itemId': 'Q8502', 'enLabel': 'mountain'},
#     {'itemId': 'Q29025902', 'enLabel': 'volcanic landform'},
#     {'itemId': 'Q14524493', 'enLabel': 'terrain'},
#     {'itemId': 'Q207326', 'enLabel': 'summit'},
#     {'itemId': 'Q35145263', 'enLabel': 'natural geographic object'},
#     {'itemId': 'Q271669', 'enLabel': 'landform'},
#     {'itemId': 'Q2221906', 'enLabel': 'geographic location'},
#     {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#     {'itemId': 'Q16686022', 'enLabel': 'natural physical object'},
#     {'itemId': 'Q12766313', 'enLabel': 'geomorphological unit'},
#     {'itemId': 'Q17334923', 'enLabel': 'location'},
#     {'itemId': 'Q223557', 'enLabel': 'physical object'},
#     {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#     {'itemId': 'Q29651224', 'enLabel': 'natural object'},
#     {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#     {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#     {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q1322005', 'enLabel': 'natural phenomenon'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q30060700', 'enLabel': 'object of science'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q483247', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q6671777', 'enLabel': 'structure'},
#     {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#     {'itemId': 'Q16722960', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q26907166', 'enLabel': 'temporal entity'}],
#    'wikiDataClassIds': ['Q1330974',
#     'Q169358',
#     'Q8072',
#     'Q8502',
#     'Q29025902',
#     'Q14524493',
#     'Q207326',
#     'Q35145263',
#     'Q271669',
#     'Q2221906',
#     'Q618123',
#     'Q16686022',
#     'Q12766313',
#     'Q17334923',
#     'Q223557',
#     'Q58416391',
#     'Q29651224',
#     'Q4406616',
#     'Q1454986',
#     'Q58415929',
#     'Q488383',
#     'Q1322005',
#     'Q58778',
#     'Q30060700',
#     'Q35120',
#     'Q483247',
#     'Q6671777',
#     'Q1190554',
#     'Q16722960',
#     'Q26907166'],
#    'dbPediaTypes': ['Place', 'Mountain', 'NaturalPlace', 'Volcano'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Mount_Vesuvius'},
#   {'title': 'Ancient Rome',
#    'url': 'http://en.wikipedia.org/wiki/Ancient_Rome',
#    'pageRank': 0.0031142185561927574,
#    'cosine': 0.2999609464376098,
#    'lang': 'en',
#    'support': [{'wFrom': 28, 'wTo': 28, 'chunk': 0},
#     {'wFrom': 81, 'wTo': 81, 'chunk': 0},
#     {'wFrom': 92, 'wTo': 92, 'chunk': 0},
#     {'wFrom': 562, 'wTo': 562, 'chunk': 0},
#     {'wFrom': 619, 'wTo': 619, 'chunk': 0},
#     {'wFrom': 784, 'wTo': 784, 'chunk': 0},
#     {'wFrom': 864, 'wTo': 864, 'chunk': 0},
#     {'wFrom': 1039, 'wTo': 1039, 'chunk': 0},
#     {'wFrom': 1053, 'wTo': 1053, 'chunk': 0},
#     {'wFrom': 1053, 'wTo': 1054, 'chunk': 0},
#     {'wFrom': 1075, 'wTo': 1076, 'chunk': 0},
#     {'wFrom': 1076, 'wTo': 1076, 'chunk': 0},
#     {'wFrom': 1083, 'wTo': 1083, 'chunk': 0},
#     {'wFrom': 1632, 'wTo': 1632, 'chunk': 0}],
#    'wikiDataItemId': 'Q1747689',
#    'wikiDataClasses': [{'itemId': 'Q1620908', 'enLabel': 'historical region'},
#     {'itemId': 'Q3502482', 'enLabel': 'cultural region'},
#     {'itemId': 'Q28171280', 'enLabel': 'ancient civilization'},
#     {'itemId': 'Q3024240', 'enLabel': 'historical country'},
#     {'itemId': 'Q82794', 'enLabel': 'geographic region'},
#     {'itemId': 'Q15893266', 'enLabel': 'former entity'},
#     {'itemId': 'Q15642541', 'enLabel': 'human-geographic territorial entity'},
#     {'itemId': 'Q8432', 'enLabel': 'civilization'},
#     {'itemId': 'Q19953632',
#      'enLabel': 'former administrative territorial entity'},
#     {'itemId': 'Q6256', 'enLabel': 'country'},
#     {'itemId': 'Q7275', 'enLabel': 'state'},
#     {'itemId': 'Q2221906', 'enLabel': 'geographic location'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q19829125', 'enLabel': 'absence'},
#     {'itemId': 'Q1496967', 'enLabel': 'territorial entity'},
#     {'itemId': 'Q16686448', 'enLabel': 'artificial entity'},
#     {'itemId': 'Q8425', 'enLabel': 'society'},
#     {'itemId': 'Q56061', 'enLabel': 'administrative territorial entity'},
#     {'itemId': 'Q19832712', 'enLabel': 'historical administrative division'},
#     {'itemId': 'Q1048835', 'enLabel': 'political territorial entity'},
#     {'itemId': 'Q43229', 'enLabel': 'organization'},
#     {'itemId': 'Q177634', 'enLabel': 'community'},
#     {'itemId': 'Q155076', 'enLabel': 'juridical person'},
#     {'itemId': 'Q17334923', 'enLabel': 'location'},
#     {'itemId': 'Q16889133', 'enLabel': 'class'},
#     {'itemId': 'Q874405', 'enLabel': 'social group'},
#     {'itemId': 'Q4204519', 'enLabel': 'historical fact'},
#     {'itemId': 'Q24229398', 'enLabel': 'agent'},
#     {'itemId': 'Q16334295', 'enLabel': 'group of humans'},
#     {'itemId': 'Q16513015', 'enLabel': 'order'},
#     {'itemId': 'Q3778211', 'enLabel': 'legal person'},
#     {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#     {'itemId': 'Q5127848', 'enLabel': 'class'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q7887142', 'enLabel': 'unit of analysis'},
#     {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#     {'itemId': 'Q188572', 'enLabel': 'fact'},
#     {'itemId': 'Q192630', 'enLabel': 'past'},
#     {'itemId': 'Q23958946', 'enLabel': 'individual'},
#     {'itemId': 'Q1789452', 'enLabel': 'criterion'},
#     {'itemId': 'Q16334298', 'enLabel': 'living thing group'},
#     {'itemId': 'Q3505845', 'enLabel': 'state'},
#     {'itemId': 'Q830077', 'enLabel': 'subject'},
#     {'itemId': 'Q223557', 'enLabel': 'physical object'},
#     {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#     {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#     {'itemId': 'Q6671777', 'enLabel': 'structure'},
#     {'itemId': 'Q4330518', 'enLabel': 'research object'},
#     {'itemId': 'Q2198779', 'enLabel': 'unit'},
#     {'itemId': 'Q26907166', 'enLabel': 'temporal entity'},
#     {'itemId': 'Q42848', 'enLabel': 'data'},
#     {'itemId': 'Q2684591', 'enLabel': 'statement'},
#     {'itemId': 'Q11471', 'enLabel': 'time'},
#     {'itemId': 'Q1921834', 'enLabel': 'feature'},
#     {'itemId': 'Q16887380', 'enLabel': 'group'},
#     {'itemId': 'Q517966', 'enLabel': 'structure'},
#     {'itemId': 'Q937228', 'enLabel': 'property'},
#     {'itemId': 'Q483247', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#     {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#     {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q11028', 'enLabel': 'information'},
#     {'itemId': 'Q108163', 'enLabel': 'proposition'},
#     {'itemId': 'Q20937557', 'enLabel': 'series'},
#     {'itemId': 'Q17553950', 'enLabel': 'object'},
#     {'itemId': 'Q714737', 'enLabel': 'category of being'},
#     {'itemId': 'Q1207505', 'enLabel': 'quality'},
#     {'itemId': 'Q16722960', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q30060700', 'enLabel': 'object of science'},
#     {'itemId': 'Q41796', 'enLabel': 'sentence'},
#     {'itemId': 'Q246672', 'enLabel': 'mathematical object'},
#     {'itemId': 'Q151885', 'enLabel': 'concept'},
#     {'itemId': 'Q1786828', 'enLabel': 'constituent'},
#     {'itemId': 'Q15916540', 'enLabel': 'semantic unit'},
#     {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#     {'itemId': 'Q5371079', 'enLabel': 'emic unit'},
#     {'itemId': 'Q183046', 'enLabel': 'meaning'},
#     {'itemId': 'Q4393498', 'enLabel': 'representation'},
#     {'itemId': 'Q20817253', 'enLabel': 'linguistic unit'},
#     {'itemId': 'Q16877783', 'enLabel': 'meaning'},
#     {'itemId': 'Q4173967', 'enLabel': 'language unit'},
#     {'itemId': 'Q29651519', 'enLabel': 'mental object'}],
#    'wikiDataClassIds': ['Q1620908',
#     'Q3502482',
#     'Q28171280',
#     'Q3024240',
#     'Q82794',
#     'Q15893266',
#     'Q15642541',
#     'Q8432',
#     'Q19953632',
#     'Q6256',
#     'Q7275',
#     'Q2221906',
#     'Q35120',
#     'Q19829125',
#     'Q1496967',
#     'Q16686448',
#     'Q8425',
#     'Q56061',
#     'Q19832712',
#     'Q1048835',
#     'Q43229',
#     'Q177634',
#     'Q155076',
#     'Q17334923',
#     'Q16889133',
#     'Q874405',
#     'Q4204519',
#     'Q24229398',
#     'Q16334295',
#     'Q16513015',
#     'Q3778211',
#     'Q618123',
#     'Q5127848',
#     'Q58778',
#     'Q7887142',
#     'Q1190554',
#     'Q188572',
#     'Q192630',
#     'Q23958946',
#     'Q1789452',
#     'Q16334298',
#     'Q3505845',
#     'Q830077',
#     'Q223557',
#     'Q58416391',
#     'Q7184903',
#     'Q6671777',
#     'Q4330518',
#     'Q2198779',
#     'Q26907166',
#     'Q42848',
#     'Q2684591',
#     'Q11471',
#     'Q1921834',
#     'Q16887380',
#     'Q517966',
#     'Q937228',
#     'Q483247',
#     'Q4406616',
#     'Q1454986',
#     'Q58415929',
#     'Q488383',
#     'Q11028',
#     'Q108163',
#     'Q20937557',
#     'Q17553950',
#     'Q714737',
#     'Q1207505',
#     'Q16722960',
#     'Q30060700',
#     'Q41796',
#     'Q246672',
#     'Q151885',
#     'Q1786828',
#     'Q15916540',
#     'Q2145290',
#     'Q5371079',
#     'Q183046',
#     'Q4393498',
#     'Q20817253',
#     'Q16877783',
#     'Q4173967',
#     'Q29651519'],
#    'dbPediaTypes': ['PopulatedPlace',
#     'Place',
#     'Country',
#     'Territory',
#     'OldTerritory'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Ancient_Rome'},
#   {'title': 'Boscoreale',
#    'url': 'http://en.wikipedia.org/wiki/Boscoreale',
#    'pageRank': 0.003113899583083107,
#    'cosine': 0.24575084340794787,
#    'lang': 'en',
#    'support': [{'wFrom': 223, 'wTo': 223, 'chunk': 0},
#     {'wFrom': 225, 'wTo': 225, 'chunk': 0},
#     {'wFrom': 275, 'wTo': 275, 'chunk': 0}],
#    'wikiDataItemId': 'Q71845',
#    'wikiDataClasses': [{'itemId': 'Q747074', 'enLabel': 'comune of Italy'},
#     {'itemId': 'Q13221722',
#      'enLabel': 'third-level administrative country subdivision'},
#     {'itemId': 'Q2824645',
#      'enLabel': 'administrative territorial entity of Italy'},
#     {'itemId': 'Q15284', 'enLabel': 'municipality'},
#     {'itemId': 'Q1799794',
#      'enLabel': 'administrative territorial entity of a specific level'},
#     {'itemId': 'Q15916867',
#      'enLabel': 'administrative territorial entity of a single country'},
#     {'itemId': 'Q1048835', 'enLabel': 'political territorial entity'},
#     {'itemId': 'Q2097994', 'enLabel': 'municipal corporation'},
#     {'itemId': 'Q486972', 'enLabel': 'human settlement'},
#     {'itemId': 'Q56061', 'enLabel': 'administrative territorial entity'},
#     {'itemId': 'Q15642541', 'enLabel': 'human-geographic territorial entity'},
#     {'itemId': 'Q6501447', 'enLabel': 'local government'},
#     {'itemId': 'Q82794', 'enLabel': 'geographic region'},
#     {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#     {'itemId': 'Q177634', 'enLabel': 'community'},
#     {'itemId': 'Q1496967', 'enLabel': 'territorial entity'},
#     {'itemId': 'Q16686448', 'enLabel': 'artificial entity'},
#     {'itemId': 'Q7188', 'enLabel': 'government'},
#     {'itemId': 'Q43229', 'enLabel': 'organization'},
#     {'itemId': 'Q2221906', 'enLabel': 'geographic location'},
#     {'itemId': 'Q223557', 'enLabel': 'physical object'},
#     {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#     {'itemId': 'Q874405', 'enLabel': 'social group'},
#     {'itemId': 'Q16334295', 'enLabel': 'group of humans'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q7210356', 'enLabel': 'political organisation'},
#     {'itemId': 'Q895526', 'enLabel': 'organ'},
#     {'itemId': 'Q35798', 'enLabel': 'executive branch'},
#     {'itemId': 'Q24229398', 'enLabel': 'agent'},
#     {'itemId': 'Q16513015', 'enLabel': 'order'},
#     {'itemId': 'Q17334923', 'enLabel': 'location'},
#     {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#     {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#     {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q7887142', 'enLabel': 'unit of analysis'},
#     {'itemId': 'Q16334298', 'enLabel': 'living thing group'},
#     {'itemId': 'Q174834', 'enLabel': 'authority'},
#     {'itemId': 'Q2101636', 'enLabel': 'political power'},
#     {'itemId': 'Q15708736', 'enLabel': 'public authority'},
#     {'itemId': 'Q2324993', 'enLabel': 'state power'},
#     {'itemId': 'Q23958946', 'enLabel': 'individual'},
#     {'itemId': 'Q1789452', 'enLabel': 'criterion'},
#     {'itemId': 'Q3505845', 'enLabel': 'state'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q30060700', 'enLabel': 'object of science'},
#     {'itemId': 'Q6671777', 'enLabel': 'structure'},
#     {'itemId': 'Q4330518', 'enLabel': 'research object'},
#     {'itemId': 'Q2198779', 'enLabel': 'unit'},
#     {'itemId': 'Q16887380', 'enLabel': 'group'},
#     {'itemId': 'Q517966', 'enLabel': 'structure'},
#     {'itemId': 'Q25107', 'enLabel': 'power'},
#     {'itemId': 'Q2659904', 'enLabel': 'government organization'},
#     {'itemId': 'Q1125239', 'enLabel': 'public body'},
#     {'itemId': 'Q1921834', 'enLabel': 'feature'},
#     {'itemId': 'Q937228', 'enLabel': 'property'},
#     {'itemId': 'Q483247', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#     {'itemId': 'Q17553950', 'enLabel': 'object'},
#     {'itemId': 'Q18340964', 'enLabel': 'power'},
#     {'itemId': 'Q714737', 'enLabel': 'category of being'},
#     {'itemId': 'Q1207505', 'enLabel': 'quality'},
#     {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#     {'itemId': 'Q16722960', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q151885', 'enLabel': 'concept'},
#     {'itemId': 'Q26907166', 'enLabel': 'temporal entity'},
#     {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#     {'itemId': 'Q4393498', 'enLabel': 'representation'}],
#    'wikiDataClassIds': ['Q747074',
#     'Q13221722',
#     'Q2824645',
#     'Q15284',
#     'Q1799794',
#     'Q15916867',
#     'Q1048835',
#     'Q2097994',
#     'Q486972',
#     'Q56061',
#     'Q15642541',
#     'Q6501447',
#     'Q82794',
#     'Q618123',
#     'Q177634',
#     'Q1496967',
#     'Q16686448',
#     'Q7188',
#     'Q43229',
#     'Q2221906',
#     'Q223557',
#     'Q58416391',
#     'Q874405',
#     'Q16334295',
#     'Q35120',
#     'Q7210356',
#     'Q895526',
#     'Q35798',
#     'Q24229398',
#     'Q16513015',
#     'Q17334923',
#     'Q4406616',
#     'Q1454986',
#     'Q58415929',
#     'Q58778',
#     'Q7887142',
#     'Q16334298',
#     'Q174834',
#     'Q2101636',
#     'Q15708736',
#     'Q2324993',
#     'Q23958946',
#     'Q1789452',
#     'Q3505845',
#     'Q488383',
#     'Q30060700',
#     'Q6671777',
#     'Q4330518',
#     'Q2198779',
#     'Q16887380',
#     'Q517966',
#     'Q25107',
#     'Q2659904',
#     'Q1125239',
#     'Q1921834',
#     'Q937228',
#     'Q483247',
#     'Q7184903',
#     'Q17553950',
#     'Q18340964',
#     'Q714737',
#     'Q1207505',
#     'Q1190554',
#     'Q16722960',
#     'Q151885',
#     'Q26907166',
#     'Q2145290',
#     'Q4393498'],
#    'dbPediaTypes': ['City',
#     'Settlement',
#     'PopulatedPlace',
#     'Place',
#     'AdministrativeRegion',
#     'Region'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Boscoreale'},
#   {'title': 'Skeleton',
#    'url': 'http://en.wikipedia.org/wiki/Skeleton',
#    'pageRank': 0.0027404853711771584,
#    'cosine': 0.22432098003312076,
#    'lang': 'en',
#    'support': [{'wFrom': 1707, 'wTo': 1707, 'chunk': 0},
#     {'wFrom': 1716, 'wTo': 1716, 'chunk': 0},
#     {'wFrom': 1721, 'wTo': 1721, 'chunk': 0},
#     {'wFrom': 1783, 'wTo': 1783, 'chunk': 0},
#     {'wFrom': 1789, 'wTo': 1789, 'chunk': 0},
#     {'wFrom': 1837, 'wTo': 1837, 'chunk': 0},
#     {'wFrom': 52, 'wTo': 52, 'chunk': 1},
#     {'wFrom': 96, 'wTo': 96, 'chunk': 1}],
#    'wikiDataItemId': 'Q7881',
#    'wikiDataClasses': [],
#    'wikiDataClassIds': [],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/Skeleton'},
#   {'title': 'Campania',
#    'url': 'http://en.wikipedia.org/wiki/Campania',
#    'pageRank': 0.002653586789565017,
#    'cosine': 0.28352691499769916,
#    'lang': 'en',
#    'support': [{'wFrom': 55, 'wTo': 55, 'chunk': 0}],
#    'wikiDataItemId': 'Q1438',
#    'wikiDataClasses': [{'itemId': 'Q16110', 'enLabel': 'region of Italy'},
#     {'itemId': 'Q2824645',
#      'enLabel': 'administrative territorial entity of Italy'},
#     {'itemId': 'Q10864048',
#      'enLabel': 'first-level administrative country subdivision'},
#     {'itemId': 'Q1048835', 'enLabel': 'political territorial entity'},
#     {'itemId': 'Q3455524', 'enLabel': 'administrative region'},
#     {'itemId': 'Q15916867',
#      'enLabel': 'administrative territorial entity of a single country'},
#     {'itemId': 'Q1799794',
#      'enLabel': 'administrative territorial entity of a specific level'},
#     {'itemId': 'Q15642541', 'enLabel': 'human-geographic territorial entity'},
#     {'itemId': 'Q56061', 'enLabel': 'administrative territorial entity'},
#     {'itemId': 'Q1496967', 'enLabel': 'territorial entity'},
#     {'itemId': 'Q16686448', 'enLabel': 'artificial entity'},
#     {'itemId': 'Q82794', 'enLabel': 'geographic region'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q2221906', 'enLabel': 'geographic location'},
#     {'itemId': 'Q17334923', 'enLabel': 'location'},
#     {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#     {'itemId': 'Q223557', 'enLabel': 'physical object'},
#     {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#     {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#     {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#     {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q30060700', 'enLabel': 'object of science'},
#     {'itemId': 'Q6671777', 'enLabel': 'structure'}],
#    'wikiDataClassIds': ['Q16110',
#     'Q2824645',
#     'Q10864048',
#     'Q1048835',
#     'Q3455524',
#     'Q15916867',
#     'Q1799794',
#     'Q15642541',
#     'Q56061',
#     'Q1496967',
#     'Q16686448',
#     'Q82794',
#     'Q35120',
#     'Q2221906',
#     'Q17334923',
#     'Q618123',
#     'Q223557',
#     'Q58416391',
#     'Q4406616',
#     'Q1454986',
#     'Q58415929',
#     'Q488383',
#     'Q58778',
#     'Q30060700',
#     'Q6671777'],
#    'dbPediaTypes': ['PopulatedPlace',
#     'Place',
#     'AdministrativeRegion',
#     'Region'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Campania'},
#   {'title': 'Naples',
#    'url': 'http://en.wikipedia.org/wiki/Naples',
#    'pageRank': 0.002491342969735601,
#    'cosine': 0.2410574134288819,
#    'lang': 'en',
#    'support': [{'wFrom': 207, 'wTo': 207, 'chunk': 0}],
#    'wikiDataItemId': 'Q2634',
#    'wikiDataClasses': [{'itemId': 'Q515', 'enLabel': 'city'},
#     {'itemId': 'Q747074', 'enLabel': 'comune of Italy'},
#     {'itemId': 'Q3024240', 'enLabel': 'historical country'},
#     {'itemId': 'Q1549591', 'enLabel': 'big city'},
#     {'itemId': 'Q486972', 'enLabel': 'human settlement'},
#     {'itemId': 'Q177634', 'enLabel': 'community'},
#     {'itemId': 'Q7930989', 'enLabel': 'city/town'},
#     {'itemId': 'Q702492', 'enLabel': 'urban area'},
#     {'itemId': 'Q13221722',
#      'enLabel': 'third-level administrative country subdivision'},
#     {'itemId': 'Q2824645',
#      'enLabel': 'administrative territorial entity of Italy'},
#     {'itemId': 'Q15284', 'enLabel': 'municipality'},
#     {'itemId': 'Q19953632',
#      'enLabel': 'former administrative territorial entity'},
#     {'itemId': 'Q6256', 'enLabel': 'country'},
#     {'itemId': 'Q7275', 'enLabel': 'state'},
#     {'itemId': 'Q82794', 'enLabel': 'geographic region'},
#     {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#     {'itemId': 'Q874405', 'enLabel': 'social group'},
#     {'itemId': 'Q16334295', 'enLabel': 'group of humans'},
#     {'itemId': 'Q15042037', 'enLabel': 'statistical territorial entity'},
#     {'itemId': 'Q1799794',
#      'enLabel': 'administrative territorial entity of a specific level'},
#     {'itemId': 'Q15916867',
#      'enLabel': 'administrative territorial entity of a single country'},
#     {'itemId': 'Q1048835', 'enLabel': 'political territorial entity'},
#     {'itemId': 'Q2097994', 'enLabel': 'municipal corporation'},
#     {'itemId': 'Q56061', 'enLabel': 'administrative territorial entity'},
#     {'itemId': 'Q15893266', 'enLabel': 'former entity'},
#     {'itemId': 'Q19832712', 'enLabel': 'historical administrative division'},
#     {'itemId': 'Q43229', 'enLabel': 'organization'},
#     {'itemId': 'Q155076', 'enLabel': 'juridical person'},
#     {'itemId': 'Q2221906', 'enLabel': 'geographic location'},
#     {'itemId': 'Q223557', 'enLabel': 'physical object'},
#     {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q7887142', 'enLabel': 'unit of analysis'},
#     {'itemId': 'Q16334298', 'enLabel': 'living thing group'},
#     {'itemId': 'Q15642541', 'enLabel': 'human-geographic territorial entity'},
#     {'itemId': 'Q6501447', 'enLabel': 'local government'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q19829125', 'enLabel': 'absence'},
#     {'itemId': 'Q4204519', 'enLabel': 'historical fact'},
#     {'itemId': 'Q24229398', 'enLabel': 'agent'},
#     {'itemId': 'Q16513015', 'enLabel': 'order'},
#     {'itemId': 'Q3778211', 'enLabel': 'legal person'},
#     {'itemId': 'Q17334923', 'enLabel': 'location'},
#     {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#     {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#     {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#     {'itemId': 'Q6671777', 'enLabel': 'structure'},
#     {'itemId': 'Q4330518', 'enLabel': 'research object'},
#     {'itemId': 'Q2198779', 'enLabel': 'unit'},
#     {'itemId': 'Q16887380', 'enLabel': 'group'},
#     {'itemId': 'Q517966', 'enLabel': 'structure'},
#     {'itemId': 'Q1496967', 'enLabel': 'territorial entity'},
#     {'itemId': 'Q16686448', 'enLabel': 'artificial entity'},
#     {'itemId': 'Q7188', 'enLabel': 'government'},
#     {'itemId': 'Q16889133', 'enLabel': 'class'},
#     {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#     {'itemId': 'Q188572', 'enLabel': 'fact'},
#     {'itemId': 'Q192630', 'enLabel': 'past'},
#     {'itemId': 'Q23958946', 'enLabel': 'individual'},
#     {'itemId': 'Q1789452', 'enLabel': 'criterion'},
#     {'itemId': 'Q3505845', 'enLabel': 'state'},
#     {'itemId': 'Q830077', 'enLabel': 'subject'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q30060700', 'enLabel': 'object of science'},
#     {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#     {'itemId': 'Q17553950', 'enLabel': 'object'},
#     {'itemId': 'Q7210356', 'enLabel': 'political organisation'},
#     {'itemId': 'Q895526', 'enLabel': 'organ'},
#     {'itemId': 'Q35798', 'enLabel': 'executive branch'},
#     {'itemId': 'Q5127848', 'enLabel': 'class'},
#     {'itemId': 'Q26907166', 'enLabel': 'temporal entity'},
#     {'itemId': 'Q42848', 'enLabel': 'data'},
#     {'itemId': 'Q2684591', 'enLabel': 'statement'},
#     {'itemId': 'Q11471', 'enLabel': 'time'},
#     {'itemId': 'Q1921834', 'enLabel': 'feature'},
#     {'itemId': 'Q937228', 'enLabel': 'property'},
#     {'itemId': 'Q483247', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q174834', 'enLabel': 'authority'},
#     {'itemId': 'Q2101636', 'enLabel': 'political power'},
#     {'itemId': 'Q15708736', 'enLabel': 'public authority'},
#     {'itemId': 'Q2324993', 'enLabel': 'state power'},
#     {'itemId': 'Q11028', 'enLabel': 'information'},
#     {'itemId': 'Q108163', 'enLabel': 'proposition'},
#     {'itemId': 'Q20937557', 'enLabel': 'series'},
#     {'itemId': 'Q714737', 'enLabel': 'category of being'},
#     {'itemId': 'Q1207505', 'enLabel': 'quality'},
#     {'itemId': 'Q16722960', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q25107', 'enLabel': 'power'},
#     {'itemId': 'Q2659904', 'enLabel': 'government organization'},
#     {'itemId': 'Q1125239', 'enLabel': 'public body'},
#     {'itemId': 'Q41796', 'enLabel': 'sentence'},
#     {'itemId': 'Q246672', 'enLabel': 'mathematical object'},
#     {'itemId': 'Q151885', 'enLabel': 'concept'},
#     {'itemId': 'Q18340964', 'enLabel': 'power'},
#     {'itemId': 'Q1786828', 'enLabel': 'constituent'},
#     {'itemId': 'Q15916540', 'enLabel': 'semantic unit'},
#     {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#     {'itemId': 'Q5371079', 'enLabel': 'emic unit'},
#     {'itemId': 'Q183046', 'enLabel': 'meaning'},
#     {'itemId': 'Q4393498', 'enLabel': 'representation'},
#     {'itemId': 'Q20817253', 'enLabel': 'linguistic unit'},
#     {'itemId': 'Q16877783', 'enLabel': 'meaning'},
#     {'itemId': 'Q4173967', 'enLabel': 'language unit'},
#     {'itemId': 'Q29651519', 'enLabel': 'mental object'}],
#    'wikiDataClassIds': ['Q515',
#     'Q747074',
#     'Q3024240',
#     'Q1549591',
#     'Q486972',
#     'Q177634',
#     'Q7930989',
#     'Q702492',
#     'Q13221722',
#     'Q2824645',
#     'Q15284',
#     'Q19953632',
#     'Q6256',
#     'Q7275',
#     'Q82794',
#     'Q618123',
#     'Q874405',
#     'Q16334295',
#     'Q15042037',
#     'Q1799794',
#     'Q15916867',
#     'Q1048835',
#     'Q2097994',
#     'Q56061',
#     'Q15893266',
#     'Q19832712',
#     'Q43229',
#     'Q155076',
#     'Q2221906',
#     'Q223557',
#     'Q58416391',
#     'Q58778',
#     'Q7887142',
#     'Q16334298',
#     'Q15642541',
#     'Q6501447',
#     'Q35120',
#     'Q19829125',
#     'Q4204519',
#     'Q24229398',
#     'Q16513015',
#     'Q3778211',
#     'Q17334923',
#     'Q4406616',
#     'Q1454986',
#     'Q58415929',
#     'Q6671777',
#     'Q4330518',
#     'Q2198779',
#     'Q16887380',
#     'Q517966',
#     'Q1496967',
#     'Q16686448',
#     'Q7188',
#     'Q16889133',
#     'Q1190554',
#     'Q188572',
#     'Q192630',
#     'Q23958946',
#     'Q1789452',
#     'Q3505845',
#     'Q830077',
#     'Q488383',
#     'Q30060700',
#     'Q7184903',
#     'Q17553950',
#     'Q7210356',
#     'Q895526',
#     'Q35798',
#     'Q5127848',
#     'Q26907166',
#     'Q42848',
#     'Q2684591',
#     'Q11471',
#     'Q1921834',
#     'Q937228',
#     'Q483247',
#     'Q174834',
#     'Q2101636',
#     'Q15708736',
#     'Q2324993',
#     'Q11028',
#     'Q108163',
#     'Q20937557',
#     'Q714737',
#     'Q1207505',
#     'Q16722960',
#     'Q25107',
#     'Q2659904',
#     'Q1125239',
#     'Q41796',
#     'Q246672',
#     'Q151885',
#     'Q18340964',
#     'Q1786828',
#     'Q15916540',
#     'Q2145290',
#     'Q5371079',
#     'Q183046',
#     'Q4393498',
#     'Q20817253',
#     'Q16877783',
#     'Q4173967',
#     'Q29651519'],
#    'dbPediaTypes': ['City',
#     'Settlement',
#     'PopulatedPlace',
#     'Place',
#     'AdministrativeRegion',
#     'Region'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Naples'},
#   {'title': 'Italy',
#    'url': 'http://en.wikipedia.org/wiki/Italy',
#    'pageRank': 0.0022563201073930025,
#    'cosine': 0.28350418112514525,
#    'lang': 'en',
#    'support': [{'wFrom': 715, 'wTo': 715, 'chunk': 0},
#     {'wFrom': 951, 'wTo': 951, 'chunk': 0}],
#    'wikiDataItemId': 'Q38',
#    'wikiDataClasses': [{'itemId': 'Q3624078', 'enLabel': 'sovereign state'},
#     {'itemId': 'Q6256', 'enLabel': 'country'},
#     {'itemId': 'Q619610', 'enLabel': 'social state'},
#     {'itemId': 'Q179164', 'enLabel': 'unitary state'},
#     {'itemId': 'Q7275', 'enLabel': 'state'},
#     {'itemId': 'Q7270', 'enLabel': 'republic'},
#     {'itemId': 'Q1048835', 'enLabel': 'political territorial entity'},
#     {'itemId': 'Q43229', 'enLabel': 'organization'},
#     {'itemId': 'Q177634', 'enLabel': 'community'},
#     {'itemId': 'Q155076', 'enLabel': 'juridical person'},
#     {'itemId': 'Q7174', 'enLabel': 'democracy'},
#     {'itemId': 'Q15642541', 'enLabel': 'human-geographic territorial entity'},
#     {'itemId': 'Q24229398', 'enLabel': 'agent'},
#     {'itemId': 'Q16334295', 'enLabel': 'group of humans'},
#     {'itemId': 'Q16513015', 'enLabel': 'order'},
#     {'itemId': 'Q874405', 'enLabel': 'social group'},
#     {'itemId': 'Q3778211', 'enLabel': 'legal person'},
#     {'itemId': 'Q28108', 'enLabel': 'political system'},
#     {'itemId': 'Q1496967', 'enLabel': 'territorial entity'},
#     {'itemId': 'Q16686448', 'enLabel': 'artificial entity'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q23958946', 'enLabel': 'individual'},
#     {'itemId': 'Q1789452', 'enLabel': 'criterion'},
#     {'itemId': 'Q16334298', 'enLabel': 'living thing group'},
#     {'itemId': 'Q3505845', 'enLabel': 'state'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q7887142', 'enLabel': 'unit of analysis'},
#     {'itemId': 'Q830077', 'enLabel': 'subject'},
#     {'itemId': 'Q1639378', 'enLabel': 'social system'},
#     {'itemId': 'Q82794', 'enLabel': 'geographic region'},
#     {'itemId': 'Q1921834', 'enLabel': 'feature'},
#     {'itemId': 'Q16887380', 'enLabel': 'group'},
#     {'itemId': 'Q517966', 'enLabel': 'structure'},
#     {'itemId': 'Q937228', 'enLabel': 'property'},
#     {'itemId': 'Q483247', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q6671777', 'enLabel': 'structure'},
#     {'itemId': 'Q4330518', 'enLabel': 'research object'},
#     {'itemId': 'Q2198779', 'enLabel': 'unit'},
#     {'itemId': 'Q2221906', 'enLabel': 'geographic location'},
#     {'itemId': 'Q17553950', 'enLabel': 'object'},
#     {'itemId': 'Q714737', 'enLabel': 'category of being'},
#     {'itemId': 'Q1207505', 'enLabel': 'quality'},
#     {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#     {'itemId': 'Q16722960', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#     {'itemId': 'Q17334923', 'enLabel': 'location'},
#     {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#     {'itemId': 'Q151885', 'enLabel': 'concept'},
#     {'itemId': 'Q26907166', 'enLabel': 'temporal entity'},
#     {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#     {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#     {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#     {'itemId': 'Q223557', 'enLabel': 'physical object'},
#     {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#     {'itemId': 'Q4393498', 'enLabel': 'representation'},
#     {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#     {'itemId': 'Q30060700', 'enLabel': 'object of science'}],
#    'wikiDataClassIds': ['Q3624078',
#     'Q6256',
#     'Q619610',
#     'Q179164',
#     'Q7275',
#     'Q7270',
#     'Q1048835',
#     'Q43229',
#     'Q177634',
#     'Q155076',
#     'Q7174',
#     'Q15642541',
#     'Q24229398',
#     'Q16334295',
#     'Q16513015',
#     'Q874405',
#     'Q3778211',
#     'Q28108',
#     'Q1496967',
#     'Q16686448',
#     'Q35120',
#     'Q23958946',
#     'Q1789452',
#     'Q16334298',
#     'Q3505845',
#     'Q58778',
#     'Q7887142',
#     'Q830077',
#     'Q1639378',
#     'Q82794',
#     'Q1921834',
#     'Q16887380',
#     'Q517966',
#     'Q937228',
#     'Q483247',
#     'Q6671777',
#     'Q4330518',
#     'Q2198779',
#     'Q2221906',
#     'Q17553950',
#     'Q714737',
#     'Q1207505',
#     'Q1190554',
#     'Q16722960',
#     'Q488383',
#     'Q7184903',
#     'Q17334923',
#     'Q4406616',
#     'Q151885',
#     'Q26907166',
#     'Q618123',
#     'Q2145290',
#     'Q58415929',
#     'Q223557',
#     'Q58416391',
#     'Q4393498',
#     'Q1454986',
#     'Q30060700'],
#    'dbPediaTypes': ['PopulatedPlace', 'Place', 'Country'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Italy'},
#   {'title': 'Peristyle',
#    'url': 'http://en.wikipedia.org/wiki/Peristyle',
#    'pageRank': 0.0022272463297215747,
#    'cosine': 0.17891798661997024,
#    'lang': 'en',
#    'support': [{'wFrom': 802, 'wTo': 802, 'chunk': 0}],
#    'wikiDataItemId': 'Q725453',
#    'wikiDataClasses': [{'itemId': 'Q1497384', 'enLabel': 'part of building'},
#     {'itemId': 'Q56052926', 'enLabel': 'building division'},
#     {'itemId': 'Q17334923', 'enLabel': 'location'},
#     {'itemId': 'Q811430', 'enLabel': 'construction'},
#     {'itemId': 'Q15989253', 'enLabel': 'part'},
#     {'itemId': 'Q618123', 'enLabel': 'geographical object'},
#     {'itemId': 'Q8205328', 'enLabel': 'artificial physical object'},
#     {'itemId': 'Q35145743', 'enLabel': 'human-made geographic object'},
#     {'itemId': 'Q386724', 'enLabel': 'work'},
#     {'itemId': 'Q6671777', 'enLabel': 'structure'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q223557', 'enLabel': 'physical object'},
#     {'itemId': 'Q58416391', 'enLabel': 'spatial entity'},
#     {'itemId': 'Q16686448', 'enLabel': 'artificial entity'},
#     {'itemId': 'Q27096235', 'enLabel': 'artificial geographic entity'},
#     {'itemId': 'Q15401930', 'enLabel': 'product'},
#     {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#     {'itemId': 'Q1454986', 'enLabel': 'physical system'},
#     {'itemId': 'Q58415929', 'enLabel': 'spacio-temporal entity'},
#     {'itemId': 'Q27096213', 'enLabel': 'geographic entity'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q30060700', 'enLabel': 'object of science'}],
#    'wikiDataClassIds': ['Q1497384',
#     'Q56052926',
#     'Q17334923',
#     'Q811430',
#     'Q15989253',
#     'Q618123',
#     'Q8205328',
#     'Q35145743',
#     'Q386724',
#     'Q6671777',
#     'Q35120',
#     'Q223557',
#     'Q58416391',
#     'Q16686448',
#     'Q27096235',
#     'Q15401930',
#     'Q4406616',
#     'Q1454986',
#     'Q58415929',
#     'Q27096213',
#     'Q488383',
#     'Q58778',
#     'Q30060700'],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/Peristyle'},
#   {'title': 'Architecture',
#    'url': 'http://en.wikipedia.org/wiki/Architecture',
#    'pageRank': 0.0021981072962756454,
#    'cosine': 0.27032474176319343,
#    'lang': 'en',
#    'support': [{'wFrom': 53, 'wTo': 53, 'chunk': 0},
#     {'wFrom': 125, 'wTo': 125, 'chunk': 0},
#     {'wFrom': 383, 'wTo': 383, 'chunk': 0},
#     {'wFrom': 444, 'wTo': 444, 'chunk': 0},
#     {'wFrom': 564, 'wTo': 564, 'chunk': 0},
#     {'wFrom': 990, 'wTo': 990, 'chunk': 0},
#     {'wFrom': 1080, 'wTo': 1080, 'chunk': 0}],
#    'wikiDataItemId': 'Q12271',
#    'wikiDataClasses': [{'itemId': 'Q11862829',
#      'enLabel': 'academic discipline'},
#     {'itemId': 'Q1047113', 'enLabel': 'specialty'},
#     {'itemId': 'Q9081', 'enLabel': 'knowledge'},
#     {'itemId': 'Q11028', 'enLabel': 'information'},
#     {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
# ...
#    'support': [{'wFrom': 1580, 'wTo': 1580, 'chunk': 0}],
#    'wikiDataItemId': 'Q79007',
#    'wikiDataClasses': [],
#    'wikiDataClassIds': [],
#    'dbPediaTypes': ['PopulatedPlace', 'Place'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Street'},
#   {'title': 'Fact',
#    'url': 'http://en.wikipedia.org/wiki/Fact',
#    'pageRank': 0.0007979679955828611,
#    'cosine': 0.255090747699011,
#    'lang': 'en',
#    'support': [{'wFrom': 115, 'wTo': 115, 'chunk': 0},
#     {'wFrom': 608, 'wTo': 608, 'chunk': 0},
#     {'wFrom': 1187, 'wTo': 1187, 'chunk': 0},
#     {'wFrom': 1263, 'wTo': 1263, 'chunk': 0},
#     {'wFrom': 1311, 'wTo': 1311, 'chunk': 0},
#     {'wFrom': 1425, 'wTo': 1425, 'chunk': 0},
#     {'wFrom': 1669, 'wTo': 1669, 'chunk': 0}],
#    'wikiDataItemId': 'Q188572',
#    'wikiDataClasses': [],
#    'wikiDataClassIds': [],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/Fact'},
#   {'title': 'Witness',
#    'url': 'http://en.wikipedia.org/wiki/Witness',
#    'pageRank': 0.0007844500367621678,
#    'cosine': 0.19392077732358493,
#    'lang': 'en',
#    'support': [{'wFrom': 1103, 'wTo': 1103, 'chunk': 0}],
#    'wikiDataItemId': 'Q196939',
#    'wikiDataClasses': [],
#    'wikiDataClassIds': [],
#    'dbPediaTypes': ['Work', 'Album', 'MusicalWork'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Witness'},
#   {'title': 'Multiverse',
#    'url': 'http://en.wikipedia.org/wiki/Multiverse',
#    'pageRank': 0.0007819466003039575,
#    'cosine': 0.2030278987262624,
#    'lang': 'en',
#    'support': [{'wFrom': 851, 'wTo': 851, 'chunk': 0},
#     {'wFrom': 1512, 'wTo': 1512, 'chunk': 0},
#     {'wFrom': 1760, 'wTo': 1760, 'chunk': 0}],
#    'wikiDataItemId': 'Q3327819',
#    'wikiDataClasses': [{'itemId': 'Q41719', 'enLabel': 'hypothesis'},
#     {'itemId': 'Q108163', 'enLabel': 'proposition'},
#     {'itemId': 'Q321703', 'enLabel': 'premise'},
#     {'itemId': 'Q11028', 'enLabel': 'information'},
#     {'itemId': 'Q41796', 'enLabel': 'sentence'},
#     {'itemId': 'Q246672', 'enLabel': 'mathematical object'},
#     {'itemId': 'Q7184903', 'enLabel': 'abstract object'},
#     {'itemId': 'Q1786828', 'enLabel': 'constituent'},
#     {'itemId': 'Q15916540', 'enLabel': 'semantic unit'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q5371079', 'enLabel': 'emic unit'},
#     {'itemId': 'Q183046', 'enLabel': 'meaning'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q16889133', 'enLabel': 'class'},
#     {'itemId': 'Q20817253', 'enLabel': 'linguistic unit'},
#     {'itemId': 'Q16877783', 'enLabel': 'meaning'},
#     {'itemId': 'Q5127848', 'enLabel': 'class'},
#     {'itemId': 'Q4173967', 'enLabel': 'language unit'},
#     {'itemId': 'Q151885', 'enLabel': 'concept'},
#     {'itemId': 'Q29651519', 'enLabel': 'mental object'},
#     {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#     {'itemId': 'Q4393498', 'enLabel': 'representation'},
#     {'itemId': 'Q937228', 'enLabel': 'property'},
#     {'itemId': 'Q714737', 'enLabel': 'category of being'},
#     {'itemId': 'Q1207505', 'enLabel': 'quality'}],
#    'wikiDataClassIds': ['Q41719',
#     'Q108163',
#     'Q321703',
#     'Q11028',
#     'Q41796',
#     'Q246672',
#     'Q7184903',
#     'Q1786828',
#     'Q15916540',
#     'Q488383',
#     'Q5371079',
#     'Q183046',
#     'Q35120',
#     'Q16889133',
#     'Q20817253',
#     'Q16877783',
#     'Q5127848',
#     'Q4173967',
#     'Q151885',
#     'Q29651519',
#     'Q2145290',
#     'Q4393498',
#     'Q937228',
#     'Q714737',
#     'Q1207505'],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/Multiverse'}],
#  'words': [['Professor',
#    'Diana',
#    'E',
#    '.',
#    'E',
#    '.',
#    'Kleiner',
#    ':',
#    'Good',
#    'morning',
#    '.',
#    'As',
#    'you',
#    'can',
#    'see',
#    'from',
#    'the',
#    'title',
#    'of',
#    'today’s',
#    'lecture',
#    ',',
#    '“',
#    'Habitats',
#    'at',
#    'Herculaneum',
#    'and',
#    'Early',
#    'Roman',
#    'Interior',
#    'Decoration',
#    ',',
#    '”',
#    'we’re',
#    'going',
#    'to',
#    'be',
#    'concentrating',
#    'once',
#    'again',
#    ',',
#    'at',
#    'least',
#    'in',
#    'the',
#    'first',
#    'half',
#    'of',
#    'the',
#    'lecture',
#    ',',
#    'on',
#    'domestic',
#    'architecture',
#    'in',
#    'Campania',
#    '.',
#    'We’re',
#    'going',
#    'to',
#    'look',
#    'at',
#    'several',
#    'houses',
#    'in',
#    'Herculaneum',
#    ',',
#    'and',
#    'then',
#    'we’re',
#    'going',
#    'to',
#    'move',
#    'from',
#    'there',
#    'to',
#    'begin',
#    'our',
#    'discussion',
#    'of',
#    'early',
#    'Roman',
#    'interior',
#    'decoration',
#    ',',
#    'namely',
#    'the',
#    'First',
#    'and',
#    'Second',
#    'Styles',
#    'of',
#    'Roman',
#    'wall',
#    'painting',
#    '.',
#    'And',
#    'what',
#    'you’ll',
#    'see',
#    'makes',
#    'them',
#    'particularly',
#    'relevant',
#    'to',
#    'what',
#    'we’ve',
#    'been',
#    'discussing',
#    'thus',
#    'far',
#    'this',
#    'term',
#    'is',
#    'the',
#    'fact',
#    'that',
#    'in',
#    'both',
#    'the',
#    'First',
#    'and',
#    'Second',
#    'Styles',
#    ',',
#    'architecture',
#    'is',
#    'depicted',
#    'in',
#    'these',
#    'paintings',
#    ',',
#    'and',
#    'we’re',
#    'going',
#    'to',
#    'see',
#    'some',
#    'very',
#    'interesting',
#    'relationships',
#    'between',
#    'that',
#    'and',
#    'the',
#    'built',
#    'monuments',
#    'that',
#    'we’ve',
#    'talked',
#    'about',
#    'thus',
#    'far',
#    'this',
#    'semester',
#    '.',
#    '\n\n',
#    'Just',
#    'to',
#    'remind',
#    'you',
#    'of',
#    'the',
#    'location',
#    'of',
#    'Herculaneum',
#    ',',
#    'which',
#    'is',
#    'usually',
#    'called',
#    'the',
#    'sister',
#    'city',
#    'of',
#    'Pompeii',
#    ',',
#    'because',
#    'of',
#    'that',
#    'locale',
#    '.',
#    'We',
#    'see',
#    'it',
#    'on',
#    'the',
#    'map',
#    'here',
#    '.',
#    'Pompeii',
#    'is',
#    'down',
#    'in',
#    'this',
#    'location',
#    '.',
#    'Herculaneum',
#    'is',
#    'to',
#    'the',
#    'northeast',
#    'of',
#    'Pompeii',
#    ',',
#    'closer',
#    'to',
#    'Naples',
#    'than',
#    'Pompeii',
#    'is',
#    ',',
#    'as',
#    'you',
#    'can',
#    'see',
#    '.',
#    'And',
#    'note',
#    'also',
#    'the',
#    'city',
#    'of',
#    'Boscoreale',
#    ',',
#    'Boscoreale',
#    ',',
#    'which',
#    'is',
#    'located',
#    'between',
#    ',',
#    'almost',
#    'equidistant',
#    '–',
#    'a',
#    'little',
#    'bit',
#    'closer',
#    'to',
#    'Pompeii',
#    'than',
#    'Herculaneum',
#    '–',
#    'but',
#    'in',
#    'between',
#    'the',
#    'two',
#    '.',
#    'And',
#    'I',
#    'point',
#    'it',
#    'out',
#    'to',
#    'you',
#    'now',
#    'because',
#    'we’re',
#    'going',
#    'to',
#    'look',
#    'at',
#    'an',
#    'important',
#    'room',
#    ',',
#    'with',
#    'paintings',
#    ',',
#    'from',
#    'the',
#    'city',
#    'of',
#    'Boscoreale',
#    'today',
#    'as',
#    'well',
#    '.',
#    'Here',
#    'you',
#    'see',
#    'a',
#    'view',
#    ',',
#    'a',
#    'Google',
#    'Earth',
#    'flyover',
#    ',',
#    'of',
#    'Herculaneum',
#    ',',
#    'as',
#    'it',
#    'looks',
#    'today',
#    '.',
#    'It’s',
#    'very',
#    'helpful',
#    'because',
#    'you',
#    'can',
#    'see',
#    'a',
#    'couple',
#    'of',
#    'things',
#    'here',
#    'that',
#    'I',
#    'want',
#    'you',
#    'to',
#    'keep',
#    'in',
#    'mind',
#    ',',
#    'as',
#    'we',
#    'look',
#    'at',
#    'this',
#    'city',
#    '.',
#    'One',
#    ',',
#    'that',
#    'although',
#    'most',
#    'of',
#    'the',
#    'city',
#    'of',
#    'Pompeii',
#    'has',
#    'been',
#    'excavated',
#    ',',
#    'only',
#    'about',
#    'a',
#    'quarter',
#    'or',
#    'twenty-five',
#    'percent',
#    'of',
#    'the',
#    'city',
#    'of',
#    'Herculaneum',
#    'has',
#    'been',
#    'excavated',
#    '.',
#    'So',
#    'we',
#    'have',
#    'much',
#    'less',
#    'at',
#    'Herculaneum',
#    'than',
#    'we',
#    'do',
#    'for',
#    'Pompeii',
#    ',',
#    'and',
#    'what',
#    'we’re',
#    'missing',
#    ',',
#    'for',
#    'the',
#    'most',
#    'part',
#    ',',
#    'is',
#    'the',
#    'public',
#    'architecture',
#    '.',
#    'We',
#    'don’t',
#    'have',
#    'a',
#    'great',
#    'amphitheater',
#    'from',
#    'Herculaneum',
#    '.',
#    'We',
#    'don’t',
#    'have',
#    'a',
#    'theater',
#    'and',
#    'a',
#    'music',
#    'hall',
#    'complex',
#    '.',
#    'We',
#    'think',
#    'we',
#    'might',
#    'have',
#    'part',
#    'of',
#    'the',
#    'basilica',
#    ',',
#    'but',
#    'we’re',
#    'not',
#    'absolutely',
#    'sure',
#    '.',
#    'We',
#    'don’t',
#    'have',
#    'the',
#    'great',
#    'large',
#    'forum',
#    'space',
#    'that',
#    'we',
#    'have',
#    'in',
#    'Pompeii',
#    '.',
#    '\n\n',
#    'So',
#    'we’re',
#    'missing',
#    'a',
#    'lot',
#    'of',
#    'that',
#    'public',
#    'architecture',
#    'at',
#    'Herculaneum',
#    ',',
#    'which',
#    'gives',
#    'us',
#    'less',
#    'of',
#    'a',
#    'sense',
#    'of',
#    'what',
#    'the',
#    'city',
#    'was',
#    'originally',
#    'like',
#    ',',
#    'at',
#    'least',
#    'in',
#    'its',
#    'public',
#    'face',
#    ',',
#    'although',
#    'there’s',
#    'no',
#    'doubt',
#    'that',
#    'that',
#    'material',
#    'still',
#    'lies',
#    'beneath',
#    'the',
#    'ground',
#    '.',
#    'So',
#    'we',
#    'have',
#    'only',
#    'a',
#    'quarter',
#    'of',
#    'the',
#    'city',
#    ',',
#    'mostly',
#    'the',
#    'residential',
#    'part',
#    'of',
#    'the',
#    'city',
#    ',',
#    'or',
#    'part',
#    'of',
#    'the',
#    'residential',
#    'part',
#    'of',
#    'the',
#    'city',
#    '.',
#    'But',
#    'there',
#    'are',
#    'several',
#    'houses',
#    'there',
#    'that',
#    'are',
#    'extremely',
#    '–',
#    'give',
#    'us',
#    ',',
#    'provide',
#    'information',
#    ',',
#    'especially',
#    'about',
#    'what',
#    'was',
#    'going',
#    'on',
#    'between',
#    'the',
#    'earthquake',
#    'and',
#    'the',
#    'eruption',
#    'of',
#    'Vesuvius',
#    ',',
#    '62',
#    'to',
#    '79',
#    ',',
#    'that',
#    'are',
#    'extremely',
#    'valuable',
#    'in',
#    'terms',
#    'of',
#    'giving',
#    'us',
#    'a',
#    'sense',
#    'again',
#    'of',
#    'the',
#    'evolution',
#    'of',
#    'Roman',
#    'domestic',
#    'architecture',
#    '.',
#    'The',
#    'other',
#    'issue',
#    'that',
#    'this',
#    'particular',
#    'view',
#    'raises',
#    'is',
#    'the',
#    'reason',
#    'why',
#    'Herculaneum',
#    'is',
#    'less',
#    'well',
#    'excavated',
#    'than',
#    'Pompeii',
#    ',',
#    'and',
#    'the',
#    'reason',
#    'for',
#    'that',
#    'has',
#    'to',
#    'do',
#    '–',
#    'and',
#    'you',
#    'can',
#    'see',
#    'it',
#    'well',
#    'here',
#    '–',
#    'has',
#    'to',
#    'do',
#    'with',
#    'the',
#    'fact',
#    'that',
#    'the',
#    'modern',
#    'city',
#    'grew',
#    'up',
#    'on',
#    'top',
#    'of',
#    'the',
#    'ancient',
#    'city',
#    '.',
#    'And',
#    'they',
#    'were',
#    'able',
#    'at',
#    'one',
#    'point',
#    'to',
#    'clear',
#    'part',
#    'of',
#    'it',
#    ',',
#    'for',
#    'excavation',
#    ',',
#    'but',
#    'they',
#    'have',
#    'not',
#    'been',
#    'able',
#    'to',
#    'clear',
#    'the',
#    'rest',
#    '.',
#    'It’s',
#    'a',
#    'political',
#    'nightmare',
#    'to',
#    'have',
#    'to',
#    'deal',
#    '–',
#    'you',
#    'have',
#    'to',
#    'relocate',
#    'all',
#    'the',
#    'people',
#    'who',
#    'live',
#    'in',
#    'this',
#    'area',
#    'and',
#    'have',
#    'lived',
#    'in',
#    'this',
#    'area',
#    'for',
#    'a',
#    'very',
#    'long',
#    'time',
#    '.',
#    'That’s',
#    'politically',
#    'a',
#    'very',
#    'difficult',
#    'thing',
#    'to',
#    'do',
#    '.',
#    'It',
#    'also',
#    'is',
#    'extremely',
#    'costly',
#    '.',
#    'So',
#    'thus',
#    'far',
#    'only',
#    'twenty-five',
#    'percent',
#    'of',
#    'Herculaneum',
#    'revealed',
#    '.',
#    'Let’s',
#    'all',
#    'hope',
#    'that',
#    'at',
#    'some',
#    'point',
#    'someday',
#    'Italy',
#    'can',
#    'sort',
#    'this',
#    'out',
#    'and',
#    'find',
#    'a',
#    'way',
#    'to',
#    'excavate',
#    'the',
#    'rest',
#    'of',
#    'this',
#    'extraordinary',
#    'city',
#    '.',
#    '\n\n',
#    'You',
#    'can',
#    'see',
#    'from',
#    'this',
#    'view',
#    'that',
#    'I',
#    'took',
#    'as',
#    '–',
#    'this',
#    'is',
#    'one',
#    'of',
#    'the',
#    'views',
#    'that',
#    'you',
#    'get',
#    'as',
#    'you',
#    'enter',
#    'the',
#    'site',
#    ',',
#    'the',
#    'current',
#    'location',
#    'today',
#    '.',
#    'But',
#    'I',
#    'think',
#    'you',
#    'can',
#    'see',
#    'very',
#    'well',
#    'here',
#    'again',
#    'what',
#    'I’m',
#    'talking',
#    'about',
#    ':',
#    'the',
#    'relationship',
#    'between',
#    'the',
#    'ancient',
#    'city',
#    ',',
#    'lower',
#    'ground',
#    'level',
#    ',',
#    'that',
#    'has',
#    'been',
#    'unearthed',
#    'through',
#    'excavation',
#    '.',
#    'You',
#    'can',
#    'see',
#    'a',
#    'peristyle',
#    'court',
#    'of',
#    'one',
#    'of',
#    'the',
#    'houses',
#    'here',
#    ',',
#    'for',
#    'example',
#    '.',
#    'But',
#    'you',
#    'can',
#    'see',
#    'the',
#    'way',
#    'in',
#    'which',
#    'the',
#    'modern',
#    'city',
#    'rings',
#    'the',
#    'site',
#    ',',
#    'and',
#    'again',
#    'what',
#    'a',
#    'challenge',
#    'it',
#    'would',
#    'be',
#    'to',
#    'remove',
#    'that',
#    'modern',
#    'city',
#    'and',
#    'to',
#    'reveal',
#    'the',
#    'rest',
#    'of',
#    'Herculaneum',
#    '.',
#    'Here’s',
#    'another',
#    'view',
#    'where',
#    'you',
#    'can',
#    'also',
#    'see',
#    'some',
#    'of',
#    'the',
#    'remains',
#    'of',
#    'the',
#    'ancient',
#    'city',
#    ',',
#    'of',
#    'these',
#    'residences',
#    'and',
#    'so',
#    'on',
#    ',',
#    'and',
#    'their',
#    'relationship',
#    'to',
#    'the',
#    'rest',
#    'of',
#    'the',
#    'town',
#    '.',
#    '\n\n',
#    'With',
#    'regard',
#    'to',
#    'the',
#    'history',
#    'of',
#    'Herculaneum',
#    ',',
#    'it',
#    'is',
#    'very',
#    'similar',
#    'to',
#    'the',
#    'history',
#    'of',
#    'Pompeii',
#    '.',
#    'One',
#    'difference',
#    'is',
#    'that',
#    'the',
#    'city',
#    'of',
#    'Herculaneum',
#    'was',
#    'supposedly',
#    'founded',
#    'by',
#    'Hercules',
#    ',',
#    'hence',
#    'its',
#    'name',
#    'Herculaneum',
#    '.',
#    'But',
#    'in',
#    'other',
#    'respects',
#    'the',
#    'history',
#    'again',
#    'is',
#    'quite',
#    'comparable',
#    '.',
#    'We',
#    'know',
#    ',',
#    'for',
#    'example',
#    ',',
#    'that',
#    'the',
#    'city',
#    'of',
#    'Herculaneum',
#    'was',
#    'overseen',
#    'for',
#    'awhile',
#    'by',
#    'that',
#    'same',
#    'Italic',
#    'tribe',
#    'called',
#    'the',
#    'Oscans',
#    ',',
#    'who',
#    'were',
#    'then',
#    'conquered',
#    'by',
#    'the',
#    'Samnites',
#    ',',
#    'and',
#    'the',
#    'Samnites',
#    'took',
#    'over',
#    'Herculaneum',
#    '.',
#    'And',
#    'it',
#    'was',
#    'during',
#    'the',
#    'Samnite',
#    'period',
#    'in',
#    'Herculaneum',
#    'that',
#    'we',
#    'begin',
#    'to',
#    'see',
#    'the',
#    'same',
#    'kind',
#    'of',
#    'architectural',
#    'development',
#    'that',
#    'we',
#    'saw',
#    'also',
#    'in',
#    'Pompeii',
#    '.',
#    'We',
#    ...],
#   ['were',
#    'right',
#    'on',
#    'the',
#    'sea',
#    ',',
#    'they',
#    'had',
#    'a',
#    'lot',
#    'of',
#    'boats',
#    ',',
#    'and',
#    'the',
#    'hope',
#    'was',
#    'that',
#    'they',
#    'could',
#    'ferry',
#    'everybody',
#    'out',
#    'from',
#    'the',
#    'city',
#    '.',
#    'And',
#    'for',
#    'the',
#    'most',
#    'part',
#    'they',
#    'were',
#    'successful',
#    ',',
#    'but',
#    'there',
#    'was',
#    'a',
#    'certain',
#    'group',
#    'that',
#    'unfortunately',
#    'got',
#    'left',
#    'behind',
#    ',',
#    'and',
#    'it',
#    'was',
#    'their',
#    'remains',
#    'that',
#    'were',
#    'discovered',
#    'in',
#    'the',
#    '1980s',
#    '.',
#    '\n\n',
#    'It’s',
#    'amazing',
#    'what',
#    'these',
#    'bodies',
#    'can',
#    'tell',
#    'us',
#    'about',
#    'some',
#    'of',
#    'the',
#    'people',
#    'who',
#    'lived',
#    'there',
#    ',',
#    'and',
#    'I’ll',
#    'just',
#    'give',
#    'you',
#    'a',
#    'little',
#    'sense',
#    'of',
#    'a',
#    'couple',
#    'of',
#    'the',
#    'storylines',
#    '.',
#    'Here',
#    'is',
#    'the',
#    'skeleton',
#    'of',
#    'a',
#    'woman',
#    ',',
#    'and',
#    'you',
#    'can',
#    'see',
#    'that',
#    'this',
#    'woman',
#    'has',
#    '–',
#    'if',
#    'you',
#    'look',
#    'very',
#    'closely',
#    'at',
#    'her',
#    'left',
#    'hand',
#    ',',
#    'two',
#    'of',
#    'her',
#    'fingers',
#    '–',
#    'you',
#    'can',
#    'see',
#    'she',
#    'has',
#    'rin']]}

# %% [markdown]
# Test SAHAN

# %%
PATH = "/home/benromdhane-w/Bureau/ls2n/projects/X5GON/hackaton/x5gon_hackathon_materials/x5gon_materials_catelogue.tsv"
PATHOUT = "/home/benromdhane-w/Bureau/ls2n/projects/X5GON/hackaton/x5gon_hackathon_materials/comparewiki.tsv"

# %%
import psycopg2

PGCred = dict(PGHOST='127.0.0.1',
              PGDATABASE='x5gon',
              PGUSER='developernantestest',
              PGPASSWORD='devntes#51!&#test',
              PGPORT='5555')

def db_connect(PGHOST:str,PGDATABASE:str,PGUSER:str,PGPASSWORD:str,PGPORT:str):
    # Set up a connection to the postgres server.
    conn_string = "host="+ PGHOST +" port="+ PGPORT +" dbname="+ PGDATABASE +" user=" + PGUSER +" password="+ PGPASSWORD
    conn=psycopg2.connect(conn_string)
    conn.set_session(autocommit=True)
    cursor = conn.cursor()
    return {'connexion': conn, 'cursor': cursor}
connexion = db_connect(PGCred['PGHOST'],
                         PGCred['PGDATABASE'],
                         PGCred['PGUSER'],
                         PGCred['PGPASSWORD'],
                         PGCred['PGPORT'])

# %%
def get_data_generator(rid, *, verbose=True):
    query = "SELECT value FROM material_contents WHERE material_id=" + rid + " AND language='en' AND extension='plain';"  
    # query exec
    if verbose: print("Sending query...")
    try:
        cursor = connexion["cursor"]
        cursor.execute(query)
    except:
        print("Error when executing the query: verify it !")
    if verbose: print("Query processed!")
    return cursor

# %%
import csv 
import spacy
import time
nlp = spacy.load("en")
from wikification import LONG_TEXT_METHODS, wikification

# del LONG_TEXT_METHODS["sum_page_rank"]
nb = 0
with open(PATH, "r") as csvfile:
    with open(PATHOUT, "w") as csvout:
        csv_reader = csv.reader(csvfile, delimiter="\t", quotechar='"', quoting=csv.QUOTE_ALL)
        fields = next(csv_reader)
        print(fields)
        csv_writer = csv.writer(csvout, delimiter="\t", quotechar='"')
        csv_writer.writerow(fields + ["concepts sum_classic_page_rank cos",
                                      "concepts sum_classic_page_rank pk",
                                      "concepts sum_classic_page_rank cos top10",
                                      "concepts sum_classic_page_rank pk top10",
                                      "concepts recompute_on_anchor_text cos",
                                      "concepts recompute_on_anchor_text pk",
                                      "concepts recompute_on_anchor_text cos top10",
                                      "concepts recompute_on_anchor_text pk top10",
                                      "concepts sum_classic_page time",
                                      "concepts recompute_on_anchor_text time"])
        for row in csv_reader:
            nb += 1
            print(nb)
            rid = row[1]
            try:
                text = next(get_data_generator(rid, verbose=False))[0]["value"]
            except StopIteration:
                print(row, " has no en version in db!")
            wikifications = []
            runtime = []
            for m in LONG_TEXT_METHODS:
                print(f"Wikification {m}...")
                start = time.time()
                res = [(c['url'], c['title'], c['pageRank'], c['cosine']) for c in wikification(text, long_text_method_name=m)]
                end = time.time()
                ccos = sorted(res, key=lambda x: x[3], reverse=True)
                cpr = sorted(res, key=lambda x: x[2], reverse=True)
                top10cos = [c[1] for c in ccos[:10]]
                top10pr = [c[1] for c in cpr[:10]]
                wikifications.extend([ccos, cpr, top10cos, top10pr])
                runtime.append(end - start)
                print(f"{m} elapsed time: %f ms" % (1000*(end - start)))
            csv_writer.writerow(row + wikifications + runtime)
            if nb > 100: break
# Out:
# ['#', 'id', 'title', 'language', 'type']
# 1
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 4190.375566 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 8254.183769 ms
# 2
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 3578.340292 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 8418.923378 ms
# 3
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 2747.653961 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 7196.440458 ms
# 4
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 2763.147116 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 11080.199003 ms
# 5
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 3670.319080 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 5206.295490 ms
# 6
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 3784.085274 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 5991.353512 ms
# 7
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 2846.351624 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 9089.615107 ms
# 8
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 3796.042681 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 6004.167557 ms
# 9
# ['9', '82541', '45 let Nacionalnega inštituta za biologijo | 45th anniversary of the National Institute of Biology', 'sl', 'mp4']  has no en version in db!
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 4462.502956 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 6124.587536 ms
# 10
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 4266.768217 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 4998.503208 ms
# 11
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 6037.398815 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 7818.226337 ms
# 12
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 2886.986971 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 6915.290117 ms
# 13
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 2892.765999 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 2512.521267 ms
# 14
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 1263.699532 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 2032.653809 ms
# 15
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 5002.927542 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 7293.339252 ms
# 16
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 5289.523840 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 11738.499403 ms
# 17
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 2473.007441 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 5093.167305 ms
# 18
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 2886.327744 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 7596.126795 ms
# 19
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 2401.640892 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 5860.953808 ms
# 20
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 1877.862930 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 8925.778151 ms
# 21
# ['21', '82579', 'Živo srebro: od pomembne surovine do nevarnega odpadka', 'sl', 'pdf']  has no en version in db!
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 2124.764204 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 9786.525249 ms
# 22
# ['22', '82580', 'Dizajn molekulskega origamija za nove molekulske stroje in uravnavanje delovanja celic', 'sl', 'pdf']  has no en version in db!
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 2172.121286 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 4819.957733 ms
# 23
# ['23', '82581', 'Modifikacija površin z neravnovesno plazmo', 'sl', 'pdf']  has no en version in db!
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 3164.249659 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 3829.174519 ms
# 24
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 8584.124327 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 9390.389919 ms
# 25
# ['25', '82596', 'Življenje in smrt v Hudi jami', 'sl', 'mp4']  has no en version in db!
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 10494.590044 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 9300.315857 ms
# 26
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 4669.770479 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 8112.838984 ms
# 27
# ['27', '82599', 'Saksofon, ali te poznam?', 'sl', 'mp4']  has no en version in db!
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 4585.075140 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 9393.514395 ms
# 28
# ['28', '82600', 'Od ideje do izdelka', 'sl', 'mp4']  has no en version in db!
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 3858.740091 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 8063.073397 ms
# 29
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 1623.477459 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 1916.675329 ms
# 30
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 6891.006470 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 9217.612028 ms
# 31
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 1943.078756 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 4896.094561 ms
# 32
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 5783.622742 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 7704.862356 ms
# 33
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 6089.389086 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 8050.746441 ms
# 34
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 5695.441008 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 11082.671404 ms
# 35
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 1803.220272 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 2986.572027 ms
# 36
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 2037.798643 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 4502.619267 ms
# 37
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 906.926632 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 1022.077322 ms
# 38
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 2668.114185 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 4623.667717 ms
# 39
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 1869.882345 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 1995.677233 ms
# 40
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 631.375313 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 1018.360138 ms
# 41
# ['41', '87207', 'World cafe mladih', 'sl', 'mp4']  has no en version in db!
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 970.505714 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 2461.722612 ms
# 42
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 6665.502071 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 12178.593636 ms
# 43
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 8013.342857 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 12554.303646 ms
# 44
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 5826.312304 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 12535.105705 ms
# 45
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 8153.358698 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 14134.667397 ms
# 46
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 7083.645105 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 14262.944937 ms
# 47
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 8107.675314 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 10529.456615 ms
# 48
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 8209.683895 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 17168.230534 ms
# 49
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 8654.838800 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 14109.324932 ms
# 50
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 6704.715014 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 10827.917099 ms
# 51
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 6940.780878 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 13231.618404 ms
# 52
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 9025.686979 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 14878.280640 ms
# 53
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 7199.698925 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 11873.206854 ms
# 54
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 7010.862112 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 13054.767609 ms
# 55
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 7747.276783 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 12164.389133 ms
# 56
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 8632.846355 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 14142.013788 ms
# 57
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 6349.028111 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 11407.035828 ms
# 58
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 6940.437794 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 10575.115919 ms
# 59
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 8849.473000 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 12981.953859 ms
# 60
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 7427.456141 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 12968.529701 ms
# 61
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 7742.703199 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 12132.686853 ms
# 62
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 9038.224936 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 14594.211578 ms
# 63
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 4121.482134 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 10651.968002 ms
# 64
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 6943.692207 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 14961.930513 ms
# 65
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 3987.511873 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 6034.644604 ms
# 66
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 8035.326004 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 14710.398436 ms
# 67
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 3824.089527 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 10470.436096 ms
# 68
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 6454.364061 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 13493.483067 ms
# 69
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 7099.481583 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 13683.920622 ms
# 70
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 5134.563684 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 11464.223623 ms
# 71
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 7942.126751 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 13471.803188 ms
# 72
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 5697.417736 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 8973.369122 ms
# 73
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 4811.995983 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 8333.055019 ms
# 74
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 4034.785748 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 12418.702841 ms
# 75
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 4905.626059 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 7492.742777 ms
# 76
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 1260.528564 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 1015.970469 ms
# 77
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 3916.133881 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 7938.412666 ms
# 78
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 9542.241573 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 11566.820860 ms
# 79
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 1430.424213 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 969.202757 ms
# 80
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 764.753580 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 1017.676592 ms
# 81
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 1020.024061 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 1070.461035 ms
# 82
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 2076.324701 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 1897.639036 ms
# 83
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 4989.476919 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 7937.997103 ms
# 84
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 10088.017702 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 8794.893265 ms
# 85
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 8389.855146 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 7439.918280 ms
# 86
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 7771.876335 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 12864.286423 ms
# 87
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 4895.394564 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 8828.180790 ms
# 88
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 1958.986044 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 2651.548862 ms
# 89
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 4447.185755 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 7060.992241 ms
# 90
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 4805.271626 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 5919.892311 ms
# 91
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 4778.998613 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 6430.423975 ms
# 92
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 1291.317940 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 980.952740 ms
# 93
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 4591.201782 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 8961.110353 ms
# 94
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 4561.916351 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 6750.580072 ms
# 95
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 9273.768425 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 14506.474733 ms
# 96
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 492.329836 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 1022.506714 ms
# 97
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 6199.975491 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 8681.162834 ms
# 98
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 4109.647512 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 7863.463640 ms
# 99
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 5621.575356 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 6216.852903 ms
# 100
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 3998.971939 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 6841.362238 ms
# 101
# Wikification sum_classic_page_rank...
# sum_classic_page_rank elapsed time: 7031.619787 ms
# Wikification recompute_on_anchor_text...
# recompute_on_anchor_text elapsed time: 13710.253000 ms

# %%
times
# Out:
# {'sum_classic_page_rank': 4.408144235610962,
#  'recompute_on_anchor_text': 7.230750799179077}

# %%
wikifications = {k: sorted(v, key=lambda x: x[2], reverse=True)[:20] for k, v in wikifications.items()}

# %%
wikifications["sum_classic_page_rank"]
# Out:
# [('http://en.wikipedia.org/wiki/Publishing',
#   'Publishing',
#   0.00024976131168670535,
#   0.06370707295680747),
#  ('http://en.wikipedia.org/wiki/Subculture',
#   'Subculture',
#   0.00024901056460864464,
#   0.03468819405430953),
#  ('http://en.wikipedia.org/wiki/Subjectivity',
#   'Subjectivity',
#   0.0002487004825043602,
#   0.03609392388753419),
#  ('http://en.wikipedia.org/wiki/Screenshot',
#   'Screenshot',
#   0.00024731897109266587,
#   0.036067855218894856),
#  ('http://en.wikipedia.org/wiki/Good_Morning_America',
#   'Good Morning America',
#   0.00024731880978562804,
#   0.04487832649469313),
#  ('http://en.wikipedia.org/wiki/Data_type',
#   'Data type',
#   0.0002465436857935397,
#   0.04217951374956078),
#  ('http://en.wikipedia.org/wiki/Graph_(discrete_mathematics)',
#   'Graph (discrete mathematics)',
#   0.0002464617145499643,
#   0.028176310451856798),
#  ('http://en.wikipedia.org/wiki/Action_(philosophy)',
#   'Action (philosophy)',
#   0.0002462231860776275,
#   0.04913019988721437),
#  ('http://en.wikipedia.org/wiki/Clock',
#   'Clock',
#   0.000243802392209802,
#   0.04338016282884223),
#  ('http://en.wikipedia.org/wiki/Chinese_language',
#   'Chinese language',
#   0.00024349792759304647,
#   0.04331339931415477),
#  ('http://en.wikipedia.org/wiki/Month',
#   'Month',
#   0.00024306677047972828,
#   0.07422285428855399),
#  ('http://en.wikipedia.org/wiki/Multiverse',
#   'Multiverse',
#   0.00024267188682067516,
#   0.04742346698115513),
#  ('http://en.wikipedia.org/wiki/Evaluation',
#   'Evaluation',
#   0.00024222765351961453,
#   0.04424593554135726),
#  ('http://en.wikipedia.org/wiki/Utility',
#   'Utility',
#   0.00024177254385879525,
#   0.04502926931254838),
#  ('http://en.wikipedia.org/wiki/Germany',
#   'Germany',
#   0.00024125306046038128,
#   0.06101529584457713),
#  ('http://en.wikipedia.org/wiki/Taxonomy_(general)',
#   'Taxonomy (general)',
#   0.00024030205033631172,
#   0.04864634534350052),
#  ('http://en.wikipedia.org/wiki/Manhattan_Project',
#   'Manhattan Project',
#   0.00024009986829525521,
#   0.0662545485229275),
#  ('http://en.wikipedia.org/wiki/Tail',
#   'Tail',
#   0.00024007548945730948,
#   0.034786805001198746),
#  ('http://en.wikipedia.org/wiki/Citizenship',
#   'Citizenship',
#   0.0002393612529567331,
#   0.05599183702890129),
#  ('http://en.wikipedia.org/wiki/Authority',
#   'Authority',
#   0.00023934011115760547,
#   0.04927589070080138)]

# %%
wikifications["recompute_on_anchor_text"]
# Out:
# [('http://en.wikipedia.org/wiki/Existence',
#   'Existence',
#   0.00027306019885646563,
#   0.04028451283130918),
#  ('http://en.wikipedia.org/wiki/WikiLeaks',
#   'WikiLeaks',
#   0.000272821539822173,
#   0.004702044927254363),
#  ('http://en.wikipedia.org/wiki/Boat',
#   'Boat',
#   0.00027237446724222715,
#   0.00879045477834671),
#  ('http://en.wikipedia.org/wiki/Web_portal',
#   'Web portal',
#   0.00027163453254969963,
#   0.02151510786997989),
#  ('http://en.wikipedia.org/wiki/Debate',
#   'Debate',
#   0.0002714439760674053,
#   0.01888783636215817),
#  ('http://en.wikipedia.org/wiki/Parameter',
#   'Parameter',
#   0.00027003259223515184,
#   0.02575570525180859),
#  ('http://en.wikipedia.org/wiki/Subculture',
#   'Subculture',
#   0.00026959573933241053,
#   0.01178489182488321),
#  ('http://en.wikipedia.org/wiki/Interpersonal_relationship',
#   'Interpersonal relationship',
#   0.0002693021353359445,
#   0.026437556263209882),
#  ('http://en.wikipedia.org/wiki/Downtime',
#   'Downtime',
#   0.00026869005159876473,
#   0.04629260054619309),
#  ('http://en.wikipedia.org/wiki/Separation_of_powers',
#   'Separation of powers',
#   0.00026713953859747576,
#   0.01928466829599539),
#  ('http://en.wikipedia.org/wiki/Subroutine',
#   'Subroutine',
#   0.00026490702436264335,
#   0.019609502893073668),
#  ('http://en.wikipedia.org/wiki/Taste',
#   'Taste',
#   0.00026404244810277887,
#   0.01763107334275755),
#  ('http://en.wikipedia.org/wiki/Diphthong',
#   'Diphthong',
#   0.0002638904040695488,
#   0.01196589873989288),
#  ('http://en.wikipedia.org/wiki/Control_flow',
#   'Control flow',
#   0.0002637471785956846,
#   0.023137815212965512),
#  ('http://en.wikipedia.org/wiki/Professor',
#   'Professor',
#   0.00026304470113313564,
#   0.01348325994580826),
#  ('http://en.wikipedia.org/wiki/Air_traffic_control',
#   'Air traffic control',
#   0.00026294631245914695,
#   0.015894202668957243),
#  ('http://en.wikipedia.org/wiki/Interest',
#   'Interest',
#   0.0002625454675479028,
#   0.037450098182484355),
#  ('http://en.wikipedia.org/wiki/Interest_(emotion)',
#   'Interest (emotion)',
#   0.0002609806433841019,
#   0.014133006267369038),
#  ('http://en.wikipedia.org/wiki/Friendship',
#   'Friendship',
#   0.00026088616868419036,
#   0.01537116510003215),
#  ('http://en.wikipedia.org/wiki/Byzantine_Empire',
#   'Byzantine Empire',
#   0.0002607196163029808,
#   0.011593559940728873)]
